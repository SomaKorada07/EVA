# %%
from keras import backend as K
import time
import matplotlib.pyplot as plt

# Importing NumPy (Numerical Python) which is a library consisting of multidimensional array objects and a collection of routines for processing those arrays. It also gives an alias to the library.
import numpy as np

% matplotlib inline
np.random.seed(2017) 

# There are two main types of models available in Keras: the Sequential model and the Model class used with the functional API.
# Sequential model is a linear stack of layers. Importing Sequential model from Keras.
from keras.models import Sequential, Model

# Importing different layers from Keras.
from keras.layers.convolutional import Convolution2D, MaxPooling2D, SeparableConv2D
from keras.layers import Activation, Flatten, Dense, Dropout, Input, Lambda, Concatenate
from keras.layers.normalization import BatchNormalization

# Importing the utils library of Keras.
from keras.utils import np_utils

# Importing the concatenate library of Keras
from keras.layers.merge import concatenate

import tensorflow as tf

# Importing the callbacks of Keras.
from keras.callbacks import ModelCheckpoint

from keras.regularizers import l2
# Out:
# Using TensorFlow backend.

# %%
# !mv '/content/gdrive/My Drive/cifar-10-python.tar.gz' '/content/cifar-10-batches-py.tar.gz'

# %%
# !cp '/content/cifar-10-batches-py.tar.gz' ~/.keras/datasets/

# %%
ls ~/.keras/datasets
# Out:
# cifar-10-batches-py.tar.gz

# %%
# CIFAR10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images. Importing CIFAR10 dataset from Keras.
from keras.datasets import cifar10

# Loading the CIFAR10 60000 Training and 10000 Test data into respective numpy arrays
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()

# Setting the count, number of channels, rows and columns of training images
num_train, img_channels, img_rows, img_cols =  train_features.shape

# Setting the count of test images
num_test, _, _, _ =  test_features.shape

# Setting number of classes (10)
num_classes = len(np.unique(train_labels))

# %%
# Pixel normalization for training images
train_features = train_features.astype('float32')/255

# Pixel normalization for test images
test_features = test_features.astype('float32')/255

# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %%
# Space_to_depth funcction of Tensorflow rearranges blocks of spatial data into depth. 
def space_to_depth_x2(x):
    return tf.space_to_depth(x, block_size=2)

# %%
# Define the model
input = Input(shape=(32, 32, 3))
layer1 = SeparableConv2D(32, 5, 5, border_mode='same', kernel_regularizer=l2(1e-4))(input) #32,32
layer1 = BatchNormalization()(layer1)
layer1 = Activation('relu')(layer1)
skip_connection1 = layer1 #32,32

#layer2 = Dropout(0.125)(layer1)
layer2 = BatchNormalization()(layer1)
layer2 = Convolution2D(64, 5, 5, border_mode='same', kernel_regularizer=l2(1e-4))(layer2) #32,32
layer2 = Activation('relu')(layer2)
skip_connection2 = layer2

layer3 = BatchNormalization()(layer2)
layer3 = Convolution2D(128, 5, 5, border_mode='same', kernel_regularizer=l2(1e-4))(layer3) #32,32
layer3 = Activation('relu')(layer3)
skip_connection3 = layer3

# Group convolution of layer1 and layer3 to layer4 
groupConv1 = concatenate([skip_connection1, layer3]) #32,32

layer4 = BatchNormalization()(groupConv1)
layer4 = SeparableConv2D(256, 5, 5, border_mode='same', kernel_regularizer=l2(1e-4))(layer4) #32,32
layer4 = Activation('relu')(layer4)
skip_connection4 = layer4

# Group convolution of layer1 and layer4 to layer5
groupConv2 = concatenate([skip_connection1, layer4]) #16,16

# Using 1x1 to reduce channels
layer5 = BatchNormalization()(groupConv2)
layer5 = Convolution2D(32, 1, 1, kernel_regularizer=l2(1e-4))(layer5) #32,32
layer5 = Activation('relu')(layer5)
layer5 = MaxPooling2D(pool_size=(2, 2))(layer5) #16,16

#layer6 = Dropout(0.125)(layer5)
layer6 = BatchNormalization()(layer5)
layer6 = SeparableConv2D(32, 3, 3, border_mode='same', kernel_regularizer=l2(1e-4))(layer6) #16,16
layer6 = Activation('relu')(layer6)
skip_connection6 = layer6 #16,16

# Group convolution of layer1, layer4 and layer6 to layer7
layer1_layer4 = concatenate([skip_connection1, skip_connection4]) #32,32
layer1_layer4 = Lambda(space_to_depth_x2)(layer1_layer4) #16,16
groupConv3 = concatenate([layer1_layer4, layer6]) #16,16

#layer7 = Dropout(0.125)(groupConv3)
layer7 = BatchNormalization()(groupConv3)
layer7 = Convolution2D(64, 5, 5, border_mode='same', kernel_regularizer=l2(1e-4))(layer7) #16,16
layer7 = Activation('relu')(layer7)
skip_connection7 = layer7 #16,16

# Group convolution of layer3, layer4, layer6 and layer7 to layer8
layer3_layer4 = concatenate([skip_connection3, skip_connection4]) #32,32
layer3_layer4 = Lambda(space_to_depth_x2)(layer3_layer4) #16,16
groupConv4 = concatenate([layer3_layer4, layer6, layer7]) #16,16

layer8 = BatchNormalization()(groupConv4)
layer8 = SeparableConv2D(128, 3, 3, border_mode='same', kernel_regularizer=l2(1e-4))(layer8) #16,16
layer8 = Activation('relu')(layer8)
skip_connection8 = layer8 #16,16

# Group convolution of layer1, layer3, layer4, layer6, layer7 and layer8 to layer9
layer1_layer3_layer4 = concatenate([skip_connection1, skip_connection3, skip_connection4]) #32,32
layer1_layer3_layer4 = Lambda(space_to_depth_x2)(layer1_layer3_layer4) #16,16
groupConv5 = concatenate([layer1_layer3_layer4, layer6, layer7, layer8]) #16,16

layer9 = BatchNormalization()(groupConv5)
layer9 = SeparableConv2D(256, 5, 5, border_mode='same', kernel_regularizer=l2(1e-4))(layer9) #16,16
layer9 = Activation('relu')(layer9)

# Group convolution of layer1, layer4, layer6, layer8 and layer9 to layer10
layer1_layer4 = concatenate([skip_connection1, skip_connection4]) #32,32
layer1_layer4 = Lambda(space_to_depth_x2)(layer1_layer4) #16,16
groupConv6 = concatenate([layer1_layer4, layer6, layer8, layer9]) #16,16

# Using 1x1 to reduce channels
layer10 = BatchNormalization()(groupConv6)
layer10 = Convolution2D(32, 1, 1, kernel_regularizer=l2(1e-4))(layer10) #16,16; 16
layer10 = Activation('relu')(layer10)
layer10 = MaxPooling2D(pool_size=(2, 2))(layer10) #8,8

# Group convolution of layer7 and layer10 to layer11
skip_connection_temp7 = Lambda(space_to_depth_x2)(skip_connection7)
groupConv7 = concatenate([skip_connection_temp7, layer10]) #8,8

#layer11 = Dropout(0.125)(groupConv7)
layer11 = BatchNormalization()(groupConv7)
layer11 = Convolution2D(32, 5, 5, border_mode='same', kernel_regularizer=l2(1e-4))(layer11) #8,8
layer11 = Activation('relu')(layer11)
skip_connection11 = layer11 #8,8

# Group convolution of layer2, layer4, layer8 and layer11 to layer12
layer2_layer4 = concatenate([skip_connection2, skip_connection4]) #32,32
layer2_layer4 = Lambda(space_to_depth_x2)(layer2_layer4) #16,16
layer2_layer4_layer8 = concatenate([layer2_layer4, layer8]) #16,16
layer2_layer4_layer8 = Lambda(space_to_depth_x2)(layer2_layer4_layer8) #8,8
groupConv7 = concatenate([layer2_layer4_layer8, layer11]) #8,8

layer12 = BatchNormalization()(groupConv7)
layer12 = SeparableConv2D(64, 5, 5, border_mode='same', kernel_regularizer=l2(1e-4))(layer12) #8,8
layer12 = Activation('relu')(layer12)
skip_connection12 = layer12 #8,8

# Group convolution of layer2, layer3, layer6, layer11 and layer12 to layer13
layer2_layer3 = concatenate([skip_connection2, skip_connection3]) #32,32
layer2_layer3 = Lambda(space_to_depth_x2)(layer2_layer3) #16,16
layer2_layer3_layer6 = concatenate([layer2_layer3, layer6]) #16,16
layer2_layer3_layer6 = Lambda(space_to_depth_x2)(layer2_layer3_layer6) #8,8
groupConv8 = concatenate([layer2_layer3_layer6, layer11, layer12]) #8,8

layer13 = BatchNormalization()(groupConv8)
layer13 = Convolution2D(128, 3, 3, border_mode='same', kernel_regularizer=l2(1e-4))(layer13) #8,8
layer13 = Activation('relu')(layer13)

# Group convolution of layer1, layer3, layer4, layer6, layer8, layer12 and layer13 to layer14
layer1_layer3_layer4 = concatenate([skip_connection1, skip_connection3, skip_connection4]) #32,32
layer1_layer3_layer4 = Lambda(space_to_depth_x2)(layer1_layer3_layer4) #16,16
layer1_layer3_layer4_layer6_layer8 = concatenate([layer1_layer3_layer4, layer6, layer8]) #16,16
layer1_layer3_layer4_layer6_layer8 = Lambda(space_to_depth_x2)(layer1_layer3_layer4_layer6_layer8) #8,8
groupConv9 = concatenate([layer1_layer3_layer4_layer6_layer8, layer12, layer13]) #16,16

layer14 = BatchNormalization()(groupConv9)
layer14 = SeparableConv2D(256, 5, 5, border_mode='same', kernel_regularizer=l2(1e-4))(layer14) #8,8
layer14 = Activation('relu')(layer14)

# Group convolution of layer4, layer8, layer12 and layer14 to softmax
skip_connection_temp1 = Lambda(space_to_depth_x2)(skip_connection1) #16,16
layer4_layer8 = concatenate([skip_connection_temp1, layer8]) #16,16
layer4_layer8 = Lambda(space_to_depth_x2)(layer4_layer8) #8,8
groupConv10 = concatenate([layer4_layer8, layer12, layer14]) #8,8

#layer15 = BatchNormalization()(groupConv10)
layer15 = Convolution2D(10, 1, 1)(groupConv10) #8,8
#layer15 = Activation('relu')(layer15)
layer15 = Convolution2D(10, 8, 8)(layer15) #1,1

output = Flatten()(layer15)
output = Activation('softmax')(output)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0623 13:08:09.076530 140719482541952 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0623 13:08:09.128336 140719482541952 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(32, (5, 5), kernel_regularizer=<keras.reg..., padding="same")`
#
# W0623 13:08:09.142854 140719482541952 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0623 13:08:09.197446 140719482541952 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0623 13:08:09.198622 140719482541952 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0623 13:08:12.287898 140719482541952 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (5, 5), kernel_regularizer=<keras.reg..., padding="same")`
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (5, 5), kernel_regularizer=<keras.reg..., padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(256, (5, 5), kernel_regularizer=<keras.reg..., padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:31: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1), kernel_regularizer=<keras.reg...)`
# W0623 13:08:12.808194 140719482541952 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:37: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(32, (3, 3), kernel_regularizer=<keras.reg..., padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:48: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (5, 5), kernel_regularizer=<keras.reg..., padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:58: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(128, (3, 3), kernel_regularizer=<keras.reg..., padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:68: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(256, (5, 5), kernel_regularizer=<keras.reg..., padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:78: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1), kernel_regularizer=<keras.reg...)`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:88: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (5, 5), kernel_regularizer=<keras.reg..., padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:100: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(64, (5, 5), kernel_regularizer=<keras.reg..., padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:112: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), kernel_regularizer=<keras.reg..., padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:123: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(256, (5, 5), kernel_regularizer=<keras.reg..., padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:133: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (1, 1))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:135: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (8, 8))`

# %%
model = Model(inputs=[input], outputs=[output])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# separable_conv2d_1 (SeparableCo (None, 32, 32, 32)   203         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 32)   128         separable_conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 32)   128         activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 64)   51264       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 64)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 64)   256         activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 128)  204928      batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 128)  0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 160)  0           activation_1[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 160)  640         concatenate_1[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_2 (SeparableCo (None, 32, 32, 256)  45216       batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 256)  0           separable_conv2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 288)  0           activation_1[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 288)  1152        concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 32)   9248        batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 32)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 32)   0           activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 32)   128         max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_3 (SeparableCo (None, 16, 16, 32)   1344        batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 32, 32, 288)  0           activation_1[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 16, 16, 32)   0           separable_conv2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 16, 16, 1152) 0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 16, 16, 1184) 0           lambda_1[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 1184) 4736        concatenate_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 32, 32, 384)  0           activation_3[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 16, 16, 64)   1894464     batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 16, 16, 1536) 0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 64)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 16, 16, 1632) 0           lambda_2[0][0]
#                                                                  activation_6[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 1632) 6528        concatenate_6[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_4 (SeparableCo (None, 16, 16, 128)  223712      batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 32, 32, 416)  0           activation_1[0][0]
#                                                                  activation_3[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 128)  0           separable_conv2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 16, 16, 1664) 0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 16, 16, 1888) 0           lambda_3[0][0]
#                                                                  activation_6[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 1888) 7552        concatenate_8[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 32, 32, 288)  0           activation_1[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_5 (SeparableCo (None, 16, 16, 256)  530784      batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 16, 16, 1152) 0           concatenate_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 256)  0           separable_conv2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 16, 16, 1568) 0           lambda_4[0][0]
#                                                                  activation_6[0][0]
#                                                                  activation_8[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 1568) 6272        concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 32)   50208       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 32)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 8, 8, 256)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 32)     0           activation_10[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 32, 32, 320)  0           activation_2[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 8, 8, 288)    0           lambda_5[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 16, 16, 1280) 0           concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 8, 8, 288)    1152        concatenate_11[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 16, 16, 1408) 0           lambda_6[0][0]
#                                                                  activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 8, 8, 32)     230432      batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 8, 8, 5632)   0           concatenate_13[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 8, 8, 32)     0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 8, 8, 5664)   0           lambda_7[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 32, 32, 192)  0           activation_2[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 8, 8, 5664)   22656       concatenate_14[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 16, 16, 768)  0           concatenate_15[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_6 (SeparableCo (None, 8, 8, 64)     504160      batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 16, 16, 800)  0           lambda_8[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 8, 8, 64)     0           separable_conv2d_6[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 8, 8, 3200)   0           concatenate_16[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 32, 32, 416)  0           activation_1[0][0]
#                                                                  activation_3[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 8, 8, 3296)   0           lambda_9[0][0]
#                                                                  activation_11[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 16, 16, 1664) 0           concatenate_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 8, 8, 3296)   13184       concatenate_17[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 16, 16, 1824) 0           lambda_10[0][0]
#                                                                  activation_6[0][0]
#                                                                  activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 8, 128)    3797120     batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 8, 8, 7296)   0           concatenate_19[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 8, 8, 128)    0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 8, 8, 7488)   0           lambda_11[0][0]
#                                                                  activation_12[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 16, 16, 128)  0           activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 8, 8, 7488)   29952       concatenate_20[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 16, 16, 256)  0           lambda_12[0][0]
#                                                                  activation_8[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_7 (SeparableCo (None, 8, 8, 256)    2104384     batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 8, 8, 1024)   0           concatenate_21[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 8, 8, 256)    0           separable_conv2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 8, 8, 1344)   0           lambda_13[0][0]
#                                                                  activation_12[0][0]
#                                                                  activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 8, 8, 10)     13450       concatenate_22[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 1, 1, 10)     6410        conv2d_8[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 10)           0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 10)           0           flatten_1[0][0]
# ==================================================================================================
# Total params: 9,761,791
# Trainable params: 9,714,559
# Non-trainable params: 47,232
# __________________________________________________________________________________________________

# %%
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from keras.utils import plot_model
plot_model(model, show_shapes=True, show_layer_names=True, to_file='model_structure.png')

from IPython.display import Image
Image(retina=True, filename='model_structure.png')

# %%
# Mounting the Google Drive to save the weights
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# Specifying the path to store the weights
filepath="/content/gdrive/My Drive/Assignment7B:{epoch:03d}-val-acc:{val_acc:.3f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, save_weights_only=True, mode='max')

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False)


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 100, 
                                 validation_data = (test_features, test_labels), verbose=1,
                                 callbacks=[checkpoint])
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
#plot_model_history(model_info)
# compute test accuracy
#print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, callbacks=[<keras.ca..., steps_per_epoch=390, epochs=100)`
#   del sys.path[0]
# W0623 13:18:33.146205 140719482541952 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/100
# 390/390 [==============================] - 221s 566ms/step - loss: 1.3602 - acc: 0.5203 - val_loss: 1.1409 - val_acc: 0.6003
#
# Epoch 00001: val_acc improved from -inf to 0.60030, saving model to /content/gdrive/My Drive/Assignment7B:001-val-acc:0.600.hdf5
# Epoch 2/100
# 390/390 [==============================] - 217s 555ms/step - loss: 0.9073 - acc: 0.6892 - val_loss: 1.0667 - val_acc: 0.6478
#
# Epoch 00002: val_acc improved from 0.60030 to 0.64780, saving model to /content/gdrive/My Drive/Assignment7B:002-val-acc:0.648.hdf5
# Epoch 3/100
# 390/390 [==============================] - 214s 550ms/step - loss: 0.6661 - acc: 0.7761 - val_loss: 0.9237 - val_acc: 0.7066
#
# Epoch 00003: val_acc improved from 0.64780 to 0.70660, saving model to /content/gdrive/My Drive/Assignment7B:003-val-acc:0.707.hdf5
# Epoch 4/100
# 390/390 [==============================] - 214s 550ms/step - loss: 0.4573 - acc: 0.8538 - val_loss: 0.8347 - val_acc: 0.7509
#
# Epoch 00004: val_acc improved from 0.70660 to 0.75090, saving model to /content/gdrive/My Drive/Assignment7B:004-val-acc:0.751.hdf5
# Epoch 5/100
# 390/390 [==============================] - 214s 549ms/step - loss: 0.2739 - acc: 0.9189 - val_loss: 1.1977 - val_acc: 0.7082
#
# Epoch 00005: val_acc did not improve from 0.75090
# Epoch 6/100
# 390/390 [==============================] - 214s 549ms/step - loss: 0.1689 - acc: 0.9560 - val_loss: 1.1231 - val_acc: 0.7318
#
# Epoch 00006: val_acc did not improve from 0.75090
# Epoch 7/100
# 390/390 [==============================] - 214s 549ms/step - loss: 0.1436 - acc: 0.9649 - val_loss: 1.3277 - val_acc: 0.7181
#
# Epoch 00007: val_acc did not improve from 0.75090
# Epoch 8/100
# 390/390 [==============================] - 214s 549ms/step - loss: 0.1612 - acc: 0.9601 - val_loss: 1.3667 - val_acc: 0.7235
#
# Epoch 00008: val_acc did not improve from 0.75090
# Epoch 9/100
# 390/390 [==============================] - 214s 548ms/step - loss: 0.1387 - acc: 0.9698 - val_loss: 1.4406 - val_acc: 0.7341
#
# Epoch 00009: val_acc did not improve from 0.75090
# Epoch 10/100
# 390/390 [==============================] - 214s 548ms/step - loss: 0.1436 - acc: 0.9695 - val_loss: 1.6084 - val_acc: 0.7166
#
# Epoch 00010: val_acc did not improve from 0.75090
# Epoch 11/100
# 390/390 [==============================] - 214s 548ms/step - loss: 0.1428 - acc: 0.9715 - val_loss: 1.5818 - val_acc: 0.7325
#
# Epoch 00011: val_acc did not improve from 0.75090
# Epoch 12/100
# 390/390 [==============================] - 214s 548ms/step - loss: 0.1503 - acc: 0.9697 - val_loss: 1.8025 - val_acc: 0.7368
#
# Epoch 00012: val_acc did not improve from 0.75090
# Epoch 13/100
# 390/390 [==============================] - 214s 548ms/step - loss: 0.1322 - acc: 0.9759 - val_loss: 3.4936 - val_acc: 0.5423
#
# Epoch 00013: val_acc did not improve from 0.75090
# Epoch 14/100
# 390/390 [==============================] - 214s 548ms/step - loss: 0.1427 - acc: 0.9742 - val_loss: 1.6463 - val_acc: 0.7360
#
# Epoch 00014: val_acc did not improve from 0.75090
# Epoch 15/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.1213 - acc: 0.9798 - val_loss: 1.9221 - val_acc: 0.7366
#
# Epoch 00015: val_acc did not improve from 0.75090
# Epoch 16/100
# 390/390 [==============================] - 213s 547ms/step - loss: 0.1263 - acc: 0.9786 - val_loss: 1.7273 - val_acc: 0.7305
#
# Epoch 00016: val_acc did not improve from 0.75090
# Epoch 17/100
# 390/390 [==============================] - 213s 547ms/step - loss: 0.1429 - acc: 0.9750 - val_loss: 2.1115 - val_acc: 0.7229
#
# Epoch 00017: val_acc did not improve from 0.75090
# Epoch 18/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.1337 - acc: 0.9780 - val_loss: 1.9964 - val_acc: 0.7360
#
# Epoch 00018: val_acc did not improve from 0.75090
# Epoch 19/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.1413 - acc: 0.9769 - val_loss: 1.8815 - val_acc: 0.7371
#
# Epoch 00019: val_acc did not improve from 0.75090
# Epoch 20/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.1167 - acc: 0.9835 - val_loss: 2.0277 - val_acc: 0.7428
#
# Epoch 00020: val_acc did not improve from 0.75090
# Epoch 21/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.1223 - acc: 0.9822 - val_loss: 2.1390 - val_acc: 0.7152
#
# Epoch 00021: val_acc did not improve from 0.75090
# Epoch 22/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.1506 - acc: 0.9757 - val_loss: 2.0811 - val_acc: 0.7300
#
# Epoch 00022: val_acc did not improve from 0.75090
# Epoch 23/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.1313 - acc: 0.9802 - val_loss: 2.1658 - val_acc: 0.7277
#
# Epoch 00023: val_acc did not improve from 0.75090
# Epoch 24/100
# 390/390 [==============================] - 213s 545ms/step - loss: 0.1262 - acc: 0.9823 - val_loss: 2.3265 - val_acc: 0.7284
#
# Epoch 00024: val_acc did not improve from 0.75090
# Epoch 25/100
# 390/390 [==============================] - 213s 545ms/step - loss: 0.1292 - acc: 0.9823 - val_loss: 2.3371 - val_acc: 0.7236
#
# Epoch 00025: val_acc did not improve from 0.75090
# Epoch 26/100
# 390/390 [==============================] - 213s 545ms/step - loss: 0.1338 - acc: 0.9812 - val_loss: 2.3893 - val_acc: 0.7214
#
# Epoch 00026: val_acc did not improve from 0.75090
# Epoch 27/100
# 390/390 [==============================] - 213s 545ms/step - loss: 0.1476 - acc: 0.9784 - val_loss: 2.3031 - val_acc: 0.6993
#
# Epoch 00027: val_acc did not improve from 0.75090
# Epoch 28/100
# 390/390 [==============================] - 213s 545ms/step - loss: 0.1347 - acc: 0.9824 - val_loss: 2.4688 - val_acc: 0.7147
#
# Epoch 00028: val_acc did not improve from 0.75090
# Epoch 29/100
# 390/390 [==============================] - 213s 545ms/step - loss: 0.1142 - acc: 0.9862 - val_loss: 2.3576 - val_acc: 0.7386
#
# Epoch 00029: val_acc did not improve from 0.75090
# Epoch 30/100
# 390/390 [==============================] - 213s 545ms/step - loss: 0.1328 - acc: 0.9821 - val_loss: 2.7139 - val_acc: 0.7103
#
# Epoch 00030: val_acc did not improve from 0.75090
# Epoch 31/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.1432 - acc: 0.9800 - val_loss: 2.5086 - val_acc: 0.7262
#
# Epoch 00031: val_acc did not improve from 0.75090
# Epoch 32/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.1286 - acc: 0.9850 - val_loss: 2.5344 - val_acc: 0.7315
#
# Epoch 00032: val_acc did not improve from 0.75090
# Epoch 33/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.1346 - acc: 0.9828 - val_loss: 2.4227 - val_acc: 0.7223
#
# Epoch 00033: val_acc did not improve from 0.75090
# Epoch 34/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.1324 - acc: 0.9833 - val_loss: 2.5232 - val_acc: 0.7314
#
# Epoch 00034: val_acc did not improve from 0.75090
# Epoch 35/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.1385 - acc: 0.9822 - val_loss: 2.6737 - val_acc: 0.7226
#
# Epoch 00035: val_acc did not improve from 0.75090
# Epoch 36/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.1333 - acc: 0.9838 - val_loss: 2.5124 - val_acc: 0.7320
#
# Epoch 00036: val_acc did not improve from 0.75090
# Epoch 37/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.1299 - acc: 0.9847 - val_loss: 2.7037 - val_acc: 0.7264
#
# Epoch 00037: val_acc did not improve from 0.75090
# Epoch 38/100
# 390/390 [==============================] - 213s 547ms/step - loss: 0.1400 - acc: 0.9834 - val_loss: 2.7833 - val_acc: 0.7131
#
# Epoch 00038: val_acc did not improve from 0.75090
# Epoch 39/100
# 390/390 [==============================] - 213s 547ms/step - loss: 0.1397 - acc: 0.9835 - val_loss: 2.5934 - val_acc: 0.7344
#
# Epoch 00039: val_acc did not improve from 0.75090
# Epoch 40/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.1303 - acc: 0.9856 - val_loss: 2.5433 - val_acc: 0.7375
#
# Epoch 00040: val_acc did not improve from 0.75090
# Epoch 41/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.1256 - acc: 0.9864 - val_loss: 2.6829 - val_acc: 0.7349
#
# Epoch 00041: val_acc did not improve from 0.75090
# Epoch 42/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.1366 - acc: 0.9846 - val_loss: 2.7196 - val_acc: 0.7342
#
# Epoch 00042: val_acc did not improve from 0.75090
# Epoch 43/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.1320 - acc: 0.9864 - val_loss: 2.7211 - val_acc: 0.7445
#
# Epoch 00043: val_acc did not improve from 0.75090
# Epoch 44/100
# 390/390 [==============================] - 213s 545ms/step - loss: 0.1494 - acc: 0.9832 - val_loss: 2.7845 - val_acc: 0.7368
#
# Epoch 00044: val_acc did not improve from 0.75090
# Epoch 45/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.1398 - acc: 0.9849 - val_loss: 2.7793 - val_acc: 0.7367
#
# Epoch 00045: val_acc did not improve from 0.75090
# Epoch 46/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.1407 - acc: 0.9850 - val_loss: 2.7336 - val_acc: 0.7418
#
# Epoch 00046: val_acc did not improve from 0.75090
# Epoch 47/100
# 390/390 [==============================] - 213s 545ms/step - loss: 0.1254 - acc: 0.9878 - val_loss: 2.7698 - val_acc: 0.7412
#
# Epoch 00047: val_acc did not improve from 0.75090
# Epoch 48/100
# 390/390 [==============================] - 213s 545ms/step - loss: 0.1379 - acc: 0.9850 - val_loss: 3.0951 - val_acc: 0.7049
#
# Epoch 00048: val_acc did not improve from 0.75090
# Epoch 49/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.1433 - acc: 0.9854 - val_loss: 2.8485 - val_acc: 0.7434
#
# Epoch 00049: val_acc did not improve from 0.75090
# Epoch 50/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.1637 - acc: 0.9827 - val_loss: 3.0013 - val_acc: 0.7278
#
# Epoch 00050: val_acc did not improve from 0.75090
# Epoch 51/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.1417 - acc: 0.9859 - val_loss: 2.9152 - val_acc: 0.7363
#
# Epoch 00051: val_acc did not improve from 0.75090
# Epoch 52/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.1398 - acc: 0.9868 - val_loss: 2.8993 - val_acc: 0.7356
#
# Epoch 00052: val_acc did not improve from 0.75090
# Epoch 53/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.1338 - acc: 0.9882 - val_loss: 2.8735 - val_acc: 0.7445
#
# Epoch 00053: val_acc did not improve from 0.75090
# Epoch 54/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.1382 - acc: 0.9873 - val_loss: 3.0772 - val_acc: 0.7319
#
# Epoch 00054: val_acc did not improve from 0.75090
# Epoch 55/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.1647 - acc: 0.9838 - val_loss: 3.2609 - val_acc: 0.7220
#
# Epoch 00055: val_acc did not improve from 0.75090
# Epoch 56/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.1447 - acc: 0.9868 - val_loss: 3.1855 - val_acc: 0.7285
#
# Epoch 00056: val_acc did not improve from 0.75090
# Epoch 57/100
# 390/390 [==============================] - 213s 545ms/step - loss: 0.1517 - acc: 0.9865 - val_loss: 3.0612 - val_acc: 0.7432
#
# Epoch 00057: val_acc did not improve from 0.75090
# Epoch 58/100
# 390/390 [==============================] - 212s 545ms/step - loss: 0.1569 - acc: 0.9860 - val_loss: 3.1243 - val_acc: 0.7448
#
# Epoch 00058: val_acc did not improve from 0.75090
# Epoch 59/100
# 390/390 [==============================] - 213s 545ms/step - loss: 0.1465 - acc: 0.9878 - val_loss: 2.8794 - val_acc: 0.7499
#
# Epoch 00059: val_acc did not improve from 0.75090
# Epoch 60/100
# 390/390 [==============================] - 212s 544ms/step - loss: 0.1547 - acc: 0.9868 - val_loss: 3.3458 - val_acc: 0.7097
#
# Epoch 00060: val_acc did not improve from 0.75090
# Epoch 61/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.1714 - acc: 0.9845 - val_loss: 3.0940 - val_acc: 0.7370
#
# Epoch 00061: val_acc did not improve from 0.75090
# Epoch 62/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.1557 - acc: 0.9872 - val_loss: 3.3568 - val_acc: 0.7232
#
# Epoch 00062: val_acc did not improve from 0.75090
# Epoch 63/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.1559 - acc: 0.9875 - val_loss: 3.0901 - val_acc: 0.7461
#
# Epoch 00063: val_acc did not improve from 0.75090
# Epoch 64/100
# 390/390 [==============================] - 212s 545ms/step - loss: 0.1672 - acc: 0.9860 - val_loss: 3.2535 - val_acc: 0.7433
#
# Epoch 00064: val_acc did not improve from 0.75090
# Epoch 65/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.1777 - acc: 0.9855 - val_loss: 3.4558 - val_acc: 0.7269
#
# Epoch 00065: val_acc did not improve from 0.75090
# Epoch 66/100
# 390/390 [==============================] - 213s 545ms/step - loss: 0.1510 - acc: 0.9890 - val_loss: 3.2284 - val_acc: 0.7389
#
# Epoch 00066: val_acc did not improve from 0.75090
# Epoch 67/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.1714 - acc: 0.9865 - val_loss: 3.4769 - val_acc: 0.7296
#
# Epoch 00067: val_acc did not improve from 0.75090
# Epoch 68/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.1800 - acc: 0.9853 - val_loss: 3.6647 - val_acc: 0.7235
#
# Epoch 00068: val_acc did not improve from 0.75090
# Epoch 69/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.1596 - acc: 0.9880 - val_loss: 3.4052 - val_acc: 0.7345
#
# Epoch 00069: val_acc did not improve from 0.75090
# Epoch 70/100
# 390/390 [==============================] - 213s 545ms/step - loss: 0.1646 - acc: 0.9882 - val_loss: 3.3322 - val_acc: 0.7425
#
# Epoch 00070: val_acc did not improve from 0.75090
# Epoch 71/100
# 390/390 [==============================] - 212s 545ms/step - loss: 0.1602 - acc: 0.9891 - val_loss: 3.3713 - val_acc: 0.7423
#
# Epoch 00071: val_acc did not improve from 0.75090
# Epoch 72/100
# 390/390 [==============================] - 212s 545ms/step - loss: 0.1810 - acc: 0.9864 - val_loss: 3.4248 - val_acc: 0.7439
#
# Epoch 00072: val_acc did not improve from 0.75090
# Epoch 73/100
# 390/390 [==============================] - 213s 545ms/step - loss: 0.1914 - acc: 0.9857 - val_loss: 3.5898 - val_acc: 0.7289
#
# Epoch 00073: val_acc did not improve from 0.75090
# Epoch 74/100
# 390/390 [==============================] - 213s 547ms/step - loss: 0.1750 - acc: 0.9877 - val_loss: 3.4335 - val_acc: 0.7441
#
# Epoch 00074: val_acc did not improve from 0.75090
# Epoch 75/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.1872 - acc: 0.9872 - val_loss: 3.3913 - val_acc: 0.7474
#
# Epoch 00075: val_acc did not improve from 0.75090
# Epoch 76/100
# 390/390 [==============================] - 213s 547ms/step - loss: 0.1972 - acc: 0.9861 - val_loss: 3.4754 - val_acc: 0.7420
#
# Epoch 00076: val_acc did not improve from 0.75090
# Epoch 77/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.1896 - acc: 0.9868 - val_loss: 3.5025 - val_acc: 0.7423
#
# Epoch 00077: val_acc did not improve from 0.75090
# Epoch 78/100
# 390/390 [==============================] - 212s 545ms/step - loss: 0.1856 - acc: 0.9876 - val_loss: 3.4687 - val_acc: 0.7463
#
# Epoch 00078: val_acc did not improve from 0.75090
# Epoch 79/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.1836 - acc: 0.9880 - val_loss: 3.5091 - val_acc: 0.7367
#
# Epoch 00079: val_acc did not improve from 0.75090
# Epoch 80/100
# 390/390 [==============================] - 213s 547ms/step - loss: 0.1852 - acc: 0.9879 - val_loss: 3.9621 - val_acc: 0.7065
#
# Epoch 00080: val_acc did not improve from 0.75090
# Epoch 81/100
# 390/390 [==============================] - 213s 547ms/step - loss: 0.2095 - acc: 0.9863 - val_loss: 3.5811 - val_acc: 0.7414
#
# Epoch 00081: val_acc did not improve from 0.75090
# Epoch 82/100
# 390/390 [==============================] - 214s 548ms/step - loss: 0.2276 - acc: 0.9848 - val_loss: 3.5146 - val_acc: 0.7462
#
# Epoch 00082: val_acc did not improve from 0.75090
# Epoch 83/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.2103 - acc: 0.9869 - val_loss: 3.7699 - val_acc: 0.7329
#
# Epoch 00083: val_acc did not improve from 0.75090
# Epoch 84/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.2163 - acc: 0.9865 - val_loss: 4.1410 - val_acc: 0.7080
#
# Epoch 00084: val_acc did not improve from 0.75090
# Epoch 85/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.2459 - acc: 0.9841 - val_loss: 3.5901 - val_acc: 0.7459
#
# Epoch 00085: val_acc did not improve from 0.75090
# Epoch 86/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.2278 - acc: 0.9855 - val_loss: 3.6569 - val_acc: 0.7423
#
# Epoch 00086: val_acc did not improve from 0.75090
# Epoch 87/100
# 390/390 [==============================] - 213s 547ms/step - loss: 0.2007 - acc: 0.9891 - val_loss: 3.7972 - val_acc: 0.7362
#
# Epoch 00087: val_acc did not improve from 0.75090
# Epoch 88/100
# 390/390 [==============================] - 213s 547ms/step - loss: 0.2096 - acc: 0.9881 - val_loss: 3.7396 - val_acc: 0.7414
#
# Epoch 00088: val_acc did not improve from 0.75090
# Epoch 89/100
# 390/390 [==============================] - 212s 544ms/step - loss: 0.2286 - acc: 0.9867 - val_loss: 3.8295 - val_acc: 0.7324
#
# Epoch 00089: val_acc did not improve from 0.75090
# Epoch 90/100
# 390/390 [==============================] - 212s 544ms/step - loss: 0.2262 - acc: 0.9871 - val_loss: 4.0169 - val_acc: 0.7298
#
# Epoch 00090: val_acc did not improve from 0.75090
# Epoch 91/100
# 390/390 [==============================] - 212s 544ms/step - loss: 0.2688 - acc: 0.9840 - val_loss: 3.9455 - val_acc: 0.7288
#
# Epoch 00091: val_acc did not improve from 0.75090
# Epoch 92/100
# 390/390 [==============================] - 213s 546ms/step - loss: 0.2699 - acc: 0.9842 - val_loss: 3.7468 - val_acc: 0.7479
#
# Epoch 00092: val_acc did not improve from 0.75090
# Epoch 93/100
# 390/390 [==============================] - 213s 547ms/step - loss: 0.2679 - acc: 0.9846 - val_loss: 3.7763 - val_acc: 0.7444
#
# Epoch 00093: val_acc did not improve from 0.75090
# Epoch 94/100
# 390/390 [==============================] - 214s 548ms/step - loss: 0.2682 - acc: 0.9850 - val_loss: 3.8129 - val_acc: 0.7439
#
# Epoch 00094: val_acc did not improve from 0.75090
# Epoch 95/100
# 390/390 [==============================] - 213s 547ms/step - loss: 0.2805 - acc: 0.9837 - val_loss: 3.9280 - val_acc: 0.7356
#
# Epoch 00095: val_acc did not improve from 0.75090
# Epoch 96/100
# 390/390 [==============================] - 212s 545ms/step - loss: 0.2760 - acc: 0.9849 - val_loss: 3.9602 - val_acc: 0.7380
#
# Epoch 00096: val_acc did not improve from 0.75090
# Epoch 97/100
# 390/390 [==============================] - 212s 543ms/step - loss: 0.2706 - acc: 0.9856 - val_loss: 3.6550 - val_acc: 0.7526
#
# Epoch 00097: val_acc improved from 0.75090 to 0.75260, saving model to /content/gdrive/My Drive/Assignment7B:097-val-acc:0.753.hdf5
# Epoch 98/100
# 390/390 [==============================] - 212s 543ms/step - loss: 0.2874 - acc: 0.9841 - val_loss: 3.9511 - val_acc: 0.7355
#
# Epoch 00098: val_acc did not improve from 0.75260
# Epoch 99/100
# 390/390 [==============================] - 212s 543ms/step - loss: 0.3028 - acc: 0.9832 - val_loss: 3.9542 - val_acc: 0.7419
#
# Epoch 00099: val_acc did not improve from 0.75260
# Epoch 100/100
# 390/390 [==============================] - 212s 543ms/step - loss: 0.2726 - acc: 0.9858 - val_loss: 4.0122 - val_acc: 0.7363
#
# Epoch 00100: val_acc did not improve from 0.75260
# Model took 21313.25 seconds to train

# %%
from keras.models import load_model
model = load_model('/content/gdrive/My Drive/Assignment7B:047-val-acc:0.746.hdf5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-1e0428385f6e> in <module>()
#       1 from keras.models import load_model
# ----> 2 model = load_model('/content/gdrive/My Drive/Assignment7B:047-val-acc:0.746.hdf5')
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in load_model(filepath, custom_objects, compile)
#     417     f = h5dict(filepath, 'r')
#     418     try:
# --> 419         model = _deserialize_model(f, custom_objects, compile)
#     420     finally:
#     421         if opened_new_file:
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in _deserialize_model(f, custom_objects, compile)
#     219         return obj
#     220
# --> 221     model_config = f['model_config']
#     222     if model_config is None:
#     223         raise ValueError('No model found in config.')
#
# /usr/local/lib/python3.6/dist-packages/keras/utils/io_utils.py in __getitem__(self, attr)
#     300             else:
#     301                 if self.read_only:
# --> 302                     raise ValueError('Cannot create group in read only mode.')
#     303                 val = H5Dict(self.data.create_group(attr))
#     304         return val
#
# ValueError: Cannot create group in read only mode.
