# %%
from keras import backend as K
import time
import matplotlib.pyplot as plt

# Importing NumPy (Numerical Python) which is a library consisting of multidimensional array objects and a collection of routines for processing those arrays. It also gives an alias to the library.
import numpy as np

% matplotlib inline
np.random.seed(2017) 

# There are two main types of models available in Keras: the Sequential model and the Model class used with the functional API.
# Sequential model is a linear stack of layers. Importing Sequential model from Keras.
from keras.models import Sequential, Model

# Importing different layers from Keras.
from keras.layers.convolutional import Convolution2D, MaxPooling2D, SeparableConv2D
from keras.layers import Activation, Flatten, Dense, Dropout, Input, Lambda, Concatenate
from keras.layers.normalization import BatchNormalization

# Importing the utils library of Keras.
from keras.utils import np_utils

# Importing the concatenate library of Keras
from keras.layers.merge import concatenate

import tensorflow as tf

# Importing the callbacks of Keras.
from keras.callbacks import ModelCheckpoint

# %%
# CIFAR10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images. Importing CIFAR10 dataset from Keras.
from keras.datasets import cifar10

# Loading the CIFAR10 60000 Training and 10000 Test data into respective numpy arrays
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()

# Setting the count, number of channels, rows and columns of training images
num_train, img_channels, img_rows, img_cols =  train_features.shape

# Setting the count of test images
num_test, _, _, _ =  test_features.shape

# Setting number of classes (10)
num_classes = len(np.unique(train_labels))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 26s 0us/step

# %%
# Setting up the class names
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']

# Plotting an image from each of the 10 classes
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %%
# Custom function to test accuracy
def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %%
# Pixel normalization for training images
train_features = train_features.astype('float32')/255

# Pixel normalization for test images
test_features = test_features.astype('float32')/255

# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %%
# Space_to_depth funcction of Tensorflow rearranges blocks of spatial data into depth. 
def space_to_depth_x2(x):
    return tf.space_to_depth(x, block_size=2)

# %%
# Define the model
input = Input(shape=(32, 32, 3))
block1 = Convolution2D(32, 3, 3, border_mode='same')(input) #32,32; 3
block1 = BatchNormalization()(block1)
block1 = Activation('relu')(block1)

block2 = Dropout(0.125)(block1)
block2 = BatchNormalization()(block2)
block2 = Convolution2D(48, 3, 1, border_mode='same',)(block2) #32,32; 5
block2 = Convolution2D(48, 1, 3, border_mode='same',)(block2) #32,32; 5
block2 = Activation('relu')(block2)

block3 = Convolution2D(32, 1, 1)(block2) #32,32; 5
block3 = MaxPooling2D(pool_size=(2, 2))(block3) #16,16; 10

block4 = Dropout(0.125)(block3)
block4 = BatchNormalization()(block4)
block4 = SeparableConv2D(48, 3, 3, border_mode='same')(block4) #16,16; 14 (separableconv2d increase RF by 4 and not 2.)
block4 = Activation('relu')(block4)
skip_connection = block4 #16,16

block5 = Dropout(0.125)(block4)
block5 = BatchNormalization()(block5)
block5 = Convolution2D(96, 3, 3, border_mode='same',)(block5) #16,16; 16
block5 = Activation('relu')(block5)
skip_connection2 = block5 #16,16

block6 = Convolution2D(32, 1, 1)(block5) #16,16; 16
block6 = MaxPooling2D(pool_size=(2, 2))(block6) #8,8; 32

block7 = Dropout(0.125)(block5)
block7 = BatchNormalization()(block6)
block7 = Convolution2D(48, 5, 5, border_mode='same')(block6) #8,8; 36
block7 = Activation('relu')(block6)

skip_connection = Convolution2D(32, 1, 1)(skip_connection) #16,16
skip_connection = BatchNormalization()(skip_connection)
skip_connection = Activation('relu')(skip_connection)
skip_connection = Lambda(space_to_depth_x2)(skip_connection) #8,8

block8 = concatenate([skip_connection, block7]) #8,8

block9 = Dropout(0.125)(block8)
block9 = BatchNormalization()(block9)
block9 = Convolution2D(96, 3, 3, border_mode='same', dilation_rate=(2, 2))(block9) #8,8; 40 (dilation 2 increases RF by 4 and not 2.)
block9 = Activation('relu')(block9)

skip_connection2 = Convolution2D(32, 1, 1)(skip_connection2) #16,16
skip_connection2 = BatchNormalization()(skip_connection2)
skip_connection2 = Activation('relu')(skip_connection2)
skip_connection2 = Lambda(space_to_depth_x2)(skip_connection2) #8,8

block10 = concatenate([skip_connection2, block9]) #8,8

block11 = Convolution2D(10, 1, 1)(block10) #8,8; 40
block11 = Convolution2D(10, 8, 8)(block11) #1,1; 40

output = Flatten()(block11)
output = Activation('softmax')(output)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (3, 1), padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (1, 3), padding="same")`
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1))`
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(48, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:23: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(96, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:27: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (5, 5), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:35: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:44: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(96, (3, 3), dilation_rate=(2, 2), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:47: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:54: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (1, 1))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:55: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (8, 8))`

# %%
model = Model(inputs=[input], outputs=[output])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 32, 32, 32)   896         input_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 32, 32, 32)   128         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 32, 32, 32)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 32, 32, 32)   0           activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 32, 32, 32)   128         dropout_14[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 32, 32, 48)   4656        batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 32, 32, 48)   6960        conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 32, 32, 48)   0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 32, 32, 32)   1568        activation_22[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 16, 16, 32)   0           conv2d_30[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 16, 16, 32)   0           max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 16, 16, 32)   128         dropout_15[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_4 (SeparableCo (None, 16, 16, 48)   1872        batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 16, 16, 48)   0           separable_conv2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 16, 16, 48)   0           activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 16, 16, 48)   192         dropout_16[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 16, 16, 96)   41568       batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 16, 16, 96)   0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 16, 16, 32)   1568        activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 16, 16, 32)   128         conv2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 16, 16, 32)   3104        activation_24[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 16, 16, 32)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 8, 8, 32)     0           conv2d_32[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 8, 8, 128)    0           activation_26[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 8, 8, 32)     0           max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 8, 8, 160)    0           lambda_4[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 16, 16, 32)   3104        activation_24[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 8, 8, 160)    0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 16, 16, 32)   128         conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 8, 8, 160)    640         dropout_18[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 16, 16, 32)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 8, 8, 96)     138336      batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 8, 8, 128)    0           activation_28[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 8, 8, 96)     0           conv2d_35[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 8, 8, 224)    0           lambda_5[0][0]
#                                                                  activation_27[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 8, 8, 10)     2250        concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 1, 1, 10)     6410        conv2d_37[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 10)           0           conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 10)           0           flatten_1[0][0]
# ==================================================================================================
# Total params: 213,764
# Trainable params: 213,028
# Non-trainable params: 736
# __________________________________________________________________________________________________

# %%
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Mounting the Google Drive to save the weights
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# Specifying the path to store the weights
filepath="/content/gdrive/My Drive/Assignment6B:{epoch:03d}-acc:{acc:.3f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='acc', verbose=1, save_best_only=True, save_weights_only=True, mode='max')

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False)


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 50, 
                                 validation_data = (test_features, test_labels), verbose=1,
                                 callbacks=[checkpoint])
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# Epoch 1/50
#   3/390 [..............................] - ETA: 18s - loss: 1.4374 - acc: 0.4974
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, callbacks=[<keras.ca..., steps_per_epoch=390, epochs=50)`
#   del sys.path[0]
# 390/390 [==============================] - 14s 35ms/step - loss: 1.1858 - acc: 0.5758 - val_loss: 1.2172 - val_acc: 0.5792
#
# Epoch 00001: acc improved from -inf to 0.57582, saving model to /content/gdrive/My Drive/Assignment6B:001-acc:0.576.hdf5
# Epoch 2/50
# 390/390 [==============================] - 14s 36ms/step - loss: 0.9257 - acc: 0.6768 - val_loss: 1.0057 - val_acc: 0.6493
#
# Epoch 00002: acc improved from 0.57582 to 0.67689, saving model to /content/gdrive/My Drive/Assignment6B:002-acc:0.677.hdf5
# Epoch 3/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.7755 - acc: 0.7259 - val_loss: 0.8707 - val_acc: 0.6932
#
# Epoch 00003: acc improved from 0.67689 to 0.72596, saving model to /content/gdrive/My Drive/Assignment6B:003-acc:0.726.hdf5
# Epoch 4/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.6869 - acc: 0.7576 - val_loss: 1.0285 - val_acc: 0.6522
#
# Epoch 00004: acc improved from 0.72596 to 0.75764, saving model to /content/gdrive/My Drive/Assignment6B:004-acc:0.758.hdf5
# Epoch 5/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.6156 - acc: 0.7842 - val_loss: 0.7739 - val_acc: 0.7344
#
# Epoch 00005: acc improved from 0.75764 to 0.78411, saving model to /content/gdrive/My Drive/Assignment6B:005-acc:0.784.hdf5
# Epoch 6/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.5542 - acc: 0.8059 - val_loss: 0.8860 - val_acc: 0.6869
#
# Epoch 00006: acc improved from 0.78411 to 0.80592, saving model to /content/gdrive/My Drive/Assignment6B:006-acc:0.806.hdf5
# Epoch 7/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.5049 - acc: 0.8219 - val_loss: 0.6887 - val_acc: 0.7663
#
# Epoch 00007: acc improved from 0.80592 to 0.82194, saving model to /content/gdrive/My Drive/Assignment6B:007-acc:0.822.hdf5
# Epoch 8/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.4682 - acc: 0.8351 - val_loss: 0.7136 - val_acc: 0.7647
#
# Epoch 00008: acc improved from 0.82194 to 0.83510, saving model to /content/gdrive/My Drive/Assignment6B:008-acc:0.835.hdf5
# Epoch 9/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.4289 - acc: 0.8485 - val_loss: 0.7387 - val_acc: 0.7641
#
# Epoch 00009: acc improved from 0.83510 to 0.84863, saving model to /content/gdrive/My Drive/Assignment6B:009-acc:0.849.hdf5
# Epoch 10/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.3918 - acc: 0.8605 - val_loss: 0.7675 - val_acc: 0.7582
#
# Epoch 00010: acc improved from 0.84863 to 0.86042, saving model to /content/gdrive/My Drive/Assignment6B:010-acc:0.860.hdf5
# Epoch 11/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.3695 - acc: 0.8691 - val_loss: 0.7611 - val_acc: 0.7599
#
# Epoch 00011: acc improved from 0.86042 to 0.86912, saving model to /content/gdrive/My Drive/Assignment6B:011-acc:0.869.hdf5
# Epoch 12/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.3454 - acc: 0.8758 - val_loss: 0.7916 - val_acc: 0.7572
#
# Epoch 00012: acc improved from 0.86912 to 0.87584, saving model to /content/gdrive/My Drive/Assignment6B:012-acc:0.876.hdf5
# Epoch 13/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.3241 - acc: 0.8834 - val_loss: 0.8222 - val_acc: 0.7619
#
# Epoch 00013: acc improved from 0.87584 to 0.88338, saving model to /content/gdrive/My Drive/Assignment6B:013-acc:0.883.hdf5
# Epoch 14/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.3067 - acc: 0.8886 - val_loss: 0.8163 - val_acc: 0.7604
#
# Epoch 00014: acc improved from 0.88338 to 0.88863, saving model to /content/gdrive/My Drive/Assignment6B:014-acc:0.889.hdf5
# Epoch 15/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.2858 - acc: 0.8972 - val_loss: 0.8671 - val_acc: 0.7594
#
# Epoch 00015: acc improved from 0.88863 to 0.89722, saving model to /content/gdrive/My Drive/Assignment6B:015-acc:0.897.hdf5
# Epoch 16/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.2713 - acc: 0.9006 - val_loss: 0.7966 - val_acc: 0.7751
#
# Epoch 00016: acc improved from 0.89722 to 0.90059, saving model to /content/gdrive/My Drive/Assignment6B:016-acc:0.901.hdf5
# Epoch 17/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.2599 - acc: 0.9054 - val_loss: 0.8859 - val_acc: 0.7679
#
# Epoch 00017: acc improved from 0.90059 to 0.90540, saving model to /content/gdrive/My Drive/Assignment6B:017-acc:0.905.hdf5
# Epoch 18/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.2474 - acc: 0.9105 - val_loss: 0.8840 - val_acc: 0.7668
#
# Epoch 00018: acc improved from 0.90540 to 0.91055, saving model to /content/gdrive/My Drive/Assignment6B:018-acc:0.911.hdf5
# Epoch 19/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.2298 - acc: 0.9176 - val_loss: 0.8564 - val_acc: 0.7734
#
# Epoch 00019: acc improved from 0.91055 to 0.91757, saving model to /content/gdrive/My Drive/Assignment6B:019-acc:0.918.hdf5
# Epoch 20/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.2271 - acc: 0.9176 - val_loss: 0.8460 - val_acc: 0.7778
#
# Epoch 00020: acc did not improve from 0.91757
# Epoch 21/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.2124 - acc: 0.9230 - val_loss: 0.9078 - val_acc: 0.7632
#
# Epoch 00021: acc improved from 0.91757 to 0.92300, saving model to /content/gdrive/My Drive/Assignment6B:021-acc:0.923.hdf5
# Epoch 22/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.2085 - acc: 0.9237 - val_loss: 0.9628 - val_acc: 0.7610
#
# Epoch 00022: acc improved from 0.92300 to 0.92370, saving model to /content/gdrive/My Drive/Assignment6B:022-acc:0.924.hdf5
# Epoch 23/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.2043 - acc: 0.9248 - val_loss: 0.9235 - val_acc: 0.7702
#
# Epoch 00023: acc improved from 0.92370 to 0.92481, saving model to /content/gdrive/My Drive/Assignment6B:023-acc:0.925.hdf5
# Epoch 24/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.1992 - acc: 0.9274 - val_loss: 0.9401 - val_acc: 0.7629
#
# Epoch 00024: acc improved from 0.92481 to 0.92735, saving model to /content/gdrive/My Drive/Assignment6B:024-acc:0.927.hdf5
# Epoch 25/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.1817 - acc: 0.9343 - val_loss: 0.9593 - val_acc: 0.7718
#
# Epoch 00025: acc improved from 0.92735 to 0.93429, saving model to /content/gdrive/My Drive/Assignment6B:025-acc:0.934.hdf5
# Epoch 26/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.1848 - acc: 0.9344 - val_loss: 0.9539 - val_acc: 0.7659
#
# Epoch 00026: acc improved from 0.93429 to 0.93439, saving model to /content/gdrive/My Drive/Assignment6B:026-acc:0.934.hdf5
# Epoch 27/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.1810 - acc: 0.9343 - val_loss: 1.0050 - val_acc: 0.7669
#
# Epoch 00027: acc did not improve from 0.93439
# Epoch 28/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.1706 - acc: 0.9394 - val_loss: 1.0186 - val_acc: 0.7689
#
# Epoch 00028: acc improved from 0.93439 to 0.93940, saving model to /content/gdrive/My Drive/Assignment6B:028-acc:0.939.hdf5
# Epoch 29/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.1647 - acc: 0.9414 - val_loss: 1.0226 - val_acc: 0.7656
#
# Epoch 00029: acc improved from 0.93940 to 0.94139, saving model to /content/gdrive/My Drive/Assignment6B:029-acc:0.941.hdf5
# Epoch 30/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.1647 - acc: 0.9409 - val_loss: 0.9925 - val_acc: 0.7764
#
# Epoch 00030: acc did not improve from 0.94139
# Epoch 31/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.1552 - acc: 0.9433 - val_loss: 1.0493 - val_acc: 0.7707
#
# Epoch 00031: acc improved from 0.94139 to 0.94329, saving model to /content/gdrive/My Drive/Assignment6B:031-acc:0.943.hdf5
# Epoch 32/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.1600 - acc: 0.9423 - val_loss: 1.1478 - val_acc: 0.7418
#
# Epoch 00032: acc did not improve from 0.94329
# Epoch 33/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.1472 - acc: 0.9458 - val_loss: 1.0521 - val_acc: 0.7652
#
# Epoch 00033: acc improved from 0.94329 to 0.94584, saving model to /content/gdrive/My Drive/Assignment6B:033-acc:0.946.hdf5
# Epoch 34/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.1533 - acc: 0.9442 - val_loss: 1.0418 - val_acc: 0.7732
#
# Epoch 00034: acc did not improve from 0.94584
# Epoch 35/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.1498 - acc: 0.9454 - val_loss: 1.1369 - val_acc: 0.7668
#
# Epoch 00035: acc did not improve from 0.94584
# Epoch 36/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.1402 - acc: 0.9501 - val_loss: 1.0655 - val_acc: 0.7751
#
# Epoch 00036: acc improved from 0.94584 to 0.95013, saving model to /content/gdrive/My Drive/Assignment6B:036-acc:0.950.hdf5
# Epoch 37/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.1388 - acc: 0.9500 - val_loss: 1.1650 - val_acc: 0.7689
#
# Epoch 00037: acc did not improve from 0.95013
# Epoch 38/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.1375 - acc: 0.9509 - val_loss: 1.1140 - val_acc: 0.7681
#
# Epoch 00038: acc improved from 0.95013 to 0.95093, saving model to /content/gdrive/My Drive/Assignment6B:038-acc:0.951.hdf5
# Epoch 39/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.1346 - acc: 0.9515 - val_loss: 1.0762 - val_acc: 0.7766
#
# Epoch 00039: acc improved from 0.95093 to 0.95152, saving model to /content/gdrive/My Drive/Assignment6B:039-acc:0.952.hdf5
# Epoch 40/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.1375 - acc: 0.9510 - val_loss: 1.0432 - val_acc: 0.7781
#
# Epoch 00040: acc did not improve from 0.95152
# Epoch 41/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.1286 - acc: 0.9536 - val_loss: 1.1278 - val_acc: 0.7729
#
# Epoch 00041: acc improved from 0.95152 to 0.95360, saving model to /content/gdrive/My Drive/Assignment6B:041-acc:0.954.hdf5
# Epoch 42/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.1286 - acc: 0.9535 - val_loss: 1.0867 - val_acc: 0.7792
#
# Epoch 00042: acc did not improve from 0.95360
# Epoch 43/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.1262 - acc: 0.9550 - val_loss: 1.0929 - val_acc: 0.7789
#
# Epoch 00043: acc improved from 0.95360 to 0.95502, saving model to /content/gdrive/My Drive/Assignment6B:043-acc:0.955.hdf5
# Epoch 44/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.1251 - acc: 0.9548 - val_loss: 1.0598 - val_acc: 0.7764
#
# Epoch 00044: acc did not improve from 0.95502
# Epoch 45/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.1188 - acc: 0.9581 - val_loss: 1.1266 - val_acc: 0.7781
#
# Epoch 00045: acc improved from 0.95502 to 0.95807, saving model to /content/gdrive/My Drive/Assignment6B:045-acc:0.958.hdf5
# Epoch 46/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.1257 - acc: 0.9545 - val_loss: 1.1177 - val_acc: 0.7852
#
# Epoch 00046: acc did not improve from 0.95807
# Epoch 47/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.1147 - acc: 0.9582 - val_loss: 1.0673 - val_acc: 0.7767
#
# Epoch 00047: acc improved from 0.95807 to 0.95819, saving model to /content/gdrive/My Drive/Assignment6B:047-acc:0.958.hdf5
# Epoch 48/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.1225 - acc: 0.9564 - val_loss: 1.1054 - val_acc: 0.7757
#
# Epoch 00048: acc did not improve from 0.95819
# Epoch 49/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.1165 - acc: 0.9584 - val_loss: 1.1549 - val_acc: 0.7732
#
# Epoch 00049: acc improved from 0.95819 to 0.95849, saving model to /content/gdrive/My Drive/Assignment6B:049-acc:0.958.hdf5
# Epoch 50/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.1149 - acc: 0.9591 - val_loss: 1.1438 - val_acc: 0.7771
#
# Epoch 00050: acc improved from 0.95849 to 0.95908, saving model to /content/gdrive/My Drive/Assignment6B:050-acc:0.959.hdf5
# Model took 687.19 seconds to train
# Accuracy on test data is: 77.71

# %% [markdown]
# # BEST ACCURACY WITH DIFFERENT CONVOLUTION LAYERS
#
# Epoch 50/50
# 390/390 [==============================] - 14s 35ms/step - loss: 0.1149 - **acc: 0.9591** - val_loss: 1.1438 - val_acc: 0.7771
#
# Epoch 00050: acc improved from **0.95849 to 0.95908**, saving model to /content/gdrive/My Drive/Assignment6B:050-acc:0.959.hdf5
