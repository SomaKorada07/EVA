# %%
from keras import backend as K
import time
import matplotlib.pyplot as plt

# Importing NumPy (Numerical Python) which is a library consisting of multidimensional array objects and a collection of routines for processing those arrays. It also gives an alias to the library.
import numpy as np

% matplotlib inline
np.random.seed(2017) 

# There are two main types of models available in Keras: the Sequential model and the Model class used with the functional API.
# Sequential model is a linear stack of layers. Importing Sequential model from Keras.
from keras.models import Sequential

# Importing different layers from Keras.
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dense, Dropout
from keras.layers.normalization import BatchNormalization

# Importing the utils library of Keras.
from keras.utils import np_utils

# Importing the callbacks of Keras.
from keras.callbacks import ModelCheckpoint
# Out:
# Using TensorFlow backend.

# %%
# CIFAR10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images. Importing CIFAR10 dataset from Keras.
from keras.datasets import cifar10

# Loading the CIFAR10 60000 Training and 10000 Test data into respective numpy arrays
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()

# Setting the count, number of channels, rows and columns of training images
num_train, img_channels, img_rows, img_cols =  train_features.shape

# Setting the count of test images
num_test, _, _, _ =  test_features.shape

# Setting number of classes (10)
num_classes = len(np.unique(train_labels))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step

# %%
# Setting up the class names
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']

# Plotting an image from each of the 10 classes
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %%
# Custom function to test accuracy
def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %%
# Pixel normalization for training images
train_features = train_features.astype('float32')/255

# Pixel normalization for test images
test_features = test_features.astype('float32')/255

# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %%
# Define the model
model = Sequential()
model.add(Convolution2D(48, 3, 3, border_mode='same', input_shape=(32, 32, 3)))
model.add(Activation('relu'))
model.add(Convolution2D(48, 3, 3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Convolution2D(96, 3, 3, border_mode='same'))
model.add(Activation('relu'))
model.add(Convolution2D(96, 3, 3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Convolution2D(192, 3, 3, border_mode='same'))
model.add(Activation('relu'))
model.add(Convolution2D(192, 3, 3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (3, 3), input_shape=(32, 32, 3..., padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (3, 3))`
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(96, (3, 3), padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(96, (3, 3))`
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(192, (3, 3), padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(192, (3, 3))`
#   app.launch_new_instance()

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 48)        1344
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 48)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 30, 30, 48)        20784
# _________________________________________________________________
# activation_2 (Activation)    (None, 30, 30, 48)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 15, 48)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 15, 15, 48)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 96)        41568
# _________________________________________________________________
# activation_3 (Activation)    (None, 15, 15, 96)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 13, 13, 96)        83040
# _________________________________________________________________
# activation_4 (Activation)    (None, 13, 13, 96)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 96)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 6, 6, 96)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 6, 6, 192)         166080
# _________________________________________________________________
# activation_5 (Activation)    (None, 6, 6, 192)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 4, 4, 192)         331968
# _________________________________________________________________
# activation_6 (Activation)    (None, 4, 4, 192)         0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 192)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2, 2, 192)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 768)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               393728
# _________________________________________________________________
# activation_7 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# activation_8 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 1,172,410
# Trainable params: 1,172,410
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False)


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 50, 
                                 validation_data = (test_features, test_labels), verbose=1)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, steps_per_epoch=390, epochs=50)`
#   if sys.path[0] == '':
# Epoch 1/50
# 390/390 [==============================] - 14s 37ms/step - loss: 1.8557 - acc: 0.2909 - val_loss: 1.4735 - val_acc: 0.4525
# Epoch 2/50
# 390/390 [==============================] - 9s 23ms/step - loss: 1.3558 - acc: 0.5100 - val_loss: 1.1324 - val_acc: 0.5925
# Epoch 3/50
# 390/390 [==============================] - 9s 22ms/step - loss: 1.1333 - acc: 0.5973 - val_loss: 1.0095 - val_acc: 0.6409
# Epoch 4/50
# 390/390 [==============================] - 9s 22ms/step - loss: 0.9850 - acc: 0.6534 - val_loss: 0.8653 - val_acc: 0.6950
# Epoch 5/50
# 390/390 [==============================] - 9s 22ms/step - loss: 0.8872 - acc: 0.6918 - val_loss: 0.8266 - val_acc: 0.7186
# Epoch 6/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.8106 - acc: 0.7212 - val_loss: 0.7360 - val_acc: 0.7470
# Epoch 7/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.7573 - acc: 0.7380 - val_loss: 0.7131 - val_acc: 0.7559
# Epoch 8/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.7089 - acc: 0.7563 - val_loss: 0.6574 - val_acc: 0.7721
# Epoch 9/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.6698 - acc: 0.7721 - val_loss: 0.6362 - val_acc: 0.7836
# Epoch 10/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.6408 - acc: 0.7809 - val_loss: 0.6448 - val_acc: 0.7760
# Epoch 11/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.6141 - acc: 0.7895 - val_loss: 0.6052 - val_acc: 0.7940
# Epoch 12/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.5862 - acc: 0.8011 - val_loss: 0.6085 - val_acc: 0.7956
# Epoch 13/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.5712 - acc: 0.8055 - val_loss: 0.5933 - val_acc: 0.8004
# Epoch 14/50
# 390/390 [==============================] - 9s 22ms/step - loss: 0.5487 - acc: 0.8111 - val_loss: 0.5901 - val_acc: 0.8007
# Epoch 15/50
# 390/390 [==============================] - 9s 22ms/step - loss: 0.5373 - acc: 0.8155 - val_loss: 0.5740 - val_acc: 0.8055
# Epoch 16/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.5246 - acc: 0.8221 - val_loss: 0.5904 - val_acc: 0.8040
# Epoch 17/50
# 390/390 [==============================] - 9s 22ms/step - loss: 0.5072 - acc: 0.8282 - val_loss: 0.5902 - val_acc: 0.8014
# Epoch 18/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4949 - acc: 0.8318 - val_loss: 0.5646 - val_acc: 0.8114
# Epoch 19/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4908 - acc: 0.8336 - val_loss: 0.5728 - val_acc: 0.8131
# Epoch 20/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4758 - acc: 0.8380 - val_loss: 0.5871 - val_acc: 0.8106
# Epoch 21/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4585 - acc: 0.8439 - val_loss: 0.5586 - val_acc: 0.8157
# Epoch 22/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4522 - acc: 0.8460 - val_loss: 0.5728 - val_acc: 0.8148
# Epoch 23/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4483 - acc: 0.8476 - val_loss: 0.5844 - val_acc: 0.8108
# Epoch 24/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4338 - acc: 0.8516 - val_loss: 0.5538 - val_acc: 0.8208
# Epoch 25/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4149 - acc: 0.8588 - val_loss: 0.5839 - val_acc: 0.8181
# Epoch 26/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4135 - acc: 0.8580 - val_loss: 0.5702 - val_acc: 0.8161
# Epoch 27/50
# 390/390 [==============================] - 9s 22ms/step - loss: 0.4154 - acc: 0.8582 - val_loss: 0.5877 - val_acc: 0.8150
# Epoch 28/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4078 - acc: 0.8620 - val_loss: 0.5646 - val_acc: 0.8229
# Epoch 29/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4055 - acc: 0.8630 - val_loss: 0.5457 - val_acc: 0.8241
# Epoch 30/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3963 - acc: 0.8652 - val_loss: 0.5681 - val_acc: 0.8235
# Epoch 31/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3932 - acc: 0.8670 - val_loss: 0.5742 - val_acc: 0.8200
# Epoch 32/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3783 - acc: 0.8713 - val_loss: 0.5629 - val_acc: 0.8213
# Epoch 33/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3825 - acc: 0.8683 - val_loss: 0.5557 - val_acc: 0.8244
# Epoch 34/50
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3715 - acc: 0.8747 - val_loss: 0.5559 - val_acc: 0.8280
# Epoch 35/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3738 - acc: 0.8734 - val_loss: 0.5629 - val_acc: 0.8280
# Epoch 36/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3628 - acc: 0.8780 - val_loss: 0.5837 - val_acc: 0.8157
# Epoch 37/50
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3595 - acc: 0.8778 - val_loss: 0.5447 - val_acc: 0.8286
# Epoch 38/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3585 - acc: 0.8788 - val_loss: 0.5537 - val_acc: 0.8255
# Epoch 39/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3557 - acc: 0.8795 - val_loss: 0.5534 - val_acc: 0.8268
# Epoch 40/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3511 - acc: 0.8814 - val_loss: 0.5728 - val_acc: 0.8247
# Epoch 41/50
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3506 - acc: 0.8815 - val_loss: 0.6263 - val_acc: 0.8129
# Epoch 42/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3467 - acc: 0.8830 - val_loss: 0.5624 - val_acc: 0.8296
# Epoch 43/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3380 - acc: 0.8866 - val_loss: 0.5716 - val_acc: 0.8294
# Epoch 44/50
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3391 - acc: 0.8858 - val_loss: 0.5565 - val_acc: 0.8297
# Epoch 45/50
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3421 - acc: 0.8867 - val_loss: 0.5679 - val_acc: 0.8295
# Epoch 46/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3287 - acc: 0.8895 - val_loss: 0.5665 - val_acc: 0.8285
# Epoch 47/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3255 - acc: 0.8893 - val_loss: 0.6101 - val_acc: 0.8167
# Epoch 48/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3327 - acc: 0.8870 - val_loss: 0.5970 - val_acc: 0.8207
# Epoch 49/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3226 - acc: 0.8921 - val_loss: 0.5851 - val_acc: 0.8212
# Epoch 50/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3145 - acc: 0.8944 - val_loss: 0.5819 - val_acc: 0.8214
# Model took 446.53 seconds to train
# Accuracy on test data is: 82.14

# %%
# Training for another 50 epochs
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 50, 
                                 validation_data = (test_features, test_labels), verbose=1)
# Out:
# Epoch 1/50
#   7/390 [..............................] - ETA: 8s - loss: 0.3062 - acc: 0.8884
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, steps_per_epoch=390, epochs=50)`
#   This is separate from the ipykernel package so we can avoid doing imports until
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3161 - acc: 0.8933 - val_loss: 0.5915 - val_acc: 0.8271
# Epoch 2/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3143 - acc: 0.8951 - val_loss: 0.5861 - val_acc: 0.8301
# Epoch 3/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3177 - acc: 0.8940 - val_loss: 0.5737 - val_acc: 0.8316
# Epoch 4/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3074 - acc: 0.8991 - val_loss: 0.6178 - val_acc: 0.8137
# Epoch 5/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3077 - acc: 0.8974 - val_loss: 0.6043 - val_acc: 0.8205
# Epoch 6/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3166 - acc: 0.8965 - val_loss: 0.5573 - val_acc: 0.8323
# Epoch 7/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2982 - acc: 0.9016 - val_loss: 0.5854 - val_acc: 0.8327
# Epoch 8/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3045 - acc: 0.9005 - val_loss: 0.5734 - val_acc: 0.8284
# Epoch 9/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3018 - acc: 0.9007 - val_loss: 0.5810 - val_acc: 0.8270
# Epoch 10/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2981 - acc: 0.9020 - val_loss: 0.6059 - val_acc: 0.8188
# Epoch 11/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3013 - acc: 0.9019 - val_loss: 0.5622 - val_acc: 0.8322
# Epoch 12/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2925 - acc: 0.9025 - val_loss: 0.5799 - val_acc: 0.8363
# Epoch 13/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2961 - acc: 0.9045 - val_loss: 0.5476 - val_acc: 0.8341
# Epoch 14/50
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3008 - acc: 0.9003 - val_loss: 0.5978 - val_acc: 0.8320
# Epoch 15/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2931 - acc: 0.9042 - val_loss: 0.5543 - val_acc: 0.8324
# Epoch 16/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2960 - acc: 0.9036 - val_loss: 0.5770 - val_acc: 0.8308
# Epoch 17/50
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2978 - acc: 0.9043 - val_loss: 0.5805 - val_acc: 0.8303
# Epoch 18/50
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2919 - acc: 0.9071 - val_loss: 0.5618 - val_acc: 0.8323
# Epoch 19/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2942 - acc: 0.9048 - val_loss: 0.5818 - val_acc: 0.8326
# Epoch 20/50
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2842 - acc: 0.9072 - val_loss: 0.5800 - val_acc: 0.8340
# Epoch 21/50
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2823 - acc: 0.9086 - val_loss: 0.5951 - val_acc: 0.8344
# Epoch 22/50
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2860 - acc: 0.9062 - val_loss: 0.5806 - val_acc: 0.8338
# Epoch 23/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2811 - acc: 0.9097 - val_loss: 0.5845 - val_acc: 0.8325
# Epoch 24/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2792 - acc: 0.9069 - val_loss: 0.5937 - val_acc: 0.8289
# Epoch 25/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2763 - acc: 0.9111 - val_loss: 0.5770 - val_acc: 0.8346
# Epoch 26/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2786 - acc: 0.9087 - val_loss: 0.6240 - val_acc: 0.8181
# Epoch 27/50
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2806 - acc: 0.9091 - val_loss: 0.5798 - val_acc: 0.8327
# Epoch 28/50
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2758 - acc: 0.9129 - val_loss: 0.6071 - val_acc: 0.8346
# Epoch 29/50
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2765 - acc: 0.9110 - val_loss: 0.5847 - val_acc: 0.8335
# Epoch 30/50
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2827 - acc: 0.9093 - val_loss: 0.6188 - val_acc: 0.8245
# Epoch 31/50
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2784 - acc: 0.9116 - val_loss: 0.5829 - val_acc: 0.8368
# Epoch 32/50
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2770 - acc: 0.9117 - val_loss: 0.5855 - val_acc: 0.8395
# Epoch 33/50
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2675 - acc: 0.9145 - val_loss: 0.5892 - val_acc: 0.8328
# Epoch 34/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2774 - acc: 0.9120 - val_loss: 0.5710 - val_acc: 0.8406
# Epoch 35/50
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2663 - acc: 0.9158 - val_loss: 0.5953 - val_acc: 0.8359
# Epoch 36/50
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2738 - acc: 0.9135 - val_loss: 0.6007 - val_acc: 0.8336
# Epoch 37/50
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2751 - acc: 0.9133 - val_loss: 0.5909 - val_acc: 0.8338
# Epoch 38/50
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2723 - acc: 0.9135 - val_loss: 0.6103 - val_acc: 0.8346
# Epoch 39/50
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2704 - acc: 0.9134 - val_loss: 0.5806 - val_acc: 0.8370
# Epoch 40/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2706 - acc: 0.9130 - val_loss: 0.6445 - val_acc: 0.8276
# Epoch 41/50
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2619 - acc: 0.9155 - val_loss: 0.5986 - val_acc: 0.8391
# Epoch 42/50
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2622 - acc: 0.9165 - val_loss: 0.6058 - val_acc: 0.8322
# Epoch 43/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2608 - acc: 0.9168 - val_loss: 0.6083 - val_acc: 0.8320
# Epoch 44/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2745 - acc: 0.9130 - val_loss: 0.5989 - val_acc: 0.8306
# Epoch 45/50
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2692 - acc: 0.9152 - val_loss: 0.5903 - val_acc: 0.8293
# Epoch 46/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2725 - acc: 0.9125 - val_loss: 0.6025 - val_acc: 0.8350
# Epoch 47/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2533 - acc: 0.9197 - val_loss: 0.5868 - val_acc: 0.8381
# Epoch 48/50
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2702 - acc: 0.9146 - val_loss: 0.5669 - val_acc: 0.8345
# Epoch 49/50
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2550 - acc: 0.9197 - val_loss: 0.5857 - val_acc: 0.8361
# Epoch 50/50
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2722 - acc: 0.9135 - val_loss: 0.5912 - val_acc: 0.8307

# %% [markdown]
# # BASE TRAINING ACCURACY
#
# Epoch 47/50
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2533 - **acc: 0.9197** - val_loss: 0.5868 - val_acc: 0.8381

# %% [markdown]
# # CHANGED MODEL
#
#
# *   Reduced the number of kernels being used.
# *   Reduced the Receptive Field at the last layer from 64 to 32.
# *   Changed the dropout rate to 0.125 from 0.25.
# *   Removed Dense layer.
# *   Removed Dropout at the last layer.
# *   Removed "relu" activation at the last layer.
# *   Added Batch Normalization before Convolution and Activation layers.
# *   Followed the increase in number of kernels and then decrease by using 1x1 and MaxPooling and then again increase type of architecture (cake pattern).

# %%
# Define the model
model = Sequential()
model.add(Convolution2D(32, 3, 3, border_mode='same', input_shape=(32, 32, 3))) #32,32; 3
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(Dropout(0.125))
model.add(BatchNormalization())
model.add(Convolution2D(48, 3, 3, border_mode='same',)) #32,32; 5
model.add(Activation('relu'))

model.add(Convolution2D(32, 1, 1)) #32,32; 5
model.add(MaxPooling2D(pool_size=(2, 2))) #16,16; 10

model.add(Dropout(0.125))
model.add(BatchNormalization())
model.add(Convolution2D(48, 3, 3, border_mode='same')) #16,16; 12
model.add(Activation('relu'))

model.add(Dropout(0.125))
model.add(BatchNormalization())
model.add(Convolution2D(96, 3, 3, border_mode='same',)) #16,16; 14
model.add(Activation('relu'))

model.add(Convolution2D(32, 1, 1)) #16,16; 14
model.add(MaxPooling2D(pool_size=(2, 2))) #8,8; 28

model.add(Dropout(0.125))
model.add(BatchNormalization())
model.add(Convolution2D(48, 3, 3, border_mode='same')) #8,8; 30
model.add(Activation('relu'))

model.add(Dropout(0.125))
model.add(BatchNormalization())
model.add(Convolution2D(96, 3, 3, border_mode='same')) #8,8; 32
model.add(Activation('relu'))

model.add(Convolution2D(10, 1, 1)) #8,8; 32
model.add(Convolution2D(10, 8, 8)) #1,1; 32

model.add(Flatten())
model.add(Activation('softmax'))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), input_shape=(32, 32, 3..., padding="same")`
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (3, 3), padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1))`
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (3, 3), padding="same")`
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:21: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(96, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:24: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:29: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:34: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(96, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:37: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (1, 1))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:38: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (8, 8))`

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 48)        13872
# _________________________________________________________________
# activation_2 (Activation)    (None, 32, 32, 48)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 32)        1568
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16, 16, 32)        0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 32)        128
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 48)        13872
# _________________________________________________________________
# activation_3 (Activation)    (None, 16, 16, 48)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 16, 16, 48)        0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16, 16, 48)        192
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 96)        41568
# _________________________________________________________________
# activation_4 (Activation)    (None, 16, 16, 96)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 32)        3104
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 8, 8, 32)          0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 32)          128
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 48)          13872
# _________________________________________________________________
# activation_5 (Activation)    (None, 8, 8, 48)          0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 8, 8, 48)          0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 8, 8, 48)          192
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 8, 96)          41568
# _________________________________________________________________
# activation_6 (Activation)    (None, 8, 8, 96)          0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 8, 8, 10)          970
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 1, 1, 10)          6410
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 10)                0
# _________________________________________________________________
# activation_7 (Activation)    (None, 10)                0
# =================================================================
# Total params: 138,596
# Trainable params: 138,148
# Non-trainable params: 448
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Mounting the Google Drive to save the weights
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# Specifying the path to store the weights
filepath="/content/gdrive/My Drive/Assignment6A:{epoch:03d}-acc:{acc:.3f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='acc', verbose=1, save_best_only=True, save_weights_only=True, mode='max')

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False)


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 100, 
                                 validation_data = (test_features, test_labels), verbose=1,
                                 callbacks=[checkpoint])
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, callbacks=[<keras.ca..., steps_per_epoch=390, epochs=100)`
#   del sys.path[0]
# Epoch 1/100
# 390/390 [==============================] - 14s 37ms/step - loss: 1.4335 - acc: 0.4801 - val_loss: 1.6118 - val_acc: 0.4626
#
# Epoch 00001: acc improved from -inf to 0.48013, saving model to /content/gdrive/My Drive/Assignment6A:001-acc:0.480.hdf5
# Epoch 2/100
# 390/390 [==============================] - 11s 27ms/step - loss: 1.0319 - acc: 0.6314 - val_loss: 1.0298 - val_acc: 0.6438
#
# Epoch 00002: acc improved from 0.48013 to 0.63136, saving model to /content/gdrive/My Drive/Assignment6A:002-acc:0.631.hdf5
# Epoch 3/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.8616 - acc: 0.6946 - val_loss: 0.9576 - val_acc: 0.6668
#
# Epoch 00003: acc improved from 0.63136 to 0.69462, saving model to /content/gdrive/My Drive/Assignment6A:003-acc:0.695.hdf5
# Epoch 4/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.7552 - acc: 0.7339 - val_loss: 0.7825 - val_acc: 0.7255
#
# Epoch 00004: acc improved from 0.69462 to 0.73390, saving model to /content/gdrive/My Drive/Assignment6A:004-acc:0.734.hdf5
# Epoch 5/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.6826 - acc: 0.7612 - val_loss: 0.7337 - val_acc: 0.7518
#
# Epoch 00005: acc improved from 0.73390 to 0.76123, saving model to /content/gdrive/My Drive/Assignment6A:005-acc:0.761.hdf5
# Epoch 6/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.6310 - acc: 0.7771 - val_loss: 0.6879 - val_acc: 0.7654
#
# Epoch 00006: acc improved from 0.76123 to 0.77709, saving model to /content/gdrive/My Drive/Assignment6A:006-acc:0.777.hdf5
# Epoch 7/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.5863 - acc: 0.7934 - val_loss: 0.7155 - val_acc: 0.7558
#
# Epoch 00007: acc improved from 0.77709 to 0.79343, saving model to /content/gdrive/My Drive/Assignment6A:007-acc:0.793.hdf5
# Epoch 8/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.5518 - acc: 0.8072 - val_loss: 0.6643 - val_acc: 0.7737
#
# Epoch 00008: acc improved from 0.79343 to 0.80717, saving model to /content/gdrive/My Drive/Assignment6A:008-acc:0.807.hdf5
# Epoch 9/100
# 390/390 [==============================] - 11s 28ms/step - loss: 0.5267 - acc: 0.8158 - val_loss: 0.8573 - val_acc: 0.7204
#
# Epoch 00009: acc improved from 0.80717 to 0.81577, saving model to /content/gdrive/My Drive/Assignment6A:009-acc:0.816.hdf5
# Epoch 10/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.4957 - acc: 0.8248 - val_loss: 0.6319 - val_acc: 0.7882
#
# Epoch 00010: acc improved from 0.81577 to 0.82483, saving model to /content/gdrive/My Drive/Assignment6A:010-acc:0.825.hdf5
# Epoch 11/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.4719 - acc: 0.8347 - val_loss: 0.6733 - val_acc: 0.7720
#
# Epoch 00011: acc improved from 0.82483 to 0.83458, saving model to /content/gdrive/My Drive/Assignment6A:011-acc:0.835.hdf5
# Epoch 12/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.4523 - acc: 0.8418 - val_loss: 0.6605 - val_acc: 0.7850
#
# Epoch 00012: acc improved from 0.83458 to 0.84179, saving model to /content/gdrive/My Drive/Assignment6A:012-acc:0.842.hdf5
# Epoch 13/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.4409 - acc: 0.8452 - val_loss: 0.6515 - val_acc: 0.7799
#
# Epoch 00013: acc improved from 0.84179 to 0.84520, saving model to /content/gdrive/My Drive/Assignment6A:013-acc:0.845.hdf5
# Epoch 14/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.4201 - acc: 0.8517 - val_loss: 0.6194 - val_acc: 0.7971
#
# Epoch 00014: acc improved from 0.84520 to 0.85170, saving model to /content/gdrive/My Drive/Assignment6A:014-acc:0.852.hdf5
# Epoch 15/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.4060 - acc: 0.8546 - val_loss: 0.7075 - val_acc: 0.7648
#
# Epoch 00015: acc improved from 0.85170 to 0.85461, saving model to /content/gdrive/My Drive/Assignment6A:015-acc:0.855.hdf5
# Epoch 16/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.3935 - acc: 0.8623 - val_loss: 0.6395 - val_acc: 0.7950
#
# Epoch 00016: acc improved from 0.85461 to 0.86241, saving model to /content/gdrive/My Drive/Assignment6A:016-acc:0.862.hdf5
# Epoch 17/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.3744 - acc: 0.8668 - val_loss: 0.6479 - val_acc: 0.7923
#
# Epoch 00017: acc improved from 0.86241 to 0.86684, saving model to /content/gdrive/My Drive/Assignment6A:017-acc:0.867.hdf5
# Epoch 18/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.3697 - acc: 0.8688 - val_loss: 0.6725 - val_acc: 0.7816
#
# Epoch 00018: acc improved from 0.86684 to 0.86886, saving model to /content/gdrive/My Drive/Assignment6A:018-acc:0.869.hdf5
# Epoch 19/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.3509 - acc: 0.8754 - val_loss: 0.6504 - val_acc: 0.7906
#
# Epoch 00019: acc improved from 0.86886 to 0.87540, saving model to /content/gdrive/My Drive/Assignment6A:019-acc:0.875.hdf5
# Epoch 20/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.3453 - acc: 0.8759 - val_loss: 0.5862 - val_acc: 0.8115
#
# Epoch 00020: acc improved from 0.87540 to 0.87594, saving model to /content/gdrive/My Drive/Assignment6A:020-acc:0.876.hdf5
# Epoch 21/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.3320 - acc: 0.8833 - val_loss: 0.6120 - val_acc: 0.8103
#
# Epoch 00021: acc improved from 0.87594 to 0.88334, saving model to /content/gdrive/My Drive/Assignment6A:021-acc:0.883.hdf5
# Epoch 22/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.3286 - acc: 0.8816 - val_loss: 0.6424 - val_acc: 0.7952
#
# Epoch 00022: acc did not improve from 0.88334
# Epoch 23/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.3145 - acc: 0.8867 - val_loss: 0.5989 - val_acc: 0.8125
#
# Epoch 00023: acc improved from 0.88334 to 0.88675, saving model to /content/gdrive/My Drive/Assignment6A:023-acc:0.887.hdf5
# Epoch 24/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.3086 - acc: 0.8901 - val_loss: 0.6276 - val_acc: 0.8045
#
# Epoch 00024: acc improved from 0.88675 to 0.89014, saving model to /content/gdrive/My Drive/Assignment6A:024-acc:0.890.hdf5
# Epoch 25/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.2991 - acc: 0.8929 - val_loss: 0.6341 - val_acc: 0.8084
#
# Epoch 00025: acc improved from 0.89014 to 0.89287, saving model to /content/gdrive/My Drive/Assignment6A:025-acc:0.893.hdf5
# Epoch 26/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.3009 - acc: 0.8919 - val_loss: 0.5859 - val_acc: 0.8188
#
# Epoch 00026: acc did not improve from 0.89287
# Epoch 27/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.2856 - acc: 0.8973 - val_loss: 0.6017 - val_acc: 0.8183
#
# Epoch 00027: acc improved from 0.89287 to 0.89736, saving model to /content/gdrive/My Drive/Assignment6A:027-acc:0.897.hdf5
# Epoch 28/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.2845 - acc: 0.8973 - val_loss: 0.6513 - val_acc: 0.8028
#
# Epoch 00028: acc did not improve from 0.89736
# Epoch 29/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.2756 - acc: 0.9003 - val_loss: 0.6061 - val_acc: 0.8180
#
# Epoch 00029: acc improved from 0.89736 to 0.90026, saving model to /content/gdrive/My Drive/Assignment6A:029-acc:0.900.hdf5
# Epoch 30/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.2686 - acc: 0.9031 - val_loss: 0.6001 - val_acc: 0.8195
#
# Epoch 00030: acc improved from 0.90026 to 0.90311, saving model to /content/gdrive/My Drive/Assignment6A:030-acc:0.903.hdf5
# Epoch 31/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.2671 - acc: 0.9038 - val_loss: 0.6637 - val_acc: 0.8018
#
# Epoch 00031: acc improved from 0.90311 to 0.90389, saving model to /content/gdrive/My Drive/Assignment6A:031-acc:0.904.hdf5
# Epoch 32/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.2559 - acc: 0.9079 - val_loss: 0.6296 - val_acc: 0.8158
#
# Epoch 00032: acc improved from 0.90389 to 0.90784, saving model to /content/gdrive/My Drive/Assignment6A:032-acc:0.908.hdf5
# Epoch 33/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.2574 - acc: 0.9064 - val_loss: 0.6259 - val_acc: 0.8164
#
# Epoch 00033: acc did not improve from 0.90784
# Epoch 34/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.2493 - acc: 0.9109 - val_loss: 0.6599 - val_acc: 0.8072
#
# Epoch 00034: acc improved from 0.90784 to 0.91087, saving model to /content/gdrive/My Drive/Assignment6A:034-acc:0.911.hdf5
# Epoch 35/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.2459 - acc: 0.9121 - val_loss: 0.7161 - val_acc: 0.8034
#
# Epoch 00035: acc improved from 0.91087 to 0.91216, saving model to /content/gdrive/My Drive/Assignment6A:035-acc:0.912.hdf5
# Epoch 36/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.2473 - acc: 0.9096 - val_loss: 0.6307 - val_acc: 0.8093
#
# Epoch 00036: acc did not improve from 0.91216
# Epoch 37/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.2425 - acc: 0.9130 - val_loss: 0.7066 - val_acc: 0.8047
#
# Epoch 00037: acc improved from 0.91216 to 0.91302, saving model to /content/gdrive/My Drive/Assignment6A:037-acc:0.913.hdf5
# Epoch 38/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.2337 - acc: 0.9146 - val_loss: 0.6422 - val_acc: 0.8175
#
# Epoch 00038: acc improved from 0.91302 to 0.91454, saving model to /content/gdrive/My Drive/Assignment6A:038-acc:0.915.hdf5
# Epoch 39/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.2348 - acc: 0.9156 - val_loss: 0.6384 - val_acc: 0.8105
#
# Epoch 00039: acc improved from 0.91454 to 0.91560, saving model to /content/gdrive/My Drive/Assignment6A:039-acc:0.916.hdf5
# Epoch 40/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.2273 - acc: 0.9181 - val_loss: 0.6591 - val_acc: 0.8142
#
# Epoch 00040: acc improved from 0.91560 to 0.91813, saving model to /content/gdrive/My Drive/Assignment6A:040-acc:0.918.hdf5
# Epoch 41/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.2256 - acc: 0.9180 - val_loss: 0.6375 - val_acc: 0.8225
#
# Epoch 00041: acc did not improve from 0.91813
# Epoch 42/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.2273 - acc: 0.9173 - val_loss: 0.6252 - val_acc: 0.8220
#
# Epoch 00042: acc did not improve from 0.91813
# Epoch 43/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.2177 - acc: 0.9219 - val_loss: 0.6302 - val_acc: 0.8217
#
# Epoch 00043: acc improved from 0.91813 to 0.92188, saving model to /content/gdrive/My Drive/Assignment6A:043-acc:0.922.hdf5
# Epoch 44/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.2169 - acc: 0.9211 - val_loss: 0.6330 - val_acc: 0.8204
#
# Epoch 00044: acc did not improve from 0.92188
# Epoch 45/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.2180 - acc: 0.9215 - val_loss: 0.6289 - val_acc: 0.8197
#
# Epoch 00045: acc did not improve from 0.92188
# Epoch 46/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.2146 - acc: 0.9222 - val_loss: 0.6444 - val_acc: 0.8206
#
# Epoch 00046: acc improved from 0.92188 to 0.92212, saving model to /content/gdrive/My Drive/Assignment6A:046-acc:0.922.hdf5
# Epoch 47/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.2063 - acc: 0.9266 - val_loss: 0.6358 - val_acc: 0.8216
#
# Epoch 00047: acc improved from 0.92212 to 0.92659, saving model to /content/gdrive/My Drive/Assignment6A:047-acc:0.927.hdf5
# Epoch 48/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.2074 - acc: 0.9249 - val_loss: 0.6677 - val_acc: 0.8200
#
# Epoch 00048: acc did not improve from 0.92659
# Epoch 49/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.2022 - acc: 0.9268 - val_loss: 0.6962 - val_acc: 0.8184
#
# Epoch 00049: acc improved from 0.92659 to 0.92679, saving model to /content/gdrive/My Drive/Assignment6A:049-acc:0.927.hdf5
# Epoch 50/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.2023 - acc: 0.9275 - val_loss: 0.6555 - val_acc: 0.8230
#
# Epoch 00050: acc improved from 0.92679 to 0.92749, saving model to /content/gdrive/My Drive/Assignment6A:050-acc:0.927.hdf5
# Epoch 51/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.2010 - acc: 0.9271 - val_loss: 0.6907 - val_acc: 0.8158
#
# Epoch 00051: acc did not improve from 0.92749
# Epoch 52/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1950 - acc: 0.9284 - val_loss: 0.6793 - val_acc: 0.8186
#
# Epoch 00052: acc improved from 0.92749 to 0.92840, saving model to /content/gdrive/My Drive/Assignment6A:052-acc:0.928.hdf5
# Epoch 53/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1952 - acc: 0.9283 - val_loss: 0.6501 - val_acc: 0.8148
#
# Epoch 00053: acc did not improve from 0.92840
# Epoch 54/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1940 - acc: 0.9304 - val_loss: 0.6590 - val_acc: 0.8212
#
# Epoch 00054: acc improved from 0.92840 to 0.93040, saving model to /content/gdrive/My Drive/Assignment6A:054-acc:0.930.hdf5
# Epoch 55/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1947 - acc: 0.9292 - val_loss: 0.6741 - val_acc: 0.8190
#
# Epoch 00055: acc did not improve from 0.93040
# Epoch 56/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1929 - acc: 0.9300 - val_loss: 0.6853 - val_acc: 0.8211
#
# Epoch 00056: acc did not improve from 0.93040
# Epoch 57/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1877 - acc: 0.9327 - val_loss: 0.6612 - val_acc: 0.8226
#
# Epoch 00057: acc improved from 0.93040 to 0.93279, saving model to /content/gdrive/My Drive/Assignment6A:057-acc:0.933.hdf5
# Epoch 58/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1873 - acc: 0.9311 - val_loss: 0.7281 - val_acc: 0.8091
#
# Epoch 00058: acc did not improve from 0.93279
# Epoch 59/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1797 - acc: 0.9334 - val_loss: 0.6827 - val_acc: 0.8218
#
# Epoch 00059: acc improved from 0.93279 to 0.93343, saving model to /content/gdrive/My Drive/Assignment6A:059-acc:0.933.hdf5
# Epoch 60/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1860 - acc: 0.9327 - val_loss: 0.6775 - val_acc: 0.8208
#
# Epoch 00060: acc did not improve from 0.93343
# Epoch 61/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1831 - acc: 0.9332 - val_loss: 0.6760 - val_acc: 0.8195
#
# Epoch 00061: acc did not improve from 0.93343
# Epoch 62/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1765 - acc: 0.9344 - val_loss: 0.6788 - val_acc: 0.8244
#
# Epoch 00062: acc improved from 0.93343 to 0.93439, saving model to /content/gdrive/My Drive/Assignment6A:062-acc:0.934.hdf5
# Epoch 63/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1800 - acc: 0.9351 - val_loss: 0.6741 - val_acc: 0.8214
#
# Epoch 00063: acc improved from 0.93439 to 0.93511, saving model to /content/gdrive/My Drive/Assignment6A:063-acc:0.935.hdf5
# Epoch 64/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1774 - acc: 0.9357 - val_loss: 0.6860 - val_acc: 0.8209
#
# Epoch 00064: acc improved from 0.93511 to 0.93572, saving model to /content/gdrive/My Drive/Assignment6A:064-acc:0.936.hdf5
# Epoch 65/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1754 - acc: 0.9364 - val_loss: 0.7212 - val_acc: 0.8135
#
# Epoch 00065: acc improved from 0.93572 to 0.93646, saving model to /content/gdrive/My Drive/Assignment6A:065-acc:0.936.hdf5
# Epoch 66/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1737 - acc: 0.9365 - val_loss: 0.6766 - val_acc: 0.8210
#
# Epoch 00066: acc did not improve from 0.93646
# Epoch 67/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1717 - acc: 0.9374 - val_loss: 0.7025 - val_acc: 0.8222
#
# Epoch 00067: acc improved from 0.93646 to 0.93740, saving model to /content/gdrive/My Drive/Assignment6A:067-acc:0.937.hdf5
# Epoch 68/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1713 - acc: 0.9379 - val_loss: 0.6641 - val_acc: 0.8285
#
# Epoch 00068: acc improved from 0.93740 to 0.93790, saving model to /content/gdrive/My Drive/Assignment6A:068-acc:0.938.hdf5
# Epoch 69/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1678 - acc: 0.9384 - val_loss: 0.6898 - val_acc: 0.8222
#
# Epoch 00069: acc improved from 0.93790 to 0.93846, saving model to /content/gdrive/My Drive/Assignment6A:069-acc:0.938.hdf5
# Epoch 70/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1661 - acc: 0.9407 - val_loss: 0.7176 - val_acc: 0.8173
#
# Epoch 00070: acc improved from 0.93846 to 0.94075, saving model to /content/gdrive/My Drive/Assignment6A:070-acc:0.941.hdf5
# Epoch 71/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1691 - acc: 0.9381 - val_loss: 0.6815 - val_acc: 0.8203
#
# Epoch 00071: acc did not improve from 0.94075
# Epoch 72/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1625 - acc: 0.9414 - val_loss: 0.7480 - val_acc: 0.8112
#
# Epoch 00072: acc improved from 0.94075 to 0.94137, saving model to /content/gdrive/My Drive/Assignment6A:072-acc:0.941.hdf5
# Epoch 73/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1671 - acc: 0.9387 - val_loss: 0.6946 - val_acc: 0.8252
#
# Epoch 00073: acc did not improve from 0.94137
# Epoch 74/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1644 - acc: 0.9394 - val_loss: 0.7312 - val_acc: 0.8155
#
# Epoch 00074: acc did not improve from 0.94137
# Epoch 75/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1598 - acc: 0.9409 - val_loss: 0.6564 - val_acc: 0.8283
#
# Epoch 00075: acc did not improve from 0.94137
# Epoch 76/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1604 - acc: 0.9416 - val_loss: 0.6763 - val_acc: 0.8276
#
# Epoch 00076: acc improved from 0.94137 to 0.94161, saving model to /content/gdrive/My Drive/Assignment6A:076-acc:0.942.hdf5
# Epoch 77/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1585 - acc: 0.9418 - val_loss: 0.6866 - val_acc: 0.8214
#
# Epoch 00077: acc improved from 0.94161 to 0.94181, saving model to /content/gdrive/My Drive/Assignment6A:077-acc:0.942.hdf5
# Epoch 78/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1625 - acc: 0.9412 - val_loss: 0.6987 - val_acc: 0.8261
#
# Epoch 00078: acc did not improve from 0.94181
# Epoch 79/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1582 - acc: 0.9421 - val_loss: 0.7039 - val_acc: 0.8235
#
# Epoch 00079: acc improved from 0.94181 to 0.94211, saving model to /content/gdrive/My Drive/Assignment6A:079-acc:0.942.hdf5
# Epoch 80/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1635 - acc: 0.9405 - val_loss: 0.6671 - val_acc: 0.8285
#
# Epoch 00080: acc did not improve from 0.94211
# Epoch 81/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1555 - acc: 0.9433 - val_loss: 0.7916 - val_acc: 0.8086
#
# Epoch 00081: acc improved from 0.94211 to 0.94335, saving model to /content/gdrive/My Drive/Assignment6A:081-acc:0.943.hdf5
# Epoch 82/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1550 - acc: 0.9436 - val_loss: 0.6907 - val_acc: 0.8241
#
# Epoch 00082: acc improved from 0.94335 to 0.94364, saving model to /content/gdrive/My Drive/Assignment6A:082-acc:0.944.hdf5
# Epoch 83/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1533 - acc: 0.9453 - val_loss: 0.7471 - val_acc: 0.8176
#
# Epoch 00083: acc improved from 0.94364 to 0.94532, saving model to /content/gdrive/My Drive/Assignment6A:083-acc:0.945.hdf5
# Epoch 84/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1541 - acc: 0.9433 - val_loss: 0.7280 - val_acc: 0.8191
#
# Epoch 00084: acc did not improve from 0.94532
# Epoch 85/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1502 - acc: 0.9451 - val_loss: 0.7519 - val_acc: 0.8133
#
# Epoch 00085: acc did not improve from 0.94532
# Epoch 86/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1535 - acc: 0.9442 - val_loss: 0.6937 - val_acc: 0.8286
#
# Epoch 00086: acc did not improve from 0.94532
# Epoch 87/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1501 - acc: 0.9458 - val_loss: 0.6641 - val_acc: 0.8331
#
# Epoch 00087: acc improved from 0.94532 to 0.94584, saving model to /content/gdrive/My Drive/Assignment6A:087-acc:0.946.hdf5
# Epoch 88/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1486 - acc: 0.9458 - val_loss: 0.6922 - val_acc: 0.8242
#
# Epoch 00088: acc did not improve from 0.94584
# Epoch 89/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1481 - acc: 0.9471 - val_loss: 0.7130 - val_acc: 0.8227
#
# Epoch 00089: acc improved from 0.94584 to 0.94712, saving model to /content/gdrive/My Drive/Assignment6A:089-acc:0.947.hdf5
# Epoch 90/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1405 - acc: 0.9491 - val_loss: 0.7018 - val_acc: 0.8264
#
# Epoch 00090: acc improved from 0.94712 to 0.94911, saving model to /content/gdrive/My Drive/Assignment6A:090-acc:0.949.hdf5
# Epoch 91/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1459 - acc: 0.9472 - val_loss: 0.6852 - val_acc: 0.8266
#
# Epoch 00091: acc did not improve from 0.94911
# Epoch 92/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1453 - acc: 0.9468 - val_loss: 0.7076 - val_acc: 0.8215
#
# Epoch 00092: acc did not improve from 0.94911
# Epoch 93/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1418 - acc: 0.9493 - val_loss: 0.7291 - val_acc: 0.8234
#
# Epoch 00093: acc improved from 0.94911 to 0.94933, saving model to /content/gdrive/My Drive/Assignment6A:093-acc:0.949.hdf5
# Epoch 94/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1482 - acc: 0.9469 - val_loss: 0.6724 - val_acc: 0.8294
#
# Epoch 00094: acc did not improve from 0.94933
# Epoch 95/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1403 - acc: 0.9493 - val_loss: 0.7031 - val_acc: 0.8326
#
# Epoch 00095: acc did not improve from 0.94933
# Epoch 96/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1428 - acc: 0.9487 - val_loss: 0.7062 - val_acc: 0.8282
#
# Epoch 00096: acc did not improve from 0.94933
# Epoch 97/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1411 - acc: 0.9498 - val_loss: 0.7358 - val_acc: 0.8219
#
# Epoch 00097: acc improved from 0.94933 to 0.94983, saving model to /content/gdrive/My Drive/Assignment6A:097-acc:0.950.hdf5
# Epoch 98/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1432 - acc: 0.9480 - val_loss: 0.7165 - val_acc: 0.8309
#
# Epoch 00098: acc did not improve from 0.94983
# Epoch 99/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1381 - acc: 0.9493 - val_loss: 0.7199 - val_acc: 0.8293
#
# Epoch 00099: acc did not improve from 0.94983
# Epoch 100/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1363 - acc: 0.9503 - val_loss: 0.7209 - val_acc: 0.8224
#
# Epoch 00100: acc improved from 0.94983 to 0.95029, saving model to /content/gdrive/My Drive/Assignment6A:100-acc:0.950.hdf5
# Model took 1071.82 seconds to train
# Accuracy on test data is: 82.24

# %% [markdown]
# # BEST ACCURACY WITH CHANGED MODEL
# Epoch 100/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1363 - **acc: 0.9503** - val_loss: 0.7209 - val_acc: 0.8224
#
# Epoch 00100: acc improved from **0.94983 to 0.95029**, saving model to /content/gdrive/My Drive/Assignment6A:100-acc:0.950.hdf5
