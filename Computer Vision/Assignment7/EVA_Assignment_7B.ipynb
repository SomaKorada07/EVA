# %%
from keras import backend as K
import time
import matplotlib.pyplot as plt

# Importing NumPy (Numerical Python) which is a library consisting of multidimensional array objects and a collection of routines for processing those arrays. It also gives an alias to the library.
import numpy as np

% matplotlib inline
np.random.seed(2017) 

# There are two main types of models available in Keras: the Sequential model and the Model class used with the functional API.
# Sequential model is a linear stack of layers. Importing Sequential model from Keras.
from keras.models import Sequential, Model

# Importing different layers from Keras.
from keras.layers.convolutional import Convolution2D, MaxPooling2D, SeparableConv2D
from keras.layers import Activation, Flatten, Dense, Dropout, Input, Lambda, Concatenate
from keras.layers.normalization import BatchNormalization

# Importing the utils library of Keras.
from keras.utils import np_utils

# Importing the concatenate library of Keras
from keras.layers.merge import concatenate

import tensorflow as tf

# Importing the callbacks of Keras.
from keras.callbacks import ModelCheckpoint

from keras.regularizers import l2
# Out:
# Using TensorFlow backend.

# %%
# CIFAR10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images. Importing CIFAR10 dataset from Keras.
from keras.datasets import cifar10

# Loading the CIFAR10 60000 Training and 10000 Test data into respective numpy arrays
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()

# Setting the count, number of channels, rows and columns of training images
num_train, img_channels, img_rows, img_cols =  train_features.shape

# Setting the count of test images
num_test, _, _, _ =  test_features.shape

# Setting number of classes (10)
num_classes = len(np.unique(train_labels))

# %%
# Pixel normalization for training images
train_features = train_features.astype('float32')/255

# Pixel normalization for test images
test_features = test_features.astype('float32')/255

# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %%
# Space_to_depth funcction of Tensorflow rearranges blocks of spatial data into depth. 
def space_to_depth_x2(x):
    return tf.space_to_depth(x, block_size=2)

# %%
# Define the model
input = Input(shape=(32, 32, 3))
layer1 = SeparableConv2D(32, 5, 5, border_mode='same')(input) #32,32
layer1 = BatchNormalization()(layer1)
layer1 = Activation('relu')(layer1)
skip_connection1 = layer1 #32,32

#layer2 = Dropout(0.125)(layer1)
layer2 = BatchNormalization()(layer1)
layer2 = Convolution2D(32, 5, 5, border_mode='same')(layer2) #32,32
layer2 = Activation('relu')(layer2)
skip_connection2 = layer2

layer3 = BatchNormalization()(layer2)
layer3 = Convolution2D(64, 5, 5, border_mode='same')(layer3) #32,32
layer3 = Activation('relu')(layer3)
skip_connection3 = layer3

# Group convolution of layer1 and layer3 to layer4 
groupConv1 = concatenate([skip_connection1, layer3]) #32,32

layer4 = BatchNormalization()(groupConv1)
layer4 = SeparableConv2D(128, 5, 5, border_mode='same')(layer4) #32,32
layer4 = Activation('relu')(layer4)
skip_connection4 = layer4

# Group convolution of layer1 and layer4 to layer5
groupConv2 = concatenate([skip_connection1, layer4]) #16,16

# Using 1x1 to reduce channels
layer5 = BatchNormalization()(groupConv2)
layer5 = Convolution2D(32, 1, 1)(layer5) #32,32
layer5 = Activation('relu')(layer5)
layer5 = MaxPooling2D(pool_size=(2, 2))(layer5) #16,16

#layer6 = Dropout(0.125)(layer5)
layer6 = BatchNormalization()(layer5)
layer6 = SeparableConv2D(32, 3, 3, border_mode='same')(layer6) #16,16
layer6 = Activation('relu')(layer6)
skip_connection6 = layer6 #16,16

# Group convolution of layer1, layer4 and layer6 to layer7
layer1_layer4 = concatenate([skip_connection1, skip_connection4]) #32,32
layer1_layer4 = Lambda(space_to_depth_x2)(layer1_layer4) #16,16
groupConv3 = concatenate([layer1_layer4, layer6]) #16,16

#layer7 = Dropout(0.125)(groupConv3)
layer7 = BatchNormalization()(groupConv3)
layer7 = Convolution2D(32, 5, 5, border_mode='same')(layer7) #16,16
layer7 = Activation('relu')(layer7)
skip_connection7 = layer7 #16,16

# Group convolution of layer3, layer4, layer6 and layer7 to layer8
layer3_layer4 = concatenate([skip_connection3, skip_connection4]) #32,32
layer3_layer4 = Lambda(space_to_depth_x2)(layer3_layer4) #16,16
groupConv4 = concatenate([layer3_layer4, layer6, layer7]) #16,16

layer8 = BatchNormalization()(groupConv4)
layer8 = SeparableConv2D(64, 3, 3, border_mode='same')(layer8) #16,16
layer8 = Activation('relu')(layer8)
skip_connection8 = layer8 #16,16

# Group convolution of layer1, layer3, layer4, layer6, layer7 and layer8 to layer9
layer1_layer3_layer4 = concatenate([skip_connection1, skip_connection3, skip_connection4]) #32,32
layer1_layer3_layer4 = Lambda(space_to_depth_x2)(layer1_layer3_layer4) #16,16
groupConv5 = concatenate([layer1_layer3_layer4, layer6, layer7, layer8]) #16,16

layer9 = BatchNormalization()(groupConv5)
layer9 = SeparableConv2D(128, 5, 5, border_mode='same')(layer9) #16,16
layer9 = Activation('relu')(layer9)

# Group convolution of layer1, layer4, layer6, layer8 and layer9 to layer10
layer1_layer4 = concatenate([skip_connection1, skip_connection4]) #32,32
layer1_layer4 = Lambda(space_to_depth_x2)(layer1_layer4) #16,16
groupConv6 = concatenate([layer1_layer4, layer6, layer8, layer9]) #16,16

# Using 1x1 to reduce channels
layer10 = BatchNormalization()(groupConv6)
layer10 = Convolution2D(32, 1, 1)(layer10) #16,16; 16
layer10 = Activation('relu')(layer10)
layer10 = MaxPooling2D(pool_size=(2, 2))(layer10) #8,8

# Group convolution of layer7 and layer10 to layer11
skip_connection_temp7 = Lambda(space_to_depth_x2)(skip_connection7)
groupConv7 = concatenate([skip_connection_temp7, layer10]) #8,8

#layer11 = Dropout(0.125)(groupConv7)
layer11 = BatchNormalization()(groupConv7)
layer11 = Convolution2D(32, 5, 5, border_mode='same')(layer11) #8,8
layer11 = Activation('relu')(layer11)
skip_connection11 = layer11 #8,8

# Group convolution of layer2, layer4, layer8 and layer11 to layer12
layer2_layer4 = concatenate([skip_connection2, skip_connection4]) #32,32
layer2_layer4 = Lambda(space_to_depth_x2)(layer2_layer4) #16,16
layer2_layer4_layer8 = concatenate([layer2_layer4, layer8]) #16,16
layer2_layer4_layer8 = Lambda(space_to_depth_x2)(layer2_layer4_layer8) #8,8
groupConv7 = concatenate([layer2_layer4_layer8, layer11]) #8,8

layer12 = BatchNormalization()(groupConv7)
layer12 = SeparableConv2D(32, 5, 5, border_mode='same')(layer12) #8,8
layer12 = Activation('relu')(layer12)
skip_connection12 = layer12 #8,8

# Group convolution of layer2, layer3, layer6, layer11 and layer12 to layer13
layer2_layer3 = concatenate([skip_connection2, skip_connection3]) #32,32
layer2_layer3 = Lambda(space_to_depth_x2)(layer2_layer3) #16,16
layer2_layer3_layer6 = concatenate([layer2_layer3, layer6]) #16,16
layer2_layer3_layer6 = Lambda(space_to_depth_x2)(layer2_layer3_layer6) #8,8
groupConv8 = concatenate([layer2_layer3_layer6, layer11, layer12]) #8,8

layer13 = BatchNormalization()(groupConv8)
layer13 = Convolution2D(64, 3, 3, border_mode='same')(layer13) #8,8
layer13 = Activation('relu')(layer13)

# Group convolution of layer1, layer3, layer4, layer6, layer8, layer12 and layer13 to layer14
layer1_layer3_layer4 = concatenate([skip_connection1, skip_connection3, skip_connection4]) #32,32
layer1_layer3_layer4 = Lambda(space_to_depth_x2)(layer1_layer3_layer4) #16,16
layer1_layer3_layer4_layer6_layer8 = concatenate([layer1_layer3_layer4, layer6, layer8]) #16,16
layer1_layer3_layer4_layer6_layer8 = Lambda(space_to_depth_x2)(layer1_layer3_layer4_layer6_layer8) #8,8
groupConv9 = concatenate([layer1_layer3_layer4_layer6_layer8, layer12, layer13]) #16,16

layer14 = BatchNormalization()(groupConv9)
layer14 = SeparableConv2D(128, 5, 5, border_mode='same')(layer14) #8,8
layer14 = Activation('relu')(layer14)

# Group convolution of layer4, layer8, layer12 and layer14 to softmax
skip_connection_temp1 = Lambda(space_to_depth_x2)(skip_connection1) #16,16
layer4_layer8 = concatenate([skip_connection_temp1, layer8]) #16,16
layer4_layer8 = Lambda(space_to_depth_x2)(layer4_layer8) #8,8
groupConv10 = concatenate([layer4_layer8, layer12, layer14]) #8,8

#layer15 = BatchNormalization()(groupConv10)
layer15 = Convolution2D(10, 1, 1)(groupConv10) #8,8
#layer15 = Activation('relu')(layer15)
layer15 = Convolution2D(10, 8, 8)(layer15) #1,1

output = Flatten()(layer15)
output = Activation('softmax')(output)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0623 03:17:52.582888 140463527647104 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0623 03:17:52.599575 140463527647104 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(32, (5, 5), padding="same")`
#
# W0623 03:17:52.605524 140463527647104 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0623 03:17:52.638816 140463527647104 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0623 03:17:52.641226 140463527647104 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0623 03:17:53.454812 140463527647104 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (5, 5), padding="same")`
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (5, 5), padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(128, (5, 5), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:31: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1))`
# W0623 03:17:53.847192 140463527647104 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:37: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(32, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:48: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (5, 5), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:58: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(64, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:68: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(128, (5, 5), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:78: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:88: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (5, 5), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:100: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(32, (5, 5), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:112: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:123: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(128, (5, 5), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:133: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (1, 1))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:135: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (8, 8))`

# %%
model = Model(inputs=[input], outputs=[output])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# separable_conv2d_1 (SeparableCo (None, 32, 32, 32)   203         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 32)   128         separable_conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 32)   128         activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 32)   25632       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 32)   128         activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 64)   51264       batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 64)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 96)   0           activation_1[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 96)   384         concatenate_1[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_2 (SeparableCo (None, 32, 32, 128)  14816       batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 128)  0           separable_conv2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 160)  0           activation_1[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 160)  640         concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 32)   5152        batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 32)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 32)   0           activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 32)   128         max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_3 (SeparableCo (None, 16, 16, 32)   1344        batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 32, 32, 160)  0           activation_1[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 16, 16, 32)   0           separable_conv2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 16, 16, 640)  0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 16, 16, 672)  0           lambda_1[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 672)  2688        concatenate_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 32, 32, 192)  0           activation_3[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 16, 16, 32)   537632      batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 16, 16, 768)  0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 32)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 16, 16, 832)  0           lambda_2[0][0]
#                                                                  activation_6[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 832)  3328        concatenate_6[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_4 (SeparableCo (None, 16, 16, 64)   60800       batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 32, 32, 224)  0           activation_1[0][0]
#                                                                  activation_3[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 64)   0           separable_conv2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 16, 16, 896)  0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 16, 16, 1024) 0           lambda_3[0][0]
#                                                                  activation_6[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 1024) 4096        concatenate_8[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 32, 32, 160)  0           activation_1[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_5 (SeparableCo (None, 16, 16, 128)  156800      batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 16, 16, 640)  0           concatenate_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 128)  0           separable_conv2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 16, 16, 864)  0           lambda_4[0][0]
#                                                                  activation_6[0][0]
#                                                                  activation_8[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 864)  3456        concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 32)   27680       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 32)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 8, 8, 128)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 32)     0           activation_10[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 32, 32, 160)  0           activation_2[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 8, 8, 160)    0           lambda_5[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 16, 16, 640)  0           concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 8, 8, 160)    640         concatenate_11[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 16, 16, 704)  0           lambda_6[0][0]
#                                                                  activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 8, 8, 32)     128032      batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 8, 8, 2816)   0           concatenate_13[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 8, 8, 32)     0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 8, 8, 2848)   0           lambda_7[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 32, 32, 96)   0           activation_2[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 8, 8, 2848)   11392       concatenate_14[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 16, 16, 384)  0           concatenate_15[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_6 (SeparableCo (None, 8, 8, 32)     162368      batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 16, 16, 416)  0           lambda_8[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 8, 8, 32)     0           separable_conv2d_6[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 8, 8, 1664)   0           concatenate_16[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 32, 32, 224)  0           activation_1[0][0]
#                                                                  activation_3[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 8, 8, 1728)   0           lambda_9[0][0]
#                                                                  activation_11[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 16, 16, 896)  0           concatenate_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 8, 8, 1728)   6912        concatenate_17[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 16, 16, 992)  0           lambda_10[0][0]
#                                                                  activation_6[0][0]
#                                                                  activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 8, 64)     995392      batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 8, 8, 3968)   0           concatenate_19[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 8, 8, 64)     0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 8, 8, 4064)   0           lambda_11[0][0]
#                                                                  activation_12[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 16, 16, 128)  0           activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 8, 8, 4064)   16256       concatenate_20[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 16, 16, 192)  0           lambda_12[0][0]
#                                                                  activation_8[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_7 (SeparableCo (None, 8, 8, 128)    621920      batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 8, 8, 768)    0           concatenate_21[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 8, 8, 128)    0           separable_conv2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 8, 8, 928)    0           lambda_13[0][0]
#                                                                  activation_12[0][0]
#                                                                  activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 8, 8, 10)     9290        concatenate_22[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 1, 1, 10)     6410        conv2d_8[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 10)           0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 10)           0           flatten_1[0][0]
# ==================================================================================================
# Total params: 2,855,039
# Trainable params: 2,829,887
# Non-trainable params: 25,152
# __________________________________________________________________________________________________

# %%
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# W0623 03:17:54.873286 140463527647104 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
from keras.utils import plot_model
plot_model(model, show_shapes=True, show_layer_names=True, to_file='model_structure.png')

from IPython.display import Image
Image(retina=True, filename='model_structure.png')

# %%
# Mounting the Google Drive to save the weights
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Specifying the path to store the weights
filepath="/content/gdrive/My Drive/Assignment7B:{epoch:03d}-val-acc:{val_acc:.3f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, save_weights_only=True, mode='max')

# %%
from keras.callbacks import LearningRateScheduler

def lr_schedule(epoch):
    if epoch > 80:
        lr = 1e-5
    elif epoch > 60:
        lr = 0.5e-4
    elif epoch > 40:
        lr = 1e-4
    elif epoch > 20:
        lr = 0.5e-3
    else:
        lr = 1e-3
    print('Learning rate (from LearningRateScheduler): ', lr)
    return lr

lr_scheduler = LearningRateScheduler(lr_schedule)

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False)


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 100, 
                                 validation_data = (test_features, test_labels), verbose=1,
                                 callbacks=[checkpoint, lr_scheduler])
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
#plot_model_history(model_info)
# compute test accuracy
#print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, callbacks=[<keras.ca..., steps_per_epoch=390, epochs=100)`
#   del sys.path[0]
# W0623 03:17:57.868324 140463527647104 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/100
# Learning rate (from LearningRateScheduler):  0.001
# 390/390 [==============================] - 116s 296ms/step - loss: 1.3769 - acc: 0.5031 - val_loss: 1.1542 - val_acc: 0.5885
#
# Epoch 00001: val_acc improved from -inf to 0.58850, saving model to /content/gdrive/My Drive/Assignment7B:001-val-acc:0.589.hdf5
# Epoch 2/100
# Learning rate (from LearningRateScheduler):  0.001
# 390/390 [==============================] - 109s 280ms/step - loss: 0.9283 - acc: 0.6722 - val_loss: 1.2356 - val_acc: 0.6076
#
# Epoch 00002: val_acc improved from 0.58850 to 0.60760, saving model to /content/gdrive/My Drive/Assignment7B:002-val-acc:0.608.hdf5
# Epoch 3/100
# Learning rate (from LearningRateScheduler):  0.001
# 390/390 [==============================] - 108s 276ms/step - loss: 0.6854 - acc: 0.7605 - val_loss: 0.8334 - val_acc: 0.7140
#
# Epoch 00003: val_acc improved from 0.60760 to 0.71400, saving model to /content/gdrive/My Drive/Assignment7B:003-val-acc:0.714.hdf5
# Epoch 4/100
# Learning rate (from LearningRateScheduler):  0.001
# 390/390 [==============================] - 108s 276ms/step - loss: 0.5016 - acc: 0.8255 - val_loss: 0.8364 - val_acc: 0.7344
#
# Epoch 00004: val_acc improved from 0.71400 to 0.73440, saving model to /content/gdrive/My Drive/Assignment7B:004-val-acc:0.734.hdf5
# Epoch 5/100
# Learning rate (from LearningRateScheduler):  0.001
# 390/390 [==============================] - 108s 276ms/step - loss: 0.3288 - acc: 0.8860 - val_loss: 0.9072 - val_acc: 0.7236
#
# Epoch 00005: val_acc did not improve from 0.73440
# Epoch 6/100
# Learning rate (from LearningRateScheduler):  0.001
# 390/390 [==============================] - 108s 276ms/step - loss: 0.1819 - acc: 0.9382 - val_loss: 1.0193 - val_acc: 0.7327
#
# Epoch 00006: val_acc did not improve from 0.73440
# Epoch 7/100
# Learning rate (from LearningRateScheduler):  0.001
# 390/390 [==============================] - 108s 276ms/step - loss: 0.1207 - acc: 0.9581 - val_loss: 1.2038 - val_acc: 0.7315
#
# Epoch 00007: val_acc did not improve from 0.73440
# Epoch 8/100
# Learning rate (from LearningRateScheduler):  0.001
# 390/390 [==============================] - 108s 276ms/step - loss: 0.0881 - acc: 0.9687 - val_loss: 1.3693 - val_acc: 0.7205
#
# Epoch 00008: val_acc did not improve from 0.73440
# Epoch 9/100
# Learning rate (from LearningRateScheduler):  0.001
# 390/390 [==============================] - 108s 276ms/step - loss: 0.0948 - acc: 0.9662 - val_loss: 1.3883 - val_acc: 0.7243
#
# Epoch 00009: val_acc did not improve from 0.73440
# Epoch 10/100
# Learning rate (from LearningRateScheduler):  0.001
# 390/390 [==============================] - 107s 276ms/step - loss: 0.0821 - acc: 0.9720 - val_loss: 1.5034 - val_acc: 0.7109
#
# Epoch 00010: val_acc did not improve from 0.73440
# Epoch 11/100
# Learning rate (from LearningRateScheduler):  0.001
# 390/390 [==============================] - 107s 276ms/step - loss: 0.0804 - acc: 0.9720 - val_loss: 1.5923 - val_acc: 0.7136
#
# Epoch 00011: val_acc did not improve from 0.73440
# Epoch 12/100
# Learning rate (from LearningRateScheduler):  0.001
# 390/390 [==============================] - 108s 276ms/step - loss: 0.0660 - acc: 0.9773 - val_loss: 1.8322 - val_acc: 0.7106
#
# Epoch 00012: val_acc did not improve from 0.73440
# Epoch 13/100
# Learning rate (from LearningRateScheduler):  0.001
# 390/390 [==============================] - 107s 276ms/step - loss: 0.0699 - acc: 0.9767 - val_loss: 1.8083 - val_acc: 0.7123
#
# Epoch 00013: val_acc did not improve from 0.73440
# Epoch 14/100
# Learning rate (from LearningRateScheduler):  0.001
# 390/390 [==============================] - 107s 275ms/step - loss: 0.0692 - acc: 0.9767 - val_loss: 1.7962 - val_acc: 0.7103
#
# Epoch 00014: val_acc did not improve from 0.73440
# Epoch 15/100
# Learning rate (from LearningRateScheduler):  0.001
# 390/390 [==============================] - 107s 275ms/step - loss: 0.0794 - acc: 0.9734 - val_loss: 1.7967 - val_acc: 0.7121
#
# Epoch 00015: val_acc did not improve from 0.73440
# Epoch 16/100
# Learning rate (from LearningRateScheduler):  0.001
# 390/390 [==============================] - 108s 276ms/step - loss: 0.0565 - acc: 0.9808 - val_loss: 1.8156 - val_acc: 0.7280
#
# Epoch 00016: val_acc did not improve from 0.73440
# Epoch 17/100
# Learning rate (from LearningRateScheduler):  0.001
# 390/390 [==============================] - 107s 275ms/step - loss: 0.0468 - acc: 0.9840 - val_loss: 2.0039 - val_acc: 0.7141
#
# Epoch 00017: val_acc did not improve from 0.73440
# Epoch 18/100
# Learning rate (from LearningRateScheduler):  0.001
# 390/390 [==============================] - 107s 275ms/step - loss: 0.0622 - acc: 0.9797 - val_loss: 2.2419 - val_acc: 0.6860
#
# Epoch 00018: val_acc did not improve from 0.73440
# Epoch 19/100
# Learning rate (from LearningRateScheduler):  0.001
# 390/390 [==============================] - 107s 275ms/step - loss: 0.0679 - acc: 0.9789 - val_loss: 1.8000 - val_acc: 0.7385
#
# Epoch 00019: val_acc improved from 0.73440 to 0.73850, saving model to /content/gdrive/My Drive/Assignment7B:019-val-acc:0.739.hdf5
# Epoch 20/100
# Learning rate (from LearningRateScheduler):  0.001
# 390/390 [==============================] - 107s 275ms/step - loss: 0.0549 - acc: 0.9827 - val_loss: 2.0017 - val_acc: 0.7266
#
# Epoch 00020: val_acc did not improve from 0.73850
# Epoch 21/100
# Learning rate (from LearningRateScheduler):  0.001
# 390/390 [==============================] - 107s 275ms/step - loss: 0.0465 - acc: 0.9848 - val_loss: 1.8788 - val_acc: 0.7412
#
# Epoch 00021: val_acc improved from 0.73850 to 0.74120, saving model to /content/gdrive/My Drive/Assignment7B:021-val-acc:0.741.hdf5
# Epoch 22/100
# Learning rate (from LearningRateScheduler):  0.0005
# 390/390 [==============================] - 107s 275ms/step - loss: 0.0141 - acc: 0.9953 - val_loss: 1.8111 - val_acc: 0.7619
#
# Epoch 00022: val_acc improved from 0.74120 to 0.76190, saving model to /content/gdrive/My Drive/Assignment7B:022-val-acc:0.762.hdf5
# Epoch 23/100
# Learning rate (from LearningRateScheduler):  0.0005
# 390/390 [==============================] - 107s 275ms/step - loss: 0.0028 - acc: 0.9991 - val_loss: 1.7473 - val_acc: 0.7706
#
# Epoch 00023: val_acc improved from 0.76190 to 0.77060, saving model to /content/gdrive/My Drive/Assignment7B:023-val-acc:0.771.hdf5
# Epoch 24/100
# Learning rate (from LearningRateScheduler):  0.0005
# 390/390 [==============================] - 107s 275ms/step - loss: 5.4060e-04 - acc: 1.0000 - val_loss: 1.7370 - val_acc: 0.7718
#
# Epoch 00024: val_acc improved from 0.77060 to 0.77180, saving model to /content/gdrive/My Drive/Assignment7B:024-val-acc:0.772.hdf5
# Epoch 25/100
# Learning rate (from LearningRateScheduler):  0.0005
# 390/390 [==============================] - 107s 275ms/step - loss: 1.9108e-04 - acc: 1.0000 - val_loss: 1.7454 - val_acc: 0.7725
#
# Epoch 00025: val_acc improved from 0.77180 to 0.77250, saving model to /content/gdrive/My Drive/Assignment7B:025-val-acc:0.772.hdf5
# Epoch 26/100
# Learning rate (from LearningRateScheduler):  0.0005
# 390/390 [==============================] - 107s 275ms/step - loss: 1.1678e-04 - acc: 1.0000 - val_loss: 1.7475 - val_acc: 0.7726
#
# Epoch 00026: val_acc improved from 0.77250 to 0.77260, saving model to /content/gdrive/My Drive/Assignment7B:026-val-acc:0.773.hdf5
# Epoch 27/100
# Learning rate (from LearningRateScheduler):  0.0005
# 390/390 [==============================] - 107s 275ms/step - loss: 8.0779e-05 - acc: 1.0000 - val_loss: 1.7485 - val_acc: 0.7735
#
# Epoch 00027: val_acc improved from 0.77260 to 0.77350, saving model to /content/gdrive/My Drive/Assignment7B:027-val-acc:0.773.hdf5
# Epoch 28/100
# Learning rate (from LearningRateScheduler):  0.0005
# 390/390 [==============================] - 107s 275ms/step - loss: 6.3629e-05 - acc: 1.0000 - val_loss: 1.7555 - val_acc: 0.7731
#
# Epoch 00028: val_acc did not improve from 0.77350
# Epoch 29/100
# Learning rate (from LearningRateScheduler):  0.0005
# 390/390 [==============================] - 107s 275ms/step - loss: 5.7412e-05 - acc: 1.0000 - val_loss: 1.7634 - val_acc: 0.7740
#
# Epoch 00029: val_acc improved from 0.77350 to 0.77400, saving model to /content/gdrive/My Drive/Assignment7B:029-val-acc:0.774.hdf5
# Epoch 30/100
# Learning rate (from LearningRateScheduler):  0.0005
# 390/390 [==============================] - 107s 275ms/step - loss: 5.0918e-05 - acc: 1.0000 - val_loss: 1.7645 - val_acc: 0.7731
#
# Epoch 00030: val_acc did not improve from 0.77400
# Epoch 31/100
# Learning rate (from LearningRateScheduler):  0.0005
# 390/390 [==============================] - 107s 275ms/step - loss: 3.5486e-05 - acc: 1.0000 - val_loss: 1.7698 - val_acc: 0.7736
#
# Epoch 00031: val_acc did not improve from 0.77400
# Epoch 32/100
# Learning rate (from LearningRateScheduler):  0.0005
# 390/390 [==============================] - 107s 275ms/step - loss: 3.0593e-05 - acc: 1.0000 - val_loss: 1.7766 - val_acc: 0.7744
#
# Epoch 00032: val_acc improved from 0.77400 to 0.77440, saving model to /content/gdrive/My Drive/Assignment7B:032-val-acc:0.774.hdf5
# Epoch 33/100
# Learning rate (from LearningRateScheduler):  0.0005
# 390/390 [==============================] - 107s 275ms/step - loss: 2.4495e-05 - acc: 1.0000 - val_loss: 1.7811 - val_acc: 0.7742
#
# Epoch 00033: val_acc did not improve from 0.77440
# Epoch 34/100
# Learning rate (from LearningRateScheduler):  0.0005
# 390/390 [==============================] - 107s 275ms/step - loss: 1.9674e-05 - acc: 1.0000 - val_loss: 1.7864 - val_acc: 0.7758
#
# Epoch 00034: val_acc improved from 0.77440 to 0.77580, saving model to /content/gdrive/My Drive/Assignment7B:034-val-acc:0.776.hdf5
# Epoch 35/100
# Learning rate (from LearningRateScheduler):  0.0005
# 390/390 [==============================] - 108s 276ms/step - loss: 1.8771e-05 - acc: 1.0000 - val_loss: 1.7953 - val_acc: 0.7765
#
# Epoch 00035: val_acc improved from 0.77580 to 0.77650, saving model to /content/gdrive/My Drive/Assignment7B:035-val-acc:0.776.hdf5
# Epoch 36/100
# Learning rate (from LearningRateScheduler):  0.0005
# 390/390 [==============================] - 107s 276ms/step - loss: 1.5381e-05 - acc: 1.0000 - val_loss: 1.8012 - val_acc: 0.7755
#
# Epoch 00036: val_acc did not improve from 0.77650
# Epoch 37/100
# Learning rate (from LearningRateScheduler):  0.0005
# 390/390 [==============================] - 108s 276ms/step - loss: 1.3542e-05 - acc: 1.0000 - val_loss: 1.8071 - val_acc: 0.7766
#
# Epoch 00037: val_acc improved from 0.77650 to 0.77660, saving model to /content/gdrive/My Drive/Assignment7B:037-val-acc:0.777.hdf5
# Epoch 38/100
# Learning rate (from LearningRateScheduler):  0.0005
# 390/390 [==============================] - 107s 275ms/step - loss: 1.0547e-05 - acc: 1.0000 - val_loss: 1.8119 - val_acc: 0.7788
#
# Epoch 00038: val_acc improved from 0.77660 to 0.77880, saving model to /content/gdrive/My Drive/Assignment7B:038-val-acc:0.779.hdf5
# Epoch 39/100
# Learning rate (from LearningRateScheduler):  0.0005
# 390/390 [==============================] - 107s 275ms/step - loss: 8.3794e-06 - acc: 1.0000 - val_loss: 1.8199 - val_acc: 0.7776
#
# Epoch 00039: val_acc did not improve from 0.77880
# Epoch 40/100
# Learning rate (from LearningRateScheduler):  0.0005
# 390/390 [==============================] - 107s 274ms/step - loss: 8.4104e-06 - acc: 1.0000 - val_loss: 1.8284 - val_acc: 0.7774
#
# Epoch 00040: val_acc did not improve from 0.77880
# Epoch 41/100
# Learning rate (from LearningRateScheduler):  0.0005
# 390/390 [==============================] - 107s 274ms/step - loss: 6.7519e-06 - acc: 1.0000 - val_loss: 1.8369 - val_acc: 0.7786
#
# Epoch 00041: val_acc did not improve from 0.77880
# Epoch 42/100
# Learning rate (from LearningRateScheduler):  0.0001
# 390/390 [==============================] - 107s 274ms/step - loss: 4.7271e-06 - acc: 1.0000 - val_loss: 1.8371 - val_acc: 0.7785
#
# Epoch 00042: val_acc did not improve from 0.77880
# Epoch 43/100
# Learning rate (from LearningRateScheduler):  0.0001
# 390/390 [==============================] - 107s 274ms/step - loss: 4.3995e-06 - acc: 1.0000 - val_loss: 1.8399 - val_acc: 0.7779
#
# Epoch 00043: val_acc did not improve from 0.77880
# Epoch 44/100
# Learning rate (from LearningRateScheduler):  0.0001
# 390/390 [==============================] - 107s 274ms/step - loss: 4.5021e-06 - acc: 1.0000 - val_loss: 1.8400 - val_acc: 0.7793
#
# Epoch 00044: val_acc improved from 0.77880 to 0.77930, saving model to /content/gdrive/My Drive/Assignment7B:044-val-acc:0.779.hdf5
# Epoch 45/100
# Learning rate (from LearningRateScheduler):  0.0001
# 390/390 [==============================] - 107s 274ms/step - loss: 4.3738e-06 - acc: 1.0000 - val_loss: 1.8422 - val_acc: 0.7786
#
# Epoch 00045: val_acc did not improve from 0.77930
# Epoch 46/100
# Learning rate (from LearningRateScheduler):  0.0001
# 390/390 [==============================] - 107s 275ms/step - loss: 3.9489e-06 - acc: 1.0000 - val_loss: 1.8440 - val_acc: 0.7791
#
# Epoch 00046: val_acc did not improve from 0.77930
# Epoch 47/100
# Learning rate (from LearningRateScheduler):  0.0001
# 390/390 [==============================] - 108s 276ms/step - loss: 4.6677e-06 - acc: 1.0000 - val_loss: 1.8561 - val_acc: 0.7788
#
# Epoch 00047: val_acc did not improve from 0.77930
# Epoch 48/100
# Learning rate (from LearningRateScheduler):  0.0001
# 390/390 [==============================] - 108s 276ms/step - loss: 8.5321e-04 - acc: 0.9998 - val_loss: 1.9249 - val_acc: 0.7644
#
# Epoch 00048: val_acc did not improve from 0.77930
# Epoch 49/100
# Learning rate (from LearningRateScheduler):  0.0001
# 390/390 [==============================] - 108s 277ms/step - loss: 1.9608e-04 - acc: 1.0000 - val_loss: 1.8742 - val_acc: 0.7734
#
# Epoch 00049: val_acc did not improve from 0.77930
# Epoch 50/100
# Learning rate (from LearningRateScheduler):  0.0001
# 390/390 [==============================] - 108s 276ms/step - loss: 3.9538e-05 - acc: 1.0000 - val_loss: 1.8691 - val_acc: 0.7752
#
# Epoch 00050: val_acc did not improve from 0.77930
# Epoch 51/100
# Learning rate (from LearningRateScheduler):  0.0001
# 390/390 [==============================] - 108s 276ms/step - loss: 2.2877e-05 - acc: 1.0000 - val_loss: 1.8688 - val_acc: 0.7751
#
# Epoch 00051: val_acc did not improve from 0.77930
# Epoch 52/100
# Learning rate (from LearningRateScheduler):  0.0001
# 390/390 [==============================] - 108s 276ms/step - loss: 1.7160e-05 - acc: 1.0000 - val_loss: 1.8693 - val_acc: 0.7756
#
# Epoch 00052: val_acc did not improve from 0.77930
# Epoch 53/100
# Learning rate (from LearningRateScheduler):  0.0001
# 390/390 [==============================] - 108s 276ms/step - loss: 1.5686e-05 - acc: 1.0000 - val_loss: 1.8699 - val_acc: 0.7758
#
# Epoch 00053: val_acc did not improve from 0.77930
# Epoch 54/100
# Learning rate (from LearningRateScheduler):  0.0001
# 390/390 [==============================] - 108s 276ms/step - loss: 1.1918e-05 - acc: 1.0000 - val_loss: 1.8700 - val_acc: 0.7763
#
# Epoch 00054: val_acc did not improve from 0.77930
# Epoch 55/100
# Learning rate (from LearningRateScheduler):  0.0001
# 390/390 [==============================] - 108s 276ms/step - loss: 1.2186e-05 - acc: 1.0000 - val_loss: 1.8792 - val_acc: 0.7760
#
# Epoch 00055: val_acc did not improve from 0.77930
# Epoch 56/100
# Learning rate (from LearningRateScheduler):  0.0001
# 390/390 [==============================] - 108s 276ms/step - loss: 9.3540e-06 - acc: 1.0000 - val_loss: 1.8778 - val_acc: 0.7763
#
# Epoch 00056: val_acc did not improve from 0.77930
# Epoch 57/100
# Learning rate (from LearningRateScheduler):  0.0001
# 390/390 [==============================] - 108s 277ms/step - loss: 7.3493e-06 - acc: 1.0000 - val_loss: 1.8799 - val_acc: 0.7769
#
# Epoch 00057: val_acc did not improve from 0.77930
# Epoch 58/100
# Learning rate (from LearningRateScheduler):  0.0001
# 390/390 [==============================] - 108s 276ms/step - loss: 6.3899e-06 - acc: 1.0000 - val_loss: 1.8816 - val_acc: 0.7778
#
# Epoch 00058: val_acc did not improve from 0.77930
# Epoch 59/100
# Learning rate (from LearningRateScheduler):  0.0001
# 390/390 [==============================] - 108s 276ms/step - loss: 5.7339e-06 - acc: 1.0000 - val_loss: 1.8851 - val_acc: 0.7779
#
# Epoch 00059: val_acc did not improve from 0.77930
# Epoch 60/100
# Learning rate (from LearningRateScheduler):  0.0001
# 390/390 [==============================] - 108s 276ms/step - loss: 5.1871e-06 - acc: 1.0000 - val_loss: 1.8898 - val_acc: 0.7786
#
# Epoch 00060: val_acc did not improve from 0.77930
# Epoch 61/100
# Learning rate (from LearningRateScheduler):  0.0001
# 390/390 [==============================] - 108s 276ms/step - loss: 4.2680e-06 - acc: 1.0000 - val_loss: 1.8926 - val_acc: 0.7781
#
# Epoch 00061: val_acc did not improve from 0.77930
# Epoch 62/100
# Learning rate (from LearningRateScheduler):  5e-05
# 390/390 [==============================] - 108s 276ms/step - loss: 3.6824e-06 - acc: 1.0000 - val_loss: 1.8920 - val_acc: 0.7782
#
# Epoch 00062: val_acc did not improve from 0.77930
# Epoch 63/100
# Learning rate (from LearningRateScheduler):  5e-05
# 390/390 [==============================] - 108s 276ms/step - loss: 3.3647e-06 - acc: 1.0000 - val_loss: 1.8924 - val_acc: 0.7784
#
# Epoch 00063: val_acc did not improve from 0.77930
# Epoch 64/100
# Learning rate (from LearningRateScheduler):  5e-05
# 390/390 [==============================] - 108s 276ms/step - loss: 3.2154e-06 - acc: 1.0000 - val_loss: 1.8969 - val_acc: 0.7781
#
# Epoch 00064: val_acc did not improve from 0.77930
# Epoch 65/100
# Learning rate (from LearningRateScheduler):  5e-05
# 390/390 [==============================] - 108s 276ms/step - loss: 3.2574e-06 - acc: 1.0000 - val_loss: 1.9009 - val_acc: 0.7782
#
# Epoch 00065: val_acc did not improve from 0.77930
# Epoch 66/100
# Learning rate (from LearningRateScheduler):  5e-05
# 390/390 [==============================] - 108s 276ms/step - loss: 2.9738e-06 - acc: 1.0000 - val_loss: 1.9034 - val_acc: 0.7780
#
# Epoch 00066: val_acc did not improve from 0.77930
# Epoch 67/100
# Learning rate (from LearningRateScheduler):  5e-05
# 390/390 [==============================] - 108s 276ms/step - loss: 2.2627e-06 - acc: 1.0000 - val_loss: 1.9026 - val_acc: 0.7785
#
# Epoch 00067: val_acc did not improve from 0.77930
# Epoch 68/100
# Learning rate (from LearningRateScheduler):  5e-05
# 390/390 [==============================] - 107s 276ms/step - loss: 2.0821e-06 - acc: 1.0000 - val_loss: 1.9045 - val_acc: 0.7792
#
# Epoch 00068: val_acc did not improve from 0.77930
# Epoch 69/100
# Learning rate (from LearningRateScheduler):  5e-05
# 390/390 [==============================] - 108s 276ms/step - loss: 2.8096e-06 - acc: 1.0000 - val_loss: 1.9092 - val_acc: 0.7785
#
# Epoch 00069: val_acc did not improve from 0.77930
# Epoch 70/100
# Learning rate (from LearningRateScheduler):  5e-05
# 390/390 [==============================] - 108s 276ms/step - loss: 2.1262e-06 - acc: 1.0000 - val_loss: 1.9212 - val_acc: 0.7781
#
# Epoch 00070: val_acc did not improve from 0.77930
# Epoch 71/100
# Learning rate (from LearningRateScheduler):  5e-05
# 390/390 [==============================] - 108s 276ms/step - loss: 1.9391e-06 - acc: 1.0000 - val_loss: 1.9238 - val_acc: 0.7787
#
# Epoch 00071: val_acc did not improve from 0.77930
# Epoch 72/100
# Learning rate (from LearningRateScheduler):  5e-05
# 390/390 [==============================] - 108s 276ms/step - loss: 1.4653e-06 - acc: 1.0000 - val_loss: 1.9235 - val_acc: 0.7789
#
# Epoch 00072: val_acc did not improve from 0.77930
# Epoch 73/100
# Learning rate (from LearningRateScheduler):  5e-05
# 390/390 [==============================] - 108s 276ms/step - loss: 1.3092e-06 - acc: 1.0000 - val_loss: 1.9261 - val_acc: 0.7795
#
# Epoch 00073: val_acc improved from 0.77930 to 0.77950, saving model to /content/gdrive/My Drive/Assignment7B:073-val-acc:0.779.hdf5
# Epoch 74/100
# Learning rate (from LearningRateScheduler):  5e-05
# 390/390 [==============================] - 108s 276ms/step - loss: 1.4040e-06 - acc: 1.0000 - val_loss: 1.9299 - val_acc: 0.7782
#
# Epoch 00074: val_acc did not improve from 0.77950
# Epoch 75/100
# Learning rate (from LearningRateScheduler):  5e-05
# 390/390 [==============================] - 108s 276ms/step - loss: 1.1227e-06 - acc: 1.0000 - val_loss: 1.9359 - val_acc: 0.7794
#
# Epoch 00075: val_acc did not improve from 0.77950
# Epoch 76/100
# Learning rate (from LearningRateScheduler):  5e-05
# 390/390 [==============================] - 108s 277ms/step - loss: 9.5605e-07 - acc: 1.0000 - val_loss: 1.9350 - val_acc: 0.7799
#
# Epoch 00076: val_acc improved from 0.77950 to 0.77990, saving model to /content/gdrive/My Drive/Assignment7B:076-val-acc:0.780.hdf5
# Epoch 77/100
# Learning rate (from LearningRateScheduler):  5e-05
# 390/390 [==============================] - 108s 276ms/step - loss: 9.6907e-07 - acc: 1.0000 - val_loss: 1.9453 - val_acc: 0.7801
#
# Epoch 00077: val_acc improved from 0.77990 to 0.78010, saving model to /content/gdrive/My Drive/Assignment7B:077-val-acc:0.780.hdf5
# Epoch 78/100
# Learning rate (from LearningRateScheduler):  5e-05
# 390/390 [==============================] - 107s 276ms/step - loss: 7.5542e-07 - acc: 1.0000 - val_loss: 1.9469 - val_acc: 0.7805
#
# Epoch 00078: val_acc improved from 0.78010 to 0.78050, saving model to /content/gdrive/My Drive/Assignment7B:078-val-acc:0.780.hdf5
# Epoch 79/100
# Learning rate (from LearningRateScheduler):  5e-05
# 390/390 [==============================] - 108s 276ms/step - loss: 6.1777e-07 - acc: 1.0000 - val_loss: 1.9502 - val_acc: 0.7809
#
# Epoch 00079: val_acc improved from 0.78050 to 0.78090, saving model to /content/gdrive/My Drive/Assignment7B:079-val-acc:0.781.hdf5
# Epoch 80/100
# Learning rate (from LearningRateScheduler):  5e-05
# 390/390 [==============================] - 108s 276ms/step - loss: 6.0005e-07 - acc: 1.0000 - val_loss: 1.9573 - val_acc: 0.7812
#
# Epoch 00080: val_acc improved from 0.78090 to 0.78120, saving model to /content/gdrive/My Drive/Assignment7B:080-val-acc:0.781.hdf5
# Epoch 81/100
# Learning rate (from LearningRateScheduler):  5e-05
# 390/390 [==============================] - 108s 276ms/step - loss: 5.5051e-07 - acc: 1.0000 - val_loss: 1.9558 - val_acc: 0.7810
#
# Epoch 00081: val_acc did not improve from 0.78120
# Epoch 82/100
# Learning rate (from LearningRateScheduler):  1e-05
# 390/390 [==============================] - 108s 276ms/step - loss: 5.3098e-07 - acc: 1.0000 - val_loss: 1.9631 - val_acc: 0.7804
#
# Epoch 00082: val_acc did not improve from 0.78120
# Epoch 83/100
# Learning rate (from LearningRateScheduler):  1e-05
# 390/390 [==============================] - 108s 276ms/step - loss: 4.7873e-07 - acc: 1.0000 - val_loss: 1.9643 - val_acc: 0.7805
#
# Epoch 00083: val_acc did not improve from 0.78120
# Epoch 84/100
# Learning rate (from LearningRateScheduler):  1e-05
# 390/390 [==============================] - 108s 276ms/step - loss: 5.0481e-07 - acc: 1.0000 - val_loss: 1.9649 - val_acc: 0.7819
#
# Epoch 00084: val_acc improved from 0.78120 to 0.78190, saving model to /content/gdrive/My Drive/Assignment7B:084-val-acc:0.782.hdf5
# Epoch 85/100
# Learning rate (from LearningRateScheduler):  1e-05
# 390/390 [==============================] - 108s 277ms/step - loss: 4.6903e-07 - acc: 1.0000 - val_loss: 1.9633 - val_acc: 0.7822
#
# Epoch 00085: val_acc improved from 0.78190 to 0.78220, saving model to /content/gdrive/My Drive/Assignment7B:085-val-acc:0.782.hdf5
# Epoch 86/100
# Learning rate (from LearningRateScheduler):  1e-05
# 390/390 [==============================] - 108s 277ms/step - loss: 4.1337e-07 - acc: 1.0000 - val_loss: 1.9661 - val_acc: 0.7828
#
# Epoch 00086: val_acc improved from 0.78220 to 0.78280, saving model to /content/gdrive/My Drive/Assignment7B:086-val-acc:0.783.hdf5
# Epoch 87/100
# Learning rate (from LearningRateScheduler):  1e-05
# 390/390 [==============================] - 108s 276ms/step - loss: 4.3138e-07 - acc: 1.0000 - val_loss: 1.9664 - val_acc: 0.7812
#
# Epoch 00087: val_acc did not improve from 0.78280
# Epoch 88/100
# Learning rate (from LearningRateScheduler):  1e-05
# 390/390 [==============================] - 108s 277ms/step - loss: 4.4919e-07 - acc: 1.0000 - val_loss: 1.9721 - val_acc: 0.7808
#
# Epoch 00088: val_acc did not improve from 0.78280
# Epoch 89/100
# Learning rate (from LearningRateScheduler):  1e-05
# 390/390 [==============================] - 108s 277ms/step - loss: 4.0658e-07 - acc: 1.0000 - val_loss: 1.9712 - val_acc: 0.7818
#
# Epoch 00089: val_acc did not improve from 0.78280
# Epoch 90/100
# Learning rate (from LearningRateScheduler):  1e-05
# 390/390 [==============================] - 108s 276ms/step - loss: 3.8166e-07 - acc: 1.0000 - val_loss: 1.9737 - val_acc: 0.7819
#
# Epoch 00090: val_acc did not improve from 0.78280
# Epoch 91/100
# Learning rate (from LearningRateScheduler):  1e-05
# 390/390 [==============================] - 107s 275ms/step - loss: 3.9364e-07 - acc: 1.0000 - val_loss: 1.9740 - val_acc: 0.7831
#
# Epoch 00091: val_acc improved from 0.78280 to 0.78310, saving model to /content/gdrive/My Drive/Assignment7B:091-val-acc:0.783.hdf5
# Epoch 92/100
# Learning rate (from LearningRateScheduler):  1e-05
# 390/390 [==============================] - 107s 275ms/step - loss: 3.6558e-07 - acc: 1.0000 - val_loss: 1.9749 - val_acc: 0.7820
#
# Epoch 00092: val_acc did not improve from 0.78310
# Epoch 93/100
# Learning rate (from LearningRateScheduler):  1e-05
# 390/390 [==============================] - 107s 275ms/step - loss: 3.6119e-07 - acc: 1.0000 - val_loss: 1.9761 - val_acc: 0.7829
#
# Epoch 00093: val_acc did not improve from 0.78310
# Epoch 94/100
# Learning rate (from LearningRateScheduler):  1e-05
# 390/390 [==============================] - 107s 274ms/step - loss: 3.5498e-07 - acc: 1.0000 - val_loss: 1.9781 - val_acc: 0.7826
#
# Epoch 00094: val_acc did not improve from 0.78310
# Epoch 95/100
# Learning rate (from LearningRateScheduler):  1e-05
# 390/390 [==============================] - 107s 275ms/step - loss: 3.2261e-07 - acc: 1.0000 - val_loss: 1.9828 - val_acc: 0.7819
#
# Epoch 00095: val_acc did not improve from 0.78310
# Epoch 96/100
# Learning rate (from LearningRateScheduler):  1e-05
# 390/390 [==============================] - 107s 274ms/step - loss: 3.1678e-07 - acc: 1.0000 - val_loss: 1.9824 - val_acc: 0.7834
#
# Epoch 00096: val_acc improved from 0.78310 to 0.78340, saving model to /content/gdrive/My Drive/Assignment7B:096-val-acc:0.783.hdf5
# Epoch 97/100
# Learning rate (from LearningRateScheduler):  1e-05
# 390/390 [==============================] - 107s 274ms/step - loss: 3.3179e-07 - acc: 1.0000 - val_loss: 1.9870 - val_acc: 0.7823
#
# Epoch 00097: val_acc did not improve from 0.78340
# Epoch 98/100
# Learning rate (from LearningRateScheduler):  1e-05
# 390/390 [==============================] - 107s 274ms/step - loss: 3.5815e-07 - acc: 1.0000 - val_loss: 1.9844 - val_acc: 0.7827
#
# Epoch 00098: val_acc did not improve from 0.78340
# Epoch 99/100
# Learning rate (from LearningRateScheduler):  1e-05
# 390/390 [==============================] - 107s 274ms/step - loss: 3.2197e-07 - acc: 1.0000 - val_loss: 1.9889 - val_acc: 0.7822
#
# Epoch 00099: val_acc did not improve from 0.78340
# Epoch 100/100
# Learning rate (from LearningRateScheduler):  1e-05
# 390/390 [==============================] - 107s 274ms/step - loss: 2.9395e-07 - acc: 1.0000 - val_loss: 1.9900 - val_acc: 0.7819
#
# Epoch 00100: val_acc did not improve from 0.78340
# Model took 10766.81 seconds to train
