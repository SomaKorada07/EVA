# %%
from keras import backend as K
import time
import matplotlib.pyplot as plt

# Importing NumPy (Numerical Python) which is a library consisting of multidimensional array objects and a collection of routines for processing those arrays. It also gives an alias to the library.
import numpy as np

% matplotlib inline
np.random.seed(2017) 

# There are two main types of models available in Keras: the Sequential model and the Model class used with the functional API.
# Sequential model is a linear stack of layers. Importing Sequential model from Keras.
from keras.models import Sequential

# Importing different layers from Keras.
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dense, Dropout
from keras.layers.normalization import BatchNormalization

# Importing the utils library of Keras.
from keras.utils import np_utils

# Importing the callbacks of Keras.
from keras.callbacks import ModelCheckpoint

from keras.preprocessing import image
import cv2
import sys
import pandas as pd
# Out:
# Using TensorFlow backend.

# %%
# CIFAR10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images. Importing CIFAR10 dataset from Keras.
from keras.datasets import cifar10

# Loading the CIFAR10 60000 Training and 10000 Test data into respective numpy arrays
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()

# Setting the count, number of channels, rows and columns of training images
num_train, img_channels, img_rows, img_cols =  train_features.shape

# Setting the count of test images
num_test, _, _, _ =  test_features.shape

# Setting number of classes (10)
num_classes = len(np.unique(train_labels))

# %%
# Setting up the class names
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']

# Plotting an image from each of the 10 classes
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %%
# Custom function to test accuracy
def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %%
# Pixel normalization for training images
train_features = train_features.astype('float32')/255

# Pixel normalization for test images
test_features = test_features.astype('float32')/255

# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %% [markdown]
# # CHANGED MODEL
#
#
# *   Reduced the number of kernels being used.
# *   Reduced the Receptive Field at the last layer from 64 to 32.
# *   Changed the dropout rate to 0.125 from 0.25.
# *   Removed Dense layer.
# *   Removed Dropout at the last layer.
# *   Removed "relu" activation at the last layer.
# *   Added Batch Normalization before Convolution and Activation layers.
# *   Followed the increase in number of kernels and then decrease by using 1x1 and MaxPooling and then again increase type of architecture (cake pattern).

# %%
# Define the model
model = Sequential()
model.add(Convolution2D(32, 3, 3, border_mode='same', input_shape=(32, 32, 3))) #32,32; 3
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(Dropout(0.125))
model.add(BatchNormalization())
model.add(Convolution2D(48, 3, 3, border_mode='same',)) #32,32; 5
model.add(Activation('relu'))

model.add(BatchNormalization())
model.add(Convolution2D(32, 1, 1)) #32,32; 5
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2))) #16,16; 10

model.add(Dropout(0.125))
model.add(BatchNormalization())
model.add(Convolution2D(48, 3, 3, border_mode='same')) #16,16; 12
model.add(Activation('relu'))

model.add(Dropout(0.125))
model.add(BatchNormalization())
model.add(Convolution2D(96, 3, 3, border_mode='same',)) #16,16; 14
model.add(Activation('relu'))

model.add(BatchNormalization())
model.add(Convolution2D(32, 1, 1)) #16,16; 14
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2))) #8,8; 28

model.add(Dropout(0.125))
model.add(BatchNormalization())
model.add(Convolution2D(48, 3, 3, border_mode='same')) #8,8; 30
model.add(Activation('relu'))

model.add(Dropout(0.125))
model.add(BatchNormalization())
model.add(Convolution2D(96, 3, 3, border_mode='same')) #8,8; 32
model.add(Activation('relu'))

model.add(BatchNormalization())
model.add(Convolution2D(10, 1, 1)) #8,8; 32
model.add(Activation('relu'))
model.add(Convolution2D(10, 8, 8)) #1,1; 32

model.add(Flatten())
model.add(Activation('softmax'))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0630 15:19:41.373922 139794148116352 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), input_shape=(32, 32, 3..., padding="same")`
#
# W0630 15:19:41.397420 139794148116352 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0630 15:19:41.400460 139794148116352 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0630 15:19:41.427572 139794148116352 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0630 15:19:41.428459 139794148116352 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0630 15:19:42.184433 139794148116352 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0630 15:19:42.357446 139794148116352 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (3, 3), padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1))`
#   if sys.path[0] == '':
# W0630 15:19:42.540768 139794148116352 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:18: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:23: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(96, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:27: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:33: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:38: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(96, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:42: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (1, 1))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:44: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (8, 8))`

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 48)        13872
# _________________________________________________________________
# activation_2 (Activation)    (None, 32, 32, 48)        0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32, 32, 48)        192
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 32)        1568
# _________________________________________________________________
# activation_3 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16, 16, 32)        0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16, 16, 32)        128
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 48)        13872
# _________________________________________________________________
# activation_4 (Activation)    (None, 16, 16, 48)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 16, 16, 48)        0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 16, 16, 48)        192
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 96)        41568
# _________________________________________________________________
# activation_5 (Activation)    (None, 16, 16, 96)        0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 16, 16, 96)        384
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 32)        3104
# _________________________________________________________________
# activation_6 (Activation)    (None, 16, 16, 32)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 8, 8, 32)          0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 8, 8, 32)          128
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 48)          13872
# _________________________________________________________________
# activation_7 (Activation)    (None, 8, 8, 48)          0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 8, 8, 48)          0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 8, 8, 48)          192
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 8, 96)          41568
# _________________________________________________________________
# activation_8 (Activation)    (None, 8, 8, 96)          0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 8, 8, 96)          384
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 8, 8, 10)          970
# _________________________________________________________________
# activation_9 (Activation)    (None, 8, 8, 10)          0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 1, 1, 10)          6410
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 10)                0
# _________________________________________________________________
# activation_10 (Activation)   (None, 10)                0
# =================================================================
# Total params: 139,556
# Trainable params: 138,628
# Non-trainable params: 928
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# W0630 11:19:38.471606 140648195389312 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# Mounting the Google Drive to save the weights
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Specifying the path to store the weights
filepath="/content/gdrive/My Drive/Assignment6A_Modified:{epoch:03d}-val_acc:{val_acc:.3f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, save_weights_only=True, mode='max')

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False)


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 100, 
                                 validation_data = (test_features, test_labels), verbose=1,
                                 callbacks=[checkpoint])
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, callbacks=[<keras.ca..., steps_per_epoch=390, epochs=100)`
#   del sys.path[0]
# W0629 18:19:40.350204 140389892335488 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/100
# 390/390 [==============================] - 18s 45ms/step - loss: 1.5601 - acc: 0.4351 - val_loss: 2.1257 - val_acc: 0.3743
#
# Epoch 00001: val_acc improved from -inf to 0.37430, saving model to /content/gdrive/My Drive/Assignment6A_Modified:001-val_acc:0.374.hdf5
# Epoch 2/100
# 390/390 [==============================] - 13s 33ms/step - loss: 1.1691 - acc: 0.5799 - val_loss: 1.1242 - val_acc: 0.6050
#
# Epoch 00002: val_acc improved from 0.37430 to 0.60500, saving model to /content/gdrive/My Drive/Assignment6A_Modified:002-val_acc:0.605.hdf5
# Epoch 3/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.9671 - acc: 0.6561 - val_loss: 0.9878 - val_acc: 0.6527
#
# Epoch 00003: val_acc improved from 0.60500 to 0.65270, saving model to /content/gdrive/My Drive/Assignment6A_Modified:003-val_acc:0.653.hdf5
# Epoch 4/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.8442 - acc: 0.6991 - val_loss: 0.8307 - val_acc: 0.7068
#
# Epoch 00004: val_acc improved from 0.65270 to 0.70680, saving model to /content/gdrive/My Drive/Assignment6A_Modified:004-val_acc:0.707.hdf5
# Epoch 5/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.7623 - acc: 0.7302 - val_loss: 0.7481 - val_acc: 0.7337
#
# Epoch 00005: val_acc improved from 0.70680 to 0.73370, saving model to /content/gdrive/My Drive/Assignment6A_Modified:005-val_acc:0.734.hdf5
# Epoch 6/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.7057 - acc: 0.7512 - val_loss: 0.7850 - val_acc: 0.7237
#
# Epoch 00006: val_acc did not improve from 0.73370
# Epoch 7/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.6690 - acc: 0.7651 - val_loss: 0.7486 - val_acc: 0.7438
#
# Epoch 00007: val_acc improved from 0.73370 to 0.74380, saving model to /content/gdrive/My Drive/Assignment6A_Modified:007-val_acc:0.744.hdf5
# Epoch 8/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.6291 - acc: 0.7792 - val_loss: 0.7067 - val_acc: 0.7548
#
# Epoch 00008: val_acc improved from 0.74380 to 0.75480, saving model to /content/gdrive/My Drive/Assignment6A_Modified:008-val_acc:0.755.hdf5
# Epoch 9/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.5932 - acc: 0.7918 - val_loss: 0.8271 - val_acc: 0.7184
#
# Epoch 00009: val_acc did not improve from 0.75480
# Epoch 10/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.5691 - acc: 0.7996 - val_loss: 0.6271 - val_acc: 0.7860
#
# Epoch 00010: val_acc improved from 0.75480 to 0.78600, saving model to /content/gdrive/My Drive/Assignment6A_Modified:010-val_acc:0.786.hdf5
# Epoch 11/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.5441 - acc: 0.8093 - val_loss: 0.7147 - val_acc: 0.7631
#
# Epoch 00011: val_acc did not improve from 0.78600
# Epoch 12/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.5232 - acc: 0.8155 - val_loss: 0.7049 - val_acc: 0.7612
#
# Epoch 00012: val_acc did not improve from 0.78600
# Epoch 13/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.5068 - acc: 0.8226 - val_loss: 0.6423 - val_acc: 0.7805
#
# Epoch 00013: val_acc did not improve from 0.78600
# Epoch 14/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.4895 - acc: 0.8275 - val_loss: 0.6655 - val_acc: 0.7808
#
# Epoch 00014: val_acc did not improve from 0.78600
# Epoch 15/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.4750 - acc: 0.8314 - val_loss: 0.6206 - val_acc: 0.7903
#
# Epoch 00015: val_acc improved from 0.78600 to 0.79030, saving model to /content/gdrive/My Drive/Assignment6A_Modified:015-val_acc:0.790.hdf5
# Epoch 16/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.4562 - acc: 0.8378 - val_loss: 0.6037 - val_acc: 0.8032
#
# Epoch 00016: val_acc improved from 0.79030 to 0.80320, saving model to /content/gdrive/My Drive/Assignment6A_Modified:016-val_acc:0.803.hdf5
# Epoch 17/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.4441 - acc: 0.8432 - val_loss: 0.5905 - val_acc: 0.8071
#
# Epoch 00017: val_acc improved from 0.80320 to 0.80710, saving model to /content/gdrive/My Drive/Assignment6A_Modified:017-val_acc:0.807.hdf5
# Epoch 18/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.4379 - acc: 0.8452 - val_loss: 0.6073 - val_acc: 0.7971
#
# Epoch 00018: val_acc did not improve from 0.80710
# Epoch 19/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.4250 - acc: 0.8497 - val_loss: 0.5916 - val_acc: 0.8033
#
# Epoch 00019: val_acc did not improve from 0.80710
# Epoch 20/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.4094 - acc: 0.8539 - val_loss: 0.6518 - val_acc: 0.7909
#
# Epoch 00020: val_acc did not improve from 0.80710
# Epoch 21/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.4055 - acc: 0.8576 - val_loss: 0.6494 - val_acc: 0.7870
#
# Epoch 00021: val_acc did not improve from 0.80710
# Epoch 22/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3946 - acc: 0.8603 - val_loss: 0.5831 - val_acc: 0.8136
#
# Epoch 00022: val_acc improved from 0.80710 to 0.81360, saving model to /content/gdrive/My Drive/Assignment6A_Modified:022-val_acc:0.814.hdf5
# Epoch 23/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3882 - acc: 0.8618 - val_loss: 0.6871 - val_acc: 0.7887
#
# Epoch 00023: val_acc did not improve from 0.81360
# Epoch 24/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3731 - acc: 0.8679 - val_loss: 0.5732 - val_acc: 0.8115
#
# Epoch 00024: val_acc did not improve from 0.81360
# Epoch 25/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3735 - acc: 0.8677 - val_loss: 0.5835 - val_acc: 0.8096
#
# Epoch 00025: val_acc did not improve from 0.81360
# Epoch 26/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3576 - acc: 0.8710 - val_loss: 0.6268 - val_acc: 0.8035
#
# Epoch 00026: val_acc did not improve from 0.81360
# Epoch 27/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3561 - acc: 0.8730 - val_loss: 0.5664 - val_acc: 0.8158
#
# Epoch 00027: val_acc improved from 0.81360 to 0.81580, saving model to /content/gdrive/My Drive/Assignment6A_Modified:027-val_acc:0.816.hdf5
# Epoch 28/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3494 - acc: 0.8756 - val_loss: 0.6445 - val_acc: 0.7979
#
# Epoch 00028: val_acc did not improve from 0.81580
# Epoch 29/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3454 - acc: 0.8778 - val_loss: 0.6249 - val_acc: 0.8098
#
# Epoch 00029: val_acc did not improve from 0.81580
# Epoch 30/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3326 - acc: 0.8820 - val_loss: 0.6164 - val_acc: 0.8092
#
# Epoch 00030: val_acc did not improve from 0.81580
# Epoch 31/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3306 - acc: 0.8828 - val_loss: 0.5951 - val_acc: 0.8131
#
# Epoch 00031: val_acc did not improve from 0.81580
# Epoch 32/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3254 - acc: 0.8840 - val_loss: 0.5959 - val_acc: 0.8171
#
# Epoch 00032: val_acc improved from 0.81580 to 0.81710, saving model to /content/gdrive/My Drive/Assignment6A_Modified:032-val_acc:0.817.hdf5
# Epoch 33/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3227 - acc: 0.8851 - val_loss: 0.5750 - val_acc: 0.8179
#
# Epoch 00033: val_acc improved from 0.81710 to 0.81790, saving model to /content/gdrive/My Drive/Assignment6A_Modified:033-val_acc:0.818.hdf5
# Epoch 34/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3185 - acc: 0.8865 - val_loss: 0.5691 - val_acc: 0.8232
#
# Epoch 00034: val_acc improved from 0.81790 to 0.82320, saving model to /content/gdrive/My Drive/Assignment6A_Modified:034-val_acc:0.823.hdf5
# Epoch 35/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3073 - acc: 0.8902 - val_loss: 0.5999 - val_acc: 0.8178
#
# Epoch 00035: val_acc did not improve from 0.82320
# Epoch 36/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3046 - acc: 0.8896 - val_loss: 0.6002 - val_acc: 0.8164
#
# Epoch 00036: val_acc did not improve from 0.82320
# Epoch 37/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3092 - acc: 0.8893 - val_loss: 0.6129 - val_acc: 0.8163
#
# Epoch 00037: val_acc did not improve from 0.82320
# Epoch 38/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2959 - acc: 0.8943 - val_loss: 0.6136 - val_acc: 0.8163
#
# Epoch 00038: val_acc did not improve from 0.82320
# Epoch 39/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2981 - acc: 0.8924 - val_loss: 0.5940 - val_acc: 0.8199
#
# Epoch 00039: val_acc did not improve from 0.82320
# Epoch 40/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2887 - acc: 0.8967 - val_loss: 0.5882 - val_acc: 0.8198
#
# Epoch 00040: val_acc did not improve from 0.82320
# Epoch 41/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2889 - acc: 0.8947 - val_loss: 0.6027 - val_acc: 0.8226
#
# Epoch 00041: val_acc did not improve from 0.82320
# Epoch 42/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2846 - acc: 0.8981 - val_loss: 0.5912 - val_acc: 0.8259
#
# Epoch 00042: val_acc improved from 0.82320 to 0.82590, saving model to /content/gdrive/My Drive/Assignment6A_Modified:042-val_acc:0.826.hdf5
# Epoch 43/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2798 - acc: 0.8996 - val_loss: 0.5934 - val_acc: 0.8230
#
# Epoch 00043: val_acc did not improve from 0.82590
# Epoch 44/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2761 - acc: 0.9011 - val_loss: 0.5777 - val_acc: 0.8271
#
# Epoch 00044: val_acc improved from 0.82590 to 0.82710, saving model to /content/gdrive/My Drive/Assignment6A_Modified:044-val_acc:0.827.hdf5
# Epoch 45/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2742 - acc: 0.9016 - val_loss: 0.6082 - val_acc: 0.8165
#
# Epoch 00045: val_acc did not improve from 0.82710
# Epoch 46/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2728 - acc: 0.9022 - val_loss: 0.5890 - val_acc: 0.8232
#
# Epoch 00046: val_acc did not improve from 0.82710
# Epoch 47/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2712 - acc: 0.9026 - val_loss: 0.6188 - val_acc: 0.8218
#
# Epoch 00047: val_acc did not improve from 0.82710
# Epoch 48/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2645 - acc: 0.9044 - val_loss: 0.6606 - val_acc: 0.8076
#
# Epoch 00048: val_acc did not improve from 0.82710
# Epoch 49/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2654 - acc: 0.9038 - val_loss: 0.6271 - val_acc: 0.8188
#
# Epoch 00049: val_acc did not improve from 0.82710
# Epoch 50/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2609 - acc: 0.9061 - val_loss: 0.5837 - val_acc: 0.8322
#
# Epoch 00050: val_acc improved from 0.82710 to 0.83220, saving model to /content/gdrive/My Drive/Assignment6A_Modified:050-val_acc:0.832.hdf5
# Epoch 51/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2554 - acc: 0.9075 - val_loss: 0.6229 - val_acc: 0.8170
#
# Epoch 00051: val_acc did not improve from 0.83220
# Epoch 52/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2556 - acc: 0.9074 - val_loss: 0.6197 - val_acc: 0.8232
#
# Epoch 00052: val_acc did not improve from 0.83220
# Epoch 53/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2598 - acc: 0.9065 - val_loss: 0.5701 - val_acc: 0.8291
#
# Epoch 00053: val_acc did not improve from 0.83220
# Epoch 54/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2470 - acc: 0.9114 - val_loss: 0.6471 - val_acc: 0.8151
#
# Epoch 00054: val_acc did not improve from 0.83220
# Epoch 55/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2476 - acc: 0.9096 - val_loss: 0.5998 - val_acc: 0.8275
#
# Epoch 00055: val_acc did not improve from 0.83220
# Epoch 56/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2424 - acc: 0.9120 - val_loss: 0.6015 - val_acc: 0.8276
#
# Epoch 00056: val_acc did not improve from 0.83220
# Epoch 57/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2410 - acc: 0.9130 - val_loss: 0.6128 - val_acc: 0.8276
#
# Epoch 00057: val_acc did not improve from 0.83220
# Epoch 58/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2365 - acc: 0.9139 - val_loss: 0.6013 - val_acc: 0.8262
#
# Epoch 00058: val_acc did not improve from 0.83220
# Epoch 59/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2333 - acc: 0.9169 - val_loss: 0.6426 - val_acc: 0.8203
#
# Epoch 00059: val_acc did not improve from 0.83220
# Epoch 60/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2368 - acc: 0.9137 - val_loss: 0.6060 - val_acc: 0.8233
#
# Epoch 00060: val_acc did not improve from 0.83220
# Epoch 61/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2394 - acc: 0.9120 - val_loss: 0.6000 - val_acc: 0.8272
#
# Epoch 00061: val_acc did not improve from 0.83220
# Epoch 62/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2341 - acc: 0.9156 - val_loss: 0.6299 - val_acc: 0.8220
#
# Epoch 00062: val_acc did not improve from 0.83220
# Epoch 63/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2263 - acc: 0.9189 - val_loss: 0.6217 - val_acc: 0.8225
#
# Epoch 00063: val_acc did not improve from 0.83220
# Epoch 64/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2280 - acc: 0.9175 - val_loss: 0.6582 - val_acc: 0.8223
#
# Epoch 00064: val_acc did not improve from 0.83220
# Epoch 65/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2297 - acc: 0.9155 - val_loss: 0.6538 - val_acc: 0.8168
#
# Epoch 00065: val_acc did not improve from 0.83220
# Epoch 66/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2268 - acc: 0.9173 - val_loss: 0.5815 - val_acc: 0.8304
#
# Epoch 00066: val_acc did not improve from 0.83220
# Epoch 67/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2243 - acc: 0.9206 - val_loss: 0.6017 - val_acc: 0.8244
#
# Epoch 00067: val_acc did not improve from 0.83220
# Epoch 68/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2197 - acc: 0.9201 - val_loss: 0.6137 - val_acc: 0.8211
#
# Epoch 00068: val_acc did not improve from 0.83220
# Epoch 69/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2198 - acc: 0.9205 - val_loss: 0.6505 - val_acc: 0.8200
#
# Epoch 00069: val_acc did not improve from 0.83220
# Epoch 70/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2161 - acc: 0.9214 - val_loss: 0.6100 - val_acc: 0.8295
#
# Epoch 00070: val_acc did not improve from 0.83220
# Epoch 71/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2174 - acc: 0.9214 - val_loss: 0.6250 - val_acc: 0.8302
#
# Epoch 00071: val_acc did not improve from 0.83220
# Epoch 72/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2234 - acc: 0.9191 - val_loss: 0.6413 - val_acc: 0.8167
#
# Epoch 00072: val_acc did not improve from 0.83220
# Epoch 73/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2166 - acc: 0.9205 - val_loss: 0.6069 - val_acc: 0.8298
#
# Epoch 00073: val_acc did not improve from 0.83220
# Epoch 74/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2133 - acc: 0.9230 - val_loss: 0.6232 - val_acc: 0.8308
#
# Epoch 00074: val_acc did not improve from 0.83220
# Epoch 75/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2126 - acc: 0.9240 - val_loss: 0.6315 - val_acc: 0.8242
#
# Epoch 00075: val_acc did not improve from 0.83220
# Epoch 76/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2092 - acc: 0.9246 - val_loss: 0.6343 - val_acc: 0.8233
#
# Epoch 00076: val_acc did not improve from 0.83220
# Epoch 77/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2079 - acc: 0.9246 - val_loss: 0.6513 - val_acc: 0.8180
#
# Epoch 00077: val_acc did not improve from 0.83220
# Epoch 78/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2143 - acc: 0.9227 - val_loss: 0.6562 - val_acc: 0.8189
#
# Epoch 00078: val_acc did not improve from 0.83220
# Epoch 79/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2036 - acc: 0.9264 - val_loss: 0.5951 - val_acc: 0.8319
#
# Epoch 00079: val_acc did not improve from 0.83220
# Epoch 80/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2062 - acc: 0.9252 - val_loss: 0.6368 - val_acc: 0.8261
#
# Epoch 00080: val_acc did not improve from 0.83220
# Epoch 81/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2065 - acc: 0.9254 - val_loss: 0.6231 - val_acc: 0.8265
#
# Epoch 00081: val_acc did not improve from 0.83220
# Epoch 82/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2042 - acc: 0.9272 - val_loss: 0.6073 - val_acc: 0.8322
#
# Epoch 00082: val_acc did not improve from 0.83220
# Epoch 83/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2051 - acc: 0.9266 - val_loss: 0.6683 - val_acc: 0.8172
#
# Epoch 00083: val_acc did not improve from 0.83220
# Epoch 84/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1997 - acc: 0.9277 - val_loss: 0.6613 - val_acc: 0.8199
#
# Epoch 00084: val_acc did not improve from 0.83220
# Epoch 85/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1981 - acc: 0.9281 - val_loss: 0.6872 - val_acc: 0.8155
#
# Epoch 00085: val_acc did not improve from 0.83220
# Epoch 86/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1985 - acc: 0.9278 - val_loss: 0.6401 - val_acc: 0.8284
#
# Epoch 00086: val_acc did not improve from 0.83220
# Epoch 87/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1944 - acc: 0.9294 - val_loss: 0.6907 - val_acc: 0.8152
#
# Epoch 00087: val_acc did not improve from 0.83220
# Epoch 88/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1980 - acc: 0.9271 - val_loss: 0.6089 - val_acc: 0.8351
#
# Epoch 00088: val_acc improved from 0.83220 to 0.83510, saving model to /content/gdrive/My Drive/Assignment6A_Modified:088-val_acc:0.835.hdf5
# Epoch 89/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1927 - acc: 0.9304 - val_loss: 0.6872 - val_acc: 0.8179
#
# Epoch 00089: val_acc did not improve from 0.83510
# Epoch 90/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1909 - acc: 0.9295 - val_loss: 0.6213 - val_acc: 0.8299
#
# Epoch 00090: val_acc did not improve from 0.83510
# Epoch 91/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1974 - acc: 0.9282 - val_loss: 0.6287 - val_acc: 0.8309
#
# Epoch 00091: val_acc did not improve from 0.83510
# Epoch 92/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1927 - acc: 0.9298 - val_loss: 0.6127 - val_acc: 0.8355
#
# Epoch 00092: val_acc improved from 0.83510 to 0.83550, saving model to /content/gdrive/My Drive/Assignment6A_Modified:092-val_acc:0.836.hdf5
# Epoch 93/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1894 - acc: 0.9316 - val_loss: 0.6406 - val_acc: 0.8300
#
# Epoch 00093: val_acc did not improve from 0.83550
# Epoch 94/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1949 - acc: 0.9291 - val_loss: 0.6158 - val_acc: 0.8347
#
# Epoch 00094: val_acc did not improve from 0.83550
# Epoch 95/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1884 - acc: 0.9314 - val_loss: 0.6716 - val_acc: 0.8278
#
# Epoch 00095: val_acc did not improve from 0.83550
# Epoch 96/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1874 - acc: 0.9314 - val_loss: 0.6256 - val_acc: 0.8296
#
# Epoch 00096: val_acc did not improve from 0.83550
# Epoch 97/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1841 - acc: 0.9320 - val_loss: 0.6290 - val_acc: 0.8270
#
# Epoch 00097: val_acc did not improve from 0.83550
# Epoch 98/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1887 - acc: 0.9315 - val_loss: 0.6469 - val_acc: 0.8310
#
# Epoch 00098: val_acc did not improve from 0.83550
# Epoch 99/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1855 - acc: 0.9323 - val_loss: 0.6450 - val_acc: 0.8326
#
# Epoch 00099: val_acc did not improve from 0.83550
# Epoch 100/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1815 - acc: 0.9336 - val_loss: 0.6154 - val_acc: 0.8264
#
# Epoch 00100: val_acc did not improve from 0.83550
# Model took 1289.70 seconds to train
# Accuracy on test data is: 82.64

# %% [markdown]
# # BEST ACCURACY WITH CHANGED MODEL
# Epoch 92/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1927 - acc: 0.9298 - val_loss: 0.6127 - **val_acc: 0.8355**
#
# Epoch 00092: val_acc improved from 0.83510 to **0.83550**, saving model to /content/gdrive/My Drive/Assignment6A_Modified:092-val_acc:0.836.hdf5

# %%
#Loading the best weights for prediction
model.load_weights('/content/gdrive/My Drive/Assignment6A_Modified:092-val_acc:0.836.hdf5')

# %%
#Finding misclassified images
d = {'pred': model.predict_classes(test_features), 'true': np.argmax(test_labels,axis=1)} #axis=1!important!
df = pd.DataFrame(data=d)

# shows total mispredictions
df2 = df[(df.pred != df.true)]
df2

df2.shape
# Out:
# (1645, 2)

# %%
df2[0:25]
# Out:
#      pred  true
# 10      3     0
# 24      4     5
# 25      4     2
# 35      3     2
# 42      3     5
# 52      3     0
# 57      3     7
# 70      3     2
# 76      0     9
# 78      5     3
# 85      2     5
# 87      3     7
# 112     2     6
# 118     6     2
# 119     2     7
# 125     2     0
# 127     7     3
# 139     1     9
# 143     7     3
# 145     3     7
# 147     6     2
# 158     3     5
# 162     3     6
# 165     2     4
# 169     8     0

# %%
#Function to get actual class names
def getClassName(classNumber):
  for i in range(len(class_names)):
    if(classNumber == i):
      className = class_names[i]
  return className

# %%
#Plotting 25 misclassified images
plt.figure(figsize = (20,20))

for i in range(25):
    plt.subplot(5, 5,i+1)
    img = test_features[df2.index[i]]
    img = img.reshape((32,32,3))
    plt.imshow(img, cmap='gray')
    plt.title("Original: " + getClassName(df2["true"].iloc[i])+"    Predicted: " + getClassName(df2["pred"].iloc[i]))
    plt.axis('off')
    
plt.show()

# %%
plt.imshow(test_features[119])

# %%
#Function to plot original image and GradCAM image
def plotOrigGradCam(image_number):
  (train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
  
  # Pixel normalization for test images
  test_features = test_features.astype('float32')/255

  # convert class labels to binary class labels
  test_labels = np_utils.to_categorical(test_labels, num_classes)
  
  img = test_features[image_number]
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)
  #x = preprocess_input(x)
  
  preds = model.predict(x)
  class_idx = np.argmax(preds[0])
  class_output = model.output[:, class_idx]
  last_conv_layer = model.get_layer("activation_8")
  
  grads = K.gradients(class_output, last_conv_layer.output)[0]
  pooled_grads = K.mean(grads, axis=(0, 1, 2))
  iterate = K.function([model.input], [pooled_grads, last_conv_layer.output[0]])
  pooled_grads_value, conv_layer_output_value = iterate([test_features])
  for i in range(96):
    conv_layer_output_value[:, :, i] *= pooled_grads_value[i]
    
  heatmap = np.mean(conv_layer_output_value, axis=-1)
  heatmap = np.maximum(heatmap, 0)
  heatmap /= np.max(heatmap)
  
  (train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
  
  img = test_features[image_number]
  heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
  heatmap = np.uint8(255 * heatmap)
  heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
  superimposed_img = cv2.addWeighted(img, 0.6, heatmap, 0.4, 0)
  plt.title("Original: " + getClassName(test_labels[image_number])+"    Predicted: " + getClassName(class_idx))
  plt.imshow(img)
  plt.show()
  plt.imshow(superimposed_img)
  plt.show()
  cv2.waitKey(0)

# %%
#Image numbers of selected images
selected_image_numbers = [127,162,165,169]

#Running a loop to plot original and GradCAM image for all the selected images
for i in range(len(selected_image_numbers)):  
  plotOrigGradCam(selected_image_numbers[i])

# %% [markdown]
# # INTRODUCING CUTOUT

# %%
# Specifying the path to store the weights
filepath="/content/gdrive/My Drive/Assignment9_Cutout:{epoch:03d}-val_acc:{val_acc:.3f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, save_weights_only=True, mode='max')

# %%
# !wget https://raw.githubusercontent.com/yu4u/cutout-random-erasing/master/random_eraser.py

from random_eraser import get_random_eraser
# Out:
# --2019-06-30 09:21:02--  https://raw.githubusercontent.com/yu4u/cutout-random-erasing/master/random_eraser.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 888 [text/plain]
# Saving to: ‘random_eraser.py.2’
#
# random_eraser.py.2  100%[===================>]     888  --.-KB/s    in 0s
#
# 2019-06-30 09:21:02 (184 MB/s) - ‘random_eraser.py.2’ saved [888/888]

# %%
from keras.preprocessing.image import ImageDataGenerator

#Adding cutout as a preprocessing function
datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False,
                             preprocessing_function=get_random_eraser(v_l=0, v_h=1, pixel_level=False))


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 100, 
                                 validation_data = (test_features, test_labels), verbose=1,
                                 callbacks=[checkpoint])
end = time.time()
print ("Model took %0.2f seconds to train with cutout"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f with cutout"%accuracy(test_features, test_labels, model))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, callbacks=[<keras.ca..., steps_per_epoch=390, epochs=100)`
#
# W0630 09:21:18.732418 140168414099328 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/100
# 390/390 [==============================] - 17s 43ms/step - loss: 1.6506 - acc: 0.3995 - val_loss: 1.5039 - val_acc: 0.4735
#
# Epoch 00001: val_acc improved from -inf to 0.47350, saving model to /content/gdrive/My Drive/Assignment9_Cutout:001-val_acc:0.473.hdf5
# Epoch 2/100
# 390/390 [==============================] - 13s 34ms/step - loss: 1.2698 - acc: 0.5441 - val_loss: 1.1379 - val_acc: 0.5987
#
# Epoch 00002: val_acc improved from 0.47350 to 0.59870, saving model to /content/gdrive/My Drive/Assignment9_Cutout:002-val_acc:0.599.hdf5
# Epoch 3/100
# 390/390 [==============================] - 13s 33ms/step - loss: 1.1030 - acc: 0.6060 - val_loss: 1.1430 - val_acc: 0.5990
#
# Epoch 00003: val_acc improved from 0.59870 to 0.59900, saving model to /content/gdrive/My Drive/Assignment9_Cutout:003-val_acc:0.599.hdf5
# Epoch 4/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.9834 - acc: 0.6519 - val_loss: 0.8851 - val_acc: 0.6877
#
# Epoch 00004: val_acc improved from 0.59900 to 0.68770, saving model to /content/gdrive/My Drive/Assignment9_Cutout:004-val_acc:0.688.hdf5
# Epoch 5/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.9026 - acc: 0.6805 - val_loss: 0.8304 - val_acc: 0.7117
#
# Epoch 00005: val_acc improved from 0.68770 to 0.71170, saving model to /content/gdrive/My Drive/Assignment9_Cutout:005-val_acc:0.712.hdf5
# Epoch 6/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.8419 - acc: 0.7013 - val_loss: 0.8340 - val_acc: 0.7066
#
# Epoch 00006: val_acc did not improve from 0.71170
# Epoch 7/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.7975 - acc: 0.7179 - val_loss: 0.7777 - val_acc: 0.7320
#
# Epoch 00007: val_acc improved from 0.71170 to 0.73200, saving model to /content/gdrive/My Drive/Assignment9_Cutout:007-val_acc:0.732.hdf5
# Epoch 8/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.7648 - acc: 0.7308 - val_loss: 0.7819 - val_acc: 0.7294
#
# Epoch 00008: val_acc did not improve from 0.73200
# Epoch 9/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.7333 - acc: 0.7406 - val_loss: 0.7251 - val_acc: 0.7505
#
# Epoch 00009: val_acc improved from 0.73200 to 0.75050, saving model to /content/gdrive/My Drive/Assignment9_Cutout:009-val_acc:0.750.hdf5
# Epoch 10/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.7096 - acc: 0.7496 - val_loss: 0.7575 - val_acc: 0.7403
#
# Epoch 00010: val_acc did not improve from 0.75050
# Epoch 11/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.6873 - acc: 0.7584 - val_loss: 0.6508 - val_acc: 0.7755
#
# Epoch 00011: val_acc improved from 0.75050 to 0.77550, saving model to /content/gdrive/My Drive/Assignment9_Cutout:011-val_acc:0.775.hdf5
# Epoch 12/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.6632 - acc: 0.7660 - val_loss: 0.7312 - val_acc: 0.7520
#
# Epoch 00012: val_acc did not improve from 0.77550
# Epoch 13/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.6459 - acc: 0.7712 - val_loss: 0.7160 - val_acc: 0.7620
#
# Epoch 00013: val_acc did not improve from 0.77550
# Epoch 14/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.6259 - acc: 0.7805 - val_loss: 0.6303 - val_acc: 0.7852
#
# Epoch 00014: val_acc improved from 0.77550 to 0.78520, saving model to /content/gdrive/My Drive/Assignment9_Cutout:014-val_acc:0.785.hdf5
# Epoch 15/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.6183 - acc: 0.7823 - val_loss: 0.6133 - val_acc: 0.7912
#
# Epoch 00015: val_acc improved from 0.78520 to 0.79120, saving model to /content/gdrive/My Drive/Assignment9_Cutout:015-val_acc:0.791.hdf5
# Epoch 16/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.6010 - acc: 0.7878 - val_loss: 0.6222 - val_acc: 0.7857
#
# Epoch 00016: val_acc did not improve from 0.79120
# Epoch 17/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.5856 - acc: 0.7929 - val_loss: 0.6174 - val_acc: 0.7897
#
# Epoch 00017: val_acc did not improve from 0.79120
# Epoch 18/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.5699 - acc: 0.7989 - val_loss: 0.5743 - val_acc: 0.8030
#
# Epoch 00018: val_acc improved from 0.79120 to 0.80300, saving model to /content/gdrive/My Drive/Assignment9_Cutout:018-val_acc:0.803.hdf5
# Epoch 19/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.5624 - acc: 0.8029 - val_loss: 0.5928 - val_acc: 0.8017
#
# Epoch 00019: val_acc did not improve from 0.80300
# Epoch 20/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.5545 - acc: 0.8026 - val_loss: 0.5710 - val_acc: 0.8040
#
# Epoch 00020: val_acc improved from 0.80300 to 0.80400, saving model to /content/gdrive/My Drive/Assignment9_Cutout:020-val_acc:0.804.hdf5
# Epoch 21/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.5381 - acc: 0.8094 - val_loss: 0.5887 - val_acc: 0.7988
#
# Epoch 00021: val_acc did not improve from 0.80400
# Epoch 22/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.5377 - acc: 0.8082 - val_loss: 0.6492 - val_acc: 0.7923
#
# Epoch 00022: val_acc did not improve from 0.80400
# Epoch 23/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.5228 - acc: 0.8152 - val_loss: 0.6771 - val_acc: 0.7807
#
# Epoch 00023: val_acc did not improve from 0.80400
# Epoch 24/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.5167 - acc: 0.8178 - val_loss: 0.5652 - val_acc: 0.8084
#
# Epoch 00024: val_acc improved from 0.80400 to 0.80840, saving model to /content/gdrive/My Drive/Assignment9_Cutout:024-val_acc:0.808.hdf5
# Epoch 25/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.5138 - acc: 0.8174 - val_loss: 0.5574 - val_acc: 0.8144
#
# Epoch 00025: val_acc improved from 0.80840 to 0.81440, saving model to /content/gdrive/My Drive/Assignment9_Cutout:025-val_acc:0.814.hdf5
# Epoch 26/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.5040 - acc: 0.8235 - val_loss: 0.5495 - val_acc: 0.8156
#
# Epoch 00026: val_acc improved from 0.81440 to 0.81560, saving model to /content/gdrive/My Drive/Assignment9_Cutout:026-val_acc:0.816.hdf5
# Epoch 27/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.4999 - acc: 0.8232 - val_loss: 0.5782 - val_acc: 0.8074
#
# Epoch 00027: val_acc did not improve from 0.81560
# Epoch 28/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.4948 - acc: 0.8235 - val_loss: 0.5926 - val_acc: 0.8064
#
# Epoch 00028: val_acc did not improve from 0.81560
# Epoch 29/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.4889 - acc: 0.8270 - val_loss: 0.5907 - val_acc: 0.8067
#
# Epoch 00029: val_acc did not improve from 0.81560
# Epoch 30/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.4832 - acc: 0.8297 - val_loss: 0.5691 - val_acc: 0.8159
#
# Epoch 00030: val_acc improved from 0.81560 to 0.81590, saving model to /content/gdrive/My Drive/Assignment9_Cutout:030-val_acc:0.816.hdf5
# Epoch 31/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.4754 - acc: 0.8308 - val_loss: 0.5417 - val_acc: 0.8159
#
# Epoch 00031: val_acc did not improve from 0.81590
# Epoch 32/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.4785 - acc: 0.8309 - val_loss: 0.5285 - val_acc: 0.8248
#
# Epoch 00032: val_acc improved from 0.81590 to 0.82480, saving model to /content/gdrive/My Drive/Assignment9_Cutout:032-val_acc:0.825.hdf5
# Epoch 33/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.4644 - acc: 0.8342 - val_loss: 0.5555 - val_acc: 0.8163
#
# Epoch 00033: val_acc did not improve from 0.82480
# Epoch 34/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.4606 - acc: 0.8363 - val_loss: 0.5660 - val_acc: 0.8163
#
# Epoch 00034: val_acc did not improve from 0.82480
# Epoch 35/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.4526 - acc: 0.8399 - val_loss: 0.5576 - val_acc: 0.8224
#
# Epoch 00035: val_acc did not improve from 0.82480
# Epoch 36/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.4553 - acc: 0.8386 - val_loss: 0.5264 - val_acc: 0.8282
#
# Epoch 00036: val_acc improved from 0.82480 to 0.82820, saving model to /content/gdrive/My Drive/Assignment9_Cutout:036-val_acc:0.828.hdf5
# Epoch 37/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.4526 - acc: 0.8386 - val_loss: 0.5801 - val_acc: 0.8061
#
# Epoch 00037: val_acc did not improve from 0.82820
# Epoch 38/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.4459 - acc: 0.8401 - val_loss: 0.5402 - val_acc: 0.8208
#
# Epoch 00038: val_acc did not improve from 0.82820
# Epoch 39/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.4375 - acc: 0.8457 - val_loss: 0.5680 - val_acc: 0.8193
#
# Epoch 00039: val_acc did not improve from 0.82820
# Epoch 40/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.4348 - acc: 0.8437 - val_loss: 0.5524 - val_acc: 0.8190
#
# Epoch 00040: val_acc did not improve from 0.82820
# Epoch 41/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.4333 - acc: 0.8461 - val_loss: 0.5459 - val_acc: 0.8217
#
# Epoch 00041: val_acc did not improve from 0.82820
# Epoch 42/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.4293 - acc: 0.8480 - val_loss: 0.5248 - val_acc: 0.8228
#
# Epoch 00042: val_acc did not improve from 0.82820
# Epoch 43/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.4311 - acc: 0.8471 - val_loss: 0.5413 - val_acc: 0.8258
#
# Epoch 00043: val_acc did not improve from 0.82820
# Epoch 44/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.4236 - acc: 0.8518 - val_loss: 0.5283 - val_acc: 0.8295
#
# Epoch 00044: val_acc improved from 0.82820 to 0.82950, saving model to /content/gdrive/My Drive/Assignment9_Cutout:044-val_acc:0.830.hdf5
# Epoch 45/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.4205 - acc: 0.8499 - val_loss: 0.5258 - val_acc: 0.8267
#
# Epoch 00045: val_acc did not improve from 0.82950
# Epoch 46/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.4248 - acc: 0.8488 - val_loss: 0.5142 - val_acc: 0.8331
#
# Epoch 00046: val_acc improved from 0.82950 to 0.83310, saving model to /content/gdrive/My Drive/Assignment9_Cutout:046-val_acc:0.833.hdf5
# Epoch 47/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.4156 - acc: 0.8526 - val_loss: 0.5254 - val_acc: 0.8324
#
# Epoch 00047: val_acc did not improve from 0.83310
# Epoch 48/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.4128 - acc: 0.8525 - val_loss: 0.5323 - val_acc: 0.8272
#
# Epoch 00048: val_acc did not improve from 0.83310
# Epoch 49/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.4080 - acc: 0.8539 - val_loss: 0.5730 - val_acc: 0.8197
#
# Epoch 00049: val_acc did not improve from 0.83310
# Epoch 50/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.4026 - acc: 0.8563 - val_loss: 0.5169 - val_acc: 0.8350
#
# Epoch 00050: val_acc improved from 0.83310 to 0.83500, saving model to /content/gdrive/My Drive/Assignment9_Cutout:050-val_acc:0.835.hdf5
# Epoch 51/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.4005 - acc: 0.8566 - val_loss: 0.6357 - val_acc: 0.7995
#
# Epoch 00051: val_acc did not improve from 0.83500
# Epoch 52/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.4018 - acc: 0.8568 - val_loss: 0.5222 - val_acc: 0.8294
#
# Epoch 00052: val_acc did not improve from 0.83500
# Epoch 53/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.3987 - acc: 0.8581 - val_loss: 0.5264 - val_acc: 0.8313
#
# Epoch 00053: val_acc did not improve from 0.83500
# Epoch 54/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.3953 - acc: 0.8591 - val_loss: 0.5708 - val_acc: 0.8150
#
# Epoch 00054: val_acc did not improve from 0.83500
# Epoch 55/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.3913 - acc: 0.8609 - val_loss: 0.5270 - val_acc: 0.8339
#
# Epoch 00055: val_acc did not improve from 0.83500
# Epoch 56/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.3968 - acc: 0.8582 - val_loss: 0.5106 - val_acc: 0.8354
#
# Epoch 00056: val_acc improved from 0.83500 to 0.83540, saving model to /content/gdrive/My Drive/Assignment9_Cutout:056-val_acc:0.835.hdf5
# Epoch 57/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.3896 - acc: 0.8603 - val_loss: 0.5159 - val_acc: 0.8365
#
# Epoch 00057: val_acc improved from 0.83540 to 0.83650, saving model to /content/gdrive/My Drive/Assignment9_Cutout:057-val_acc:0.837.hdf5
# Epoch 58/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3872 - acc: 0.8645 - val_loss: 0.5446 - val_acc: 0.8266
#
# Epoch 00058: val_acc did not improve from 0.83650
# Epoch 59/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.3832 - acc: 0.8629 - val_loss: 0.5420 - val_acc: 0.8274
#
# Epoch 00059: val_acc did not improve from 0.83650
# Epoch 60/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.3820 - acc: 0.8647 - val_loss: 0.5333 - val_acc: 0.8311
#
# Epoch 00060: val_acc did not improve from 0.83650
# Epoch 61/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.3815 - acc: 0.8630 - val_loss: 0.5246 - val_acc: 0.8311
#
# Epoch 00061: val_acc did not improve from 0.83650
# Epoch 62/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.3805 - acc: 0.8647 - val_loss: 0.5456 - val_acc: 0.8263
#
# Epoch 00062: val_acc did not improve from 0.83650
# Epoch 63/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.3765 - acc: 0.8658 - val_loss: 0.5016 - val_acc: 0.8387
#
# Epoch 00063: val_acc improved from 0.83650 to 0.83870, saving model to /content/gdrive/My Drive/Assignment9_Cutout:063-val_acc:0.839.hdf5
# Epoch 64/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.3712 - acc: 0.8676 - val_loss: 0.5383 - val_acc: 0.8258
#
# Epoch 00064: val_acc did not improve from 0.83870
# Epoch 65/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3730 - acc: 0.8663 - val_loss: 0.5209 - val_acc: 0.8377
#
# Epoch 00065: val_acc did not improve from 0.83870
# Epoch 66/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3738 - acc: 0.8664 - val_loss: 0.5722 - val_acc: 0.8174
#
# Epoch 00066: val_acc did not improve from 0.83870
# Epoch 67/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3653 - acc: 0.8681 - val_loss: 0.5451 - val_acc: 0.8290
#
# Epoch 00067: val_acc did not improve from 0.83870
# Epoch 68/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3694 - acc: 0.8682 - val_loss: 0.5218 - val_acc: 0.8375
#
# Epoch 00068: val_acc did not improve from 0.83870
# Epoch 69/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3621 - acc: 0.8717 - val_loss: 0.5407 - val_acc: 0.8309
#
# Epoch 00069: val_acc did not improve from 0.83870
# Epoch 70/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3686 - acc: 0.8686 - val_loss: 0.5934 - val_acc: 0.8167
#
# Epoch 00070: val_acc did not improve from 0.83870
# Epoch 71/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3651 - acc: 0.8714 - val_loss: 0.5414 - val_acc: 0.8285
#
# Epoch 00071: val_acc did not improve from 0.83870
# Epoch 72/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3639 - acc: 0.8696 - val_loss: 0.5604 - val_acc: 0.8260
#
# Epoch 00072: val_acc did not improve from 0.83870
# Epoch 73/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3549 - acc: 0.8741 - val_loss: 0.5178 - val_acc: 0.8352
#
# Epoch 00073: val_acc did not improve from 0.83870
# Epoch 74/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3584 - acc: 0.8713 - val_loss: 0.5164 - val_acc: 0.8375
#
# Epoch 00074: val_acc did not improve from 0.83870
# Epoch 75/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3572 - acc: 0.8729 - val_loss: 0.5339 - val_acc: 0.8300
#
# Epoch 00075: val_acc did not improve from 0.83870
# Epoch 76/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3547 - acc: 0.8754 - val_loss: 0.5056 - val_acc: 0.8388
#
# Epoch 00076: val_acc improved from 0.83870 to 0.83880, saving model to /content/gdrive/My Drive/Assignment9_Cutout:076-val_acc:0.839.hdf5
# Epoch 77/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3559 - acc: 0.8730 - val_loss: 0.5330 - val_acc: 0.8297
#
# Epoch 00077: val_acc did not improve from 0.83880
# Epoch 78/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3562 - acc: 0.8721 - val_loss: 0.5440 - val_acc: 0.8291
#
# Epoch 00078: val_acc did not improve from 0.83880
# Epoch 79/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3484 - acc: 0.8765 - val_loss: 0.5092 - val_acc: 0.8374
#
# Epoch 00079: val_acc did not improve from 0.83880
# Epoch 80/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3506 - acc: 0.8765 - val_loss: 0.5151 - val_acc: 0.8343
#
# Epoch 00080: val_acc did not improve from 0.83880
# Epoch 81/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.3475 - acc: 0.8745 - val_loss: 0.5134 - val_acc: 0.8385
#
# Epoch 00081: val_acc did not improve from 0.83880
# Epoch 82/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3490 - acc: 0.8753 - val_loss: 0.5323 - val_acc: 0.8365
#
# Epoch 00082: val_acc did not improve from 0.83880
# Epoch 83/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3477 - acc: 0.8754 - val_loss: 0.5470 - val_acc: 0.8321
#
# Epoch 00083: val_acc did not improve from 0.83880
# Epoch 84/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.3433 - acc: 0.8771 - val_loss: 0.5203 - val_acc: 0.8369
#
# Epoch 00084: val_acc did not improve from 0.83880
# Epoch 85/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.3434 - acc: 0.8762 - val_loss: 0.5321 - val_acc: 0.8345
#
# Epoch 00085: val_acc did not improve from 0.83880
# Epoch 86/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.3401 - acc: 0.8793 - val_loss: 0.5227 - val_acc: 0.8397
#
# Epoch 00086: val_acc improved from 0.83880 to 0.83970, saving model to /content/gdrive/My Drive/Assignment9_Cutout:086-val_acc:0.840.hdf5
# Epoch 87/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3434 - acc: 0.8765 - val_loss: 0.5127 - val_acc: 0.8389
#
# Epoch 00087: val_acc did not improve from 0.83970
# Epoch 88/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3395 - acc: 0.8796 - val_loss: 0.5899 - val_acc: 0.8166
#
# Epoch 00088: val_acc did not improve from 0.83970
# Epoch 89/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3386 - acc: 0.8795 - val_loss: 0.5092 - val_acc: 0.8415
#
# Epoch 00089: val_acc improved from 0.83970 to 0.84150, saving model to /content/gdrive/My Drive/Assignment9_Cutout:089-val_acc:0.842.hdf5
# Epoch 90/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3342 - acc: 0.8812 - val_loss: 0.5389 - val_acc: 0.8354
#
# Epoch 00090: val_acc did not improve from 0.84150
# Epoch 91/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3382 - acc: 0.8810 - val_loss: 0.5443 - val_acc: 0.8340
#
# Epoch 00091: val_acc did not improve from 0.84150
# Epoch 92/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3344 - acc: 0.8806 - val_loss: 0.5272 - val_acc: 0.8360
#
# Epoch 00092: val_acc did not improve from 0.84150
# Epoch 93/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3339 - acc: 0.8804 - val_loss: 0.5153 - val_acc: 0.8356
#
# Epoch 00093: val_acc did not improve from 0.84150
# Epoch 94/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3327 - acc: 0.8819 - val_loss: 0.5745 - val_acc: 0.8304
#
# Epoch 00094: val_acc did not improve from 0.84150
# Epoch 95/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.3311 - acc: 0.8820 - val_loss: 0.5042 - val_acc: 0.8408
#
# Epoch 00095: val_acc did not improve from 0.84150
# Epoch 96/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3310 - acc: 0.8814 - val_loss: 0.5520 - val_acc: 0.8300
#
# Epoch 00096: val_acc did not improve from 0.84150
# Epoch 97/100
# 390/390 [==============================] - 13s 34ms/step - loss: 0.3312 - acc: 0.8806 - val_loss: 0.5201 - val_acc: 0.8387
#
# Epoch 00097: val_acc did not improve from 0.84150
# Epoch 98/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3269 - acc: 0.8826 - val_loss: 0.5476 - val_acc: 0.8294
#
# Epoch 00098: val_acc did not improve from 0.84150
# Epoch 99/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3293 - acc: 0.8822 - val_loss: 0.5389 - val_acc: 0.8353
#
# Epoch 00099: val_acc did not improve from 0.84150
# Epoch 100/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3270 - acc: 0.8834 - val_loss: 0.5059 - val_acc: 0.8347
#
# Epoch 00100: val_acc did not improve from 0.84150
# Model took 1314.79 seconds to train with cutout
# Accuracy on test data is: 83.47 with cutout

# %% [markdown]
# # BEST ACCURACY WITH CHANGED MODEL
# Epoch 89/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3386 - acc: 0.8795 - val_loss: 0.5092 - **val_acc: 0.8415**
#
# Epoch 00089: val_acc improved from 0.83970 to **0.84150**, saving model to /content/gdrive/My Drive/Assignment9_Cutout:089-val_acc:0.842.hdf5

# %%
#Loading the best weights with cutout
model.load_weights('/content/gdrive/My Drive/Assignment9_Cutout:089-val_acc:0.842.hdf5')

# %%
#Finding misclassifications with cutout
d_cutout = {'pred': model.predict_classes(test_features), 'true': np.argmax(test_labels,axis=1)} #axis=1!important!
df_cutout = pd.DataFrame(data=d_cutout)

# shows total mispredictions
df2_cutout = df_cutout[(df_cutout.pred != df_cutout.true)]
df2_correct = df_cutout[(df_cutout.pred == df_cutout.true)]

df2_cutout.shape
# Out:
# (1585, 2)

# %%
df2_cutout
# Out:
#       pred  true
# 24       4     5
# 26       2     4
# 33       3     5
# 35       9     2
# 37       9     1
# 42       7     5
# 57       3     7
# 58       3     4
# 59       3     6
# 61       5     3
# 68       9     3
# 70       8     2
# 78       5     3
# 85       7     5
# 95       3     6
# 125      2     0
# 128      3     5
# 139      8     9
# 145      3     7
# 147      5     2
# 158      3     5
# 171      0     9
# 188      2     4
# 189      8     0
# 221      5     6
# 224      4     3
# 228      3     7
# 237      9     0
# 247      8     9
# 248      4     2
# ...    ...   ...
# 9866     9     1
# 9872     8     0
# 9878     7     5
# 9881     1     9
# 9891     0     2
# 9901     2     3
# 9910     7     4
# 9918     7     5
# 9919     2     4
# 9921     8     0
# 9923     6     7
# 9924     0     4
# 9926     4     3
# 9928     2     5
# 9930     3     8
# 9933     2     7
# 9940     3     4
# 9949     6     3
# 9950     5     3
# 9953     4     7
# 9957     8     0
# 9960     0     2
# 9964     4     2
# 9965     0     2
# 9967     8     3
# 9968     2     3
# 9982     6     2
# 9989     4     2
# 9993     3     5
# 9995     0     8
#
# [1585 rows x 2 columns]

# %%
#Image numbers of selected images
selected_image_numbers = [127,162,165,169]

#Running a loop to plot original and GradCAM image for all the selected images
for i in range(len(selected_image_numbers)):  
  plotOrigGradCam(selected_image_numbers[i])
